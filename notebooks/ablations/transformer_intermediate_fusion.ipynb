# %% [markdown]
# # TRANSFORMER Intermediate Fusion Ablation
#
# Experiment: `transformer_inter_fusion`
#
# This notebook runs full GPU training on a stratified 80/10/10 train/validation/test split built from the extracted processed tabular data and image tensors. Image runs use tensor-safe train augmentation and class-weighted loss. CNN runs use tempered class-weighted loss, stronger paper-style augmentation, and early stopping to reduce overfitting; balanced sampling can be enabled manually, but is off by default because it over-corrected on this dataset. Fusion modes combine the tabular metadata vector with the image tensor. It prints per-epoch train/validation loss, accuracy, macro AUC, and macro F1 with tqdm progress bars. Epoch logs are written under `Results_Logs/<experiment>/`, figures under `Results_Figures/<experiment>/`, and XAI artifacts under `Results_XAI/<experiment>/`.

# %%
from pathlib import Path
import os, sys
REPO_ROOT = Path('/home/zeus/content/IOT_fusion')
os.chdir(REPO_ROOT)
sys.path.insert(0, str(REPO_ROOT / 'training'))
from ablation_utils import get_data_info, run_training

info = get_data_info()
print('classes:', info.class_to_idx)
print('metadata_dim:', info.metadata_dim)
# Out:
# classes: {'ACK': 0, 'BCC': 1, 'MEL': 2, 'NEV': 3, 'SCC': 4, 'SEK': 5}
# metadata_dim: 87

# %% [markdown]
# ## Full GPU Training
# Adjust `epochs` and `batch_size` if needed.

# %%
full_result = run_training(
    model_name='transformer',
    input_mode='intermediate_fusion',
    experiment_name='transformer_inter_fusion',
    epochs=25,
    batch_size=256,
    lr=0.0005,
    num_workers=2,
    device_name='cuda',
    wandb_enabled=True,
    xai_enabled=True,
    augment_train=True,
    class_weighted_loss=True,
    class_weight_power=0.5,
    class_balanced_sampler=False,
    early_stopping_patience=12,
    min_epochs=15,
)
full_result
# Out:
# wandb: [wandb.login()] Loaded credentials for https://api.wandb.ai from WANDB_API_KEY.
# wandb: Currently logged in as: belalofficial123 (belalofficial123-the-british-university-in-egypt) to https://api.wandb.ai. Use `wandb login --relogin` to force relogin
# wandb: Tracking run with wandb version 0.26.0
# wandb: Run data is saved locally in /home/zeus/content/IOT_fusion/wandb/run-20260416_192957-xo0ii6ou
# wandb: Run `wandb offline` to turn off syncing.
# wandb: Syncing run transformer_inter_fusion
# wandb: ⭐️ View project at https://wandb.ai/belalofficial123-the-british-university-in-egypt/iot%20fusion
# wandb: 🚀 View run at https://wandb.ai/belalofficial123-the-british-university-in-egypt/iot%20fusion/runs/xo0ii6ou
# Split sizes: {'train': 1838, 'val': 230, 'test': 230}
# Class mapping: {'ACK': 0, 'BCC': 1, 'MEL': 2, 'NEV': 3, 'SCC': 4, 'SEK': 5}
# /home/zeus/miniconda3/envs/cloudspace/lib/python3.12/site-packages/torch/nn/modules/transformer.py:392: UserWarning: enable_nested_tensor is True, but self.use_nested_tensor is False because encoder_layer.norm_first was True
#   warnings.warn(
# transformer_inter_fusion train epoch 1/25:   0%|          | 0/8 [00:00<?, ?it/s]
# transformer_inter_fusion val epoch 1/25:   0%|          | 0/1 [00:00<?, ?it/s]
# Epoch 001/25 | train_loss=1.9083 train_acc=22.36% train_bacc=16.25% train_auc=0.4936 train_f1=0.1292 | val_loss=1.7442 val_acc=39.13% val_bacc=18.31% val_auc=0.5891 val_f1=0.1358
# transformer_inter_fusion train epoch 2/25:   0%|          | 0/8 [00:00<?, ?it/s]
# transformer_inter_fusion val epoch 2/25:   0%|          | 0/1 [00:00<?, ?it/s]
# Epoch 002/25 | train_loss=1.7500 train_acc=36.94% train_bacc=18.51% train_auc=0.5765 train_f1=0.1647 | val_loss=1.7034 val_acc=46.09% val_bacc=22.85% val_auc=0.6591 val_f1=0.1990
# transformer_inter_fusion train epoch 3/25:   0%|          | 0/8 [00:00<?, ?it/s]
# transformer_inter_fusion val epoch 3/25:   0%|          | 0/1 [00:00<?, ?it/s]
# Epoch 003/25 | train_loss=1.7158 train_acc=40.04% train_bacc=24.63% train_auc=0.6206 train_f1=0.2339 | val_loss=1.6606 val_acc=50.00% val_bacc=31.42% val_auc=0.7153 val_f1=0.2607
# transformer_inter_fusion train epoch 4/25:   0%|          | 0/8 [00:00<?, ?it/s]
# transformer_inter_fusion val epoch 4/25:   0%|          | 0/1 [00:00<?, ?it/s]
# Epoch 004/25 | train_loss=1.6608 train_acc=46.79% train_bacc=32.31% train_auc=0.6737 train_f1=0.2951 | val_loss=1.6245 val_acc=50.00% val_bacc=36.35% val_auc=0.7598 val_f1=0.2958
# transformer_inter_fusion train epoch 5/25:   0%|          | 0/8 [00:00<?, ?it/s]
# transformer_inter_fusion val epoch 5/25:   0%|          | 0/1 [00:00<?, ?it/s]
# Epoch 005/25 | train_loss=1.6291 train_acc=48.31% train_bacc=31.51% train_auc=0.7166 train_f1=0.3090 | val_loss=1.5755 val_acc=55.65% val_bacc=40.33% val_auc=0.7953 val_f1=0.3500
# transformer_inter_fusion train epoch 6/25:   0%|          | 0/8 [00:00<?, ?it/s]
# transformer_inter_fusion val epoch 6/25:   0%|          | 0/1 [00:00<?, ?it/s]
# Epoch 006/25 | train_loss=1.5952 train_acc=55.66% train_bacc=36.27% train_auc=0.7374 train_f1=0.3667 | val_loss=1.5520 val_acc=54.35% val_bacc=40.93% val_auc=0.8039 val_f1=0.3598
# transformer_inter_fusion train epoch 7/25:   0%|          | 0/8 [00:00<?, ?it/s]
# transformer_inter_fusion val epoch 7/25:   0%|          | 0/1 [00:00<?, ?it/s]
# Epoch 007/25 | train_loss=1.5381 train_acc=56.20% train_bacc=40.06% train_auc=0.7762 train_f1=0.3803 | val_loss=1.4957 val_acc=58.26% val_bacc=42.43% val_auc=0.8279 val_f1=0.3696
# transformer_inter_fusion train epoch 8/25:   0%|          | 0/8 [00:00<?, ?it/s]
# transformer_inter_fusion val epoch 8/25:   0%|          | 0/1 [00:00<?, ?it/s]
# Epoch 008/25 | train_loss=1.4878 train_acc=59.47% train_bacc=39.75% train_auc=0.8033 train_f1=0.4000 | val_loss=1.4609 val_acc=57.83% val_bacc=46.32% val_auc=0.8261 val_f1=0.4183
# transformer_inter_fusion train epoch 9/25:   0%|          | 0/8 [00:00<?, ?it/s]
# transformer_inter_fusion val epoch 9/25:   0%|          | 0/1 [00:00<?, ?it/s]
# Epoch 009/25 | train_loss=1.4427 train_acc=60.94% train_bacc=43.68% train_auc=0.8085 train_f1=0.4389 | val_loss=1.3988 val_acc=60.00% val_bacc=45.06% val_auc=0.8544 val_f1=0.4043
# transformer_inter_fusion train epoch 10/25:   0%|          | 0/8 [00:00<?, ?it/s]
# transformer_inter_fusion val epoch 10/25:   0%|          | 0/1 [00:00<?, ?it/s]
# Epoch 010/25 | train_loss=1.4015 train_acc=62.73% train_bacc=44.93% train_auc=0.8224 train_f1=0.4547 | val_loss=1.3595 val_acc=60.00% val_bacc=50.91% val_auc=0.8521 val_f1=0.4354
# transformer_inter_fusion train epoch 11/25:   0%|          | 0/8 [00:00<?, ?it/s]
# transformer_inter_fusion val epoch 11/25:   0%|          | 0/1 [00:00<?, ?it/s]
# Epoch 011/25 | train_loss=1.3594 train_acc=63.00% train_bacc=45.62% train_auc=0.8312 train_f1=0.4533 | val_loss=1.3198 val_acc=61.30% val_bacc=53.11% val_auc=0.8637 val_f1=0.4588
# transformer_inter_fusion train epoch 12/25:   0%|          | 0/8 [00:00<?, ?it/s]
# transformer_inter_fusion val epoch 12/25:   0%|          | 0/1 [00:00<?, ?it/s]
# Epoch 012/25 | train_loss=1.3344 train_acc=62.19% train_bacc=45.63% train_auc=0.8337 train_f1=0.4440 | val_loss=1.2980 val_acc=60.43% val_bacc=47.92% val_auc=0.8626 val_f1=0.4319
# transformer_inter_fusion train epoch 13/25:   0%|          | 0/8 [00:00<?, ?it/s]
# transformer_inter_fusion val epoch 13/25:   0%|          | 0/1 [00:00<?, ?it/s]
# Epoch 013/25 | train_loss=1.3062 train_acc=63.98% train_bacc=47.75% train_auc=0.8395 train_f1=0.4836 | val_loss=1.2699 val_acc=64.35% val_bacc=51.43% val_auc=0.8752 val_f1=0.4701
# transformer_inter_fusion train epoch 14/25:   0%|          | 0/8 [00:00<?, ?it/s]
# transformer_inter_fusion val epoch 14/25:   0%|          | 0/1 [00:00<?, ?it/s]
# Epoch 014/25 | train_loss=1.2611 train_acc=63.98% train_bacc=48.21% train_auc=0.8564 train_f1=0.4824 | val_loss=1.2736 val_acc=61.30% val_bacc=47.00% val_auc=0.8797 val_f1=0.4232
# transformer_inter_fusion train epoch 15/25:   0%|          | 0/8 [00:00<?, ?it/s]
# transformer_inter_fusion val epoch 15/25:   0%|          | 0/1 [00:00<?, ?it/s]
# Epoch 015/25 | train_loss=1.2658 train_acc=64.20% train_bacc=48.24% train_auc=0.8481 train_f1=0.4764 | val_loss=1.2502 val_acc=62.17% val_bacc=53.12% val_auc=0.8787 val_f1=0.4660
# transformer_inter_fusion train epoch 16/25:   0%|          | 0/8 [00:00<?, ?it/s]
# transformer_inter_fusion val epoch 16/25:   0%|          | 0/1 [00:00<?, ?it/s]
# Epoch 016/25 | train_loss=1.2691 train_acc=63.71% train_bacc=47.62% train_auc=0.8418 train_f1=0.4806 | val_loss=1.2191 val_acc=63.04% val_bacc=51.68% val_auc=0.8909 val_f1=0.4778
# transformer_inter_fusion train epoch 17/25:   0%|          | 0/8 [00:00<?, ?it/s]
# transformer_inter_fusion val epoch 17/25:   0%|          | 0/1 [00:00<?, ?it/s]
# Epoch 017/25 | train_loss=1.2275 train_acc=64.25% train_bacc=49.55% train_auc=0.8634 train_f1=0.4796 | val_loss=1.2415 val_acc=62.17% val_bacc=40.81% val_auc=0.8871 val_f1=0.3857
# transformer_inter_fusion train epoch 18/25:   0%|          | 0/8 [00:00<?, ?it/s]
# transformer_inter_fusion val epoch 18/25:   0%|          | 0/1 [00:00<?, ?it/s]
# Epoch 018/25 | train_loss=1.2265 train_acc=66.54% train_bacc=49.99% train_auc=0.8634 train_f1=0.4893 | val_loss=1.1967 val_acc=64.78% val_bacc=56.16% val_auc=0.8920 val_f1=0.4992
# transformer_inter_fusion train epoch 19/25:   0%|          | 0/8 [00:00<?, ?it/s]
# transformer_inter_fusion val epoch 19/25:   0%|          | 0/1 [00:00<?, ?it/s]
# Epoch 019/25 | train_loss=1.2039 train_acc=64.04% train_bacc=49.73% train_auc=0.8737 train_f1=0.5023 | val_loss=1.1677 val_acc=66.96% val_bacc=55.94% val_auc=0.9004 val_f1=0.4988
# transformer_inter_fusion train epoch 20/25:   0%|          | 0/8 [00:00<?, ?it/s]
# transformer_inter_fusion val epoch 20/25:   0%|          | 0/1 [00:00<?, ?it/s]
# Epoch 020/25 | train_loss=1.1761 train_acc=67.90% train_bacc=54.76% train_auc=0.8847 train_f1=0.5525 | val_loss=1.1559 val_acc=65.22% val_bacc=55.02% val_auc=0.9049 val_f1=0.4929
# transformer_inter_fusion train epoch 21/25:   0%|          | 0/8 [00:00<?, ?it/s]
# transformer_inter_fusion val epoch 21/25:   0%|          | 0/1 [00:00<?, ?it/s]
# Epoch 021/25 | train_loss=1.1651 train_acc=67.85% train_bacc=53.68% train_auc=0.8845 train_f1=0.5317 | val_loss=1.1497 val_acc=67.83% val_bacc=60.46% val_auc=0.9076 val_f1=0.5290
# transformer_inter_fusion train epoch 22/25:   0%|          | 0/8 [00:00<?, ?it/s]
# transformer_inter_fusion val epoch 22/25:   0%|          | 0/1 [00:00<?, ?it/s]
# Epoch 022/25 | train_loss=1.1819 train_acc=66.81% train_bacc=53.38% train_auc=0.8778 train_f1=0.5326 | val_loss=1.1528 val_acc=67.39% val_bacc=53.56% val_auc=0.9079 val_f1=0.5051
# transformer_inter_fusion train epoch 23/25:   0%|          | 0/8 [00:00<?, ?it/s]
# transformer_inter_fusion val epoch 23/25:   0%|          | 0/1 [00:00<?, ?it/s]
# Epoch 023/25 | train_loss=1.1456 train_acc=68.88% train_bacc=56.66% train_auc=0.8894 train_f1=0.5625 | val_loss=1.1227 val_acc=70.87% val_bacc=53.98% val_auc=0.9149 val_f1=0.5151
# transformer_inter_fusion train epoch 24/25:   0%|          | 0/8 [00:00<?, ?it/s]
# transformer_inter_fusion val epoch 24/25:   0%|          | 0/1 [00:00<?, ?it/s]
# Epoch 024/25 | train_loss=1.1452 train_acc=70.13% train_bacc=53.37% train_auc=0.8923 train_f1=0.5451 | val_loss=1.1152 val_acc=67.39% val_bacc=55.80% val_auc=0.9153 val_f1=0.5202
# transformer_inter_fusion train epoch 25/25:   0%|          | 0/8 [00:00<?, ?it/s]
# transformer_inter_fusion val epoch 25/25:   0%|          | 0/1 [00:00<?, ?it/s]
# Epoch 025/25 | train_loss=1.1325 train_acc=69.64% train_bacc=56.09% train_auc=0.8970 train_f1=0.5620 | val_loss=1.0903 val_acc=71.30% val_bacc=61.43% val_auc=0.9218 val_f1=0.5566
# transformer_inter_fusion test:   0%|          | 0/1 [00:00<?, ?it/s]
# wandb: WARNING Saving files without folders. If you want to preserve subdirectories pass base_path to wandb.save, i.e. wandb.save("/mnt/folder/file.h5", base_path="/mnt")
# wandb: WARNING Symlinked 1 file into the W&B run directory; call wandb.save again to sync new files.
# wandb: WARNING Symlinked 1 file into the W&B run directory; call wandb.save again to sync new files.
# wandb: WARNING Symlinked 1 file into the W&B run directory; call wandb.save again to sync new files.
# wandb: WARNING Symlinked 1 file into the W&B run directory; call wandb.save again to sync new files.
# wandb: WARNING Symlinked 1 file into the W&B run directory; call wandb.save again to sync new files.
# wandb: updating run metadata
# wandb:
# wandb: Run history:
# wandb:                elapsed_sec ▁▁▂▂▂▂▃▃▃▄▄▄▅▅▅▅▆▆▆▇▇▇▇██
# wandb:                      epoch ▁▁▁▁▂▂▂▂▂▂▃▃▃▃▃▄▄▄▄▄▅▅▅▅▅▅▅▆▆▆▆▆▇▇▇▇▇▇██
# wandb: epochs_without_improvement ▁▁▁▁▁▁▁▁▃▁▁▃▁▃▆▁▃▁▃▆▁▃▆█▁
# wandb:                         lr ▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁
# wandb:                  train_acc ▁▃▄▅▅▆▆▆▇▇▇▇▇▇▇▇▇▇▇██████
# wandb:                  train_auc ▁▂▃▄▅▅▆▆▆▇▇▇▇▇▇▇▇▇███████
# wandb:                 train_bacc ▁▁▂▄▄▄▅▅▆▆▆▆▆▇▇▆▇▇▇█▇▇█▇█
# wandb:             train_f1_macro ▁▂▃▄▄▅▅▅▆▆▆▆▇▇▇▇▇▇▇██████
# wandb:                 train_loss █▇▆▆▅▅▅▄▄▃▃▃▃▂▂▂▂▂▂▁▁▁▁▁▁
# wandb:                    val_acc ▁▃▃▃▅▄▅▅▆▆▆▆▆▆▆▆▆▇▇▇▇▇█▇█
# wandb:                         +4 ...
# wandb:
# wandb: Run summary:
# wandb:                 best_epoch 25
# wandb:               best_val_acc 71.30435
# wandb:               best_val_auc 0.92182
# wandb:              best_val_bacc 61.42558
# wandb:          best_val_f1_macro 0.55661
# wandb:                elapsed_sec 147.34358
# wandb:                      epoch 25
# wandb: epochs_without_improvement 0
# wandb:                         lr 0.0005
# wandb:                   test_acc 72.6087
# wandb:                        +13 ...
# wandb:
# wandb: 🚀 View run transformer_inter_fusion at: https://wandb.ai/belalofficial123-the-british-university-in-egypt/iot%20fusion/runs/xo0ii6ou
# wandb: ⭐️ View project at: https://wandb.ai/belalofficial123-the-british-university-in-egypt/iot%20fusion
# wandb: Synced 5 W&B file(s), 4 media file(s), 0 artifact file(s) and 5 other file(s)
# wandb: Find logs at: ./wandb/run-20260416_192957-xo0ii6ou/logs
# Test performance:
# test_loss=1.0408 test_acc=72.61% test_bacc=62.20% test_auc=0.9282 test_f1=0.5719
# Classification report:
#               precision    recall  f1-score     support
# ACK            0.838710  0.712329  0.770370   73.000000
# BCC            0.710280  0.894118  0.791667   85.000000
# MEL            0.250000  0.600000  0.352941    5.000000
# NEV            0.846154  0.916667  0.880000   24.000000
# SCC            0.000000  0.000000  0.000000   20.000000
# SEK            0.666667  0.608696  0.636364   23.000000
# accuracy       0.726087  0.726087  0.726087    0.726087
# macro avg      0.551968  0.621968  0.571890  230.000000
# weighted avg   0.689090  0.726087  0.700216  230.000000
# transformer_inter_fusion complete: best_epoch=25, test_acc=72.61%
# {'experiment_name': 'transformer_inter_fusion',
#  'model_name': 'transformer',
#  'input_mode': 'intermediate_fusion',
#  'epochs': 25,
#  'batch_size': 256,
#  'split': '80 train / 10 validation / 10 test',
#  'augment_train': True,
#  'class_weighted_loss': True,
#  'class_weight_power': 0.5,
#  'class_balanced_sampler': False,
#  'best_epoch': 25,
#  'best_val_acc': 71.30434782608695,
#  'best_val_bacc': 61.42558164818438,
#  'best_val_auc': 0.9218163949919376,
#  'best_val_f1_macro': 0.5566123979196756,
#  'final_train_loss': 1.1325093838543316,
#  'final_train_acc': 69.64091403699673,
#  'final_train_bacc': 56.08575526610584,
#  'final_train_auc': 0.8970285688568868,
#  'final_train_f1_macro': 0.5619602521205425,
#  'final_val_loss': 1.0902652740478516,
#  'final_val_acc': 71.30434782608695,
#  'final_val_bacc': 61.42558164818438,
#  'final_val_auc': 0.9218163949919376,
#  'final_val_f1_macro': 0.5566123979196756,
#  'test_loss': 1.04076087474823,
#  'test_acc': 72.60869565217392,
#  'test_bacc': 62.19681221704485,
#  'test_auc': 0.9282264003176887,
#  'test_f1_macro': 0.571890308311877,
#  'elapsed_sec': 147.3435823917389,
#  'metrics_path': '/home/zeus/content/IOT_fusion/Results_Logs/transformer_inter_fusion/epoch_metrics.csv',
#  'epoch_log_path': '/home/zeus/content/IOT_fusion/Results_Logs/transformer_inter_fusion/epoch_log.txt',
#  'split_summary_path': '/home/zeus/content/IOT_fusion/Results_Logs/transformer_inter_fusion/split_summary.csv',
#  'checkpoint_path': '/home/zeus/content/IOT_fusion/outputs/ablations/transformer_inter_fusion_best.pth',
#  'classification_report_path': '/home/zeus/content/IOT_fusion/Results_Logs/transformer_inter_fusion/classification_report.csv',
#  'confusion_matrix_path': '/home/zeus/content/IOT_fusion/Results_Logs/transformer_inter_fusion/confusion_matrix.csv',
#  'test_predictions_path': '/home/zeus/content/IOT_fusion/Results_Logs/transformer_inter_fusion/test_predictions.csv',
#  'loss_curve_path': '/home/zeus/content/IOT_fusion/Results_Figures/transformer_inter_fusion/loss_curve.png',
#  'epoch_metrics_curve_path': '/home/zeus/content/IOT_fusion/Results_Figures/transformer_inter_fusion/epoch_metrics.png',
#  'confusion_matrix_plot_path': '/home/zeus/content/IOT_fusion/Results_Figures/transformer_inter_fusion/confusion_matrix.png',
#  'roc_curve_path': '/home/zeus/content/IOT_fusion/Results_Figures/transformer_inter_fusion/roc_curve.png',
#  'xai_paths': "{'image_saliency': '/home/zeus/content/IOT_fusion/Results_XAI/transformer_inter_fusion/transformer_inter_fusion_image_saliency.npy', 'metadata_importance': '/home/zeus/content/IOT_fusion/Results_XAI/transformer_inter_fusion/transformer_inter_fusion_metadata_xai_top20.csv'}"}

# %% [markdown]
# ## Training Outputs

# %%
from pathlib import Path
output_dir = Path('outputs/ablations')
logs_dir = Path('Results_Logs') / 'transformer_inter_fusion'
figures_dir = Path('Results_Figures') / 'transformer_inter_fusion'
xai_dir = Path('Results_XAI') / 'transformer_inter_fusion'
print('metrics:', logs_dir / 'epoch_metrics.csv')
print('epoch log:', logs_dir / 'epoch_log.txt')
print('result:', logs_dir / 'result_summary.csv')
print('checkpoint:', output_dir / 'transformer_inter_fusion_best.pth')
print('classification report:', logs_dir / 'classification_report.csv')
print('confusion matrix CSV:', logs_dir / 'confusion_matrix.csv')
print('loss curve:', figures_dir / 'loss_curve.png')
print('roc curve:', figures_dir / 'roc_curve.png')
sorted(str(p) for p in list(logs_dir.glob('*')) + list(figures_dir.glob('*')) + list(xai_dir.glob('*')))
# Out:
# metrics: Results_Logs/transformer_inter_fusion/epoch_metrics.csv
# epoch log: Results_Logs/transformer_inter_fusion/epoch_log.txt
# result: Results_Logs/transformer_inter_fusion/result_summary.csv
# checkpoint: outputs/ablations/transformer_inter_fusion_best.pth
# classification report: Results_Logs/transformer_inter_fusion/classification_report.csv
# confusion matrix CSV: Results_Logs/transformer_inter_fusion/confusion_matrix.csv
# loss curve: Results_Figures/transformer_inter_fusion/loss_curve.png
# roc curve: Results_Figures/transformer_inter_fusion/roc_curve.png
# ['Results_Figures/transformer_inter_fusion/confusion_matrix.png',
#  'Results_Figures/transformer_inter_fusion/epoch_metrics.png',
#  'Results_Figures/transformer_inter_fusion/loss_curve.png',
#  'Results_Figures/transformer_inter_fusion/roc_curve.png',
#  'Results_Logs/transformer_inter_fusion/classification_report.csv',
#  'Results_Logs/transformer_inter_fusion/confusion_matrix.csv',
#  'Results_Logs/transformer_inter_fusion/epoch_log.txt',
#  'Results_Logs/transformer_inter_fusion/epoch_metrics.csv',
#  'Results_Logs/transformer_inter_fusion/result_summary.csv',
#  'Results_Logs/transformer_inter_fusion/split_summary.csv',
#  'Results_Logs/transformer_inter_fusion/test_predictions.csv',
#  'Results_XAI/transformer_inter_fusion/transformer_inter_fusion_image_saliency.npy',
#  'Results_XAI/transformer_inter_fusion/transformer_inter_fusion_metadata_xai_top20.csv']
