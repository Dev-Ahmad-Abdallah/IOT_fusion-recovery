# %% [markdown]
# # CNN Images Only Ablation
#
# Experiment: `cnn_img_only`
#
# This notebook runs full GPU training on a stratified 80/10/10 train/validation/test split built from the extracted processed tabular data and image tensors. Image runs use tensor-safe train augmentation and class-weighted loss. CNN runs use tempered class-weighted loss, stronger paper-style augmentation, and early stopping to reduce overfitting; balanced sampling can be enabled manually, but is off by default because it over-corrected on this dataset. Fusion modes combine the tabular metadata vector with the image tensor. It prints per-epoch train/validation loss, accuracy, macro AUC, and macro F1 with tqdm progress bars. Epoch logs are written under `Results_Logs/<experiment>/`, figures under `Results_Figures/<experiment>/`, and XAI artifacts under `Results_XAI/<experiment>/`.

# %%
from pathlib import Path
import os, sys
REPO_ROOT = Path('/home/zeus/content/IOT_fusion')
os.chdir(REPO_ROOT)
sys.path.insert(0, str(REPO_ROOT / 'training'))
from ablation_utils import get_data_info, run_training

info = get_data_info()
print('classes:', info.class_to_idx)
print('metadata_dim:', info.metadata_dim)
# Out:
# classes: {'ACK': 0, 'BCC': 1, 'MEL': 2, 'NEV': 3, 'SCC': 4, 'SEK': 5}
# metadata_dim: 87

# %% [markdown]
# ## Full GPU Training
# Adjust `epochs` and `batch_size` if needed.

# %%
full_result = run_training(
    model_name='cnn',
    input_mode='images_only',
    experiment_name='cnn_img_only',
    epochs=60,
    batch_size=64,
    lr=0.0003,
    num_workers=2,
    device_name='cuda',
    wandb_enabled=True,
    xai_enabled=True,
    augment_train=True,
    class_weighted_loss=True,
    class_weight_power=0.5,
    class_balanced_sampler=False,
    early_stopping_patience=12,
    min_epochs=15,
)
full_result
# Out:
# wandb: [wandb.login()] Loaded credentials for https://api.wandb.ai from WANDB_API_KEY.
# wandb: Currently logged in as: belalofficial123 (belalofficial123-the-british-university-in-egypt) to https://api.wandb.ai. Use `wandb login --relogin` to force relogin
# wandb: Tracking run with wandb version 0.26.0
# wandb: Run data is saved locally in /home/zeus/content/IOT_fusion/wandb/run-20260416_190706-9btdhuh3
# wandb: Run `wandb offline` to turn off syncing.
# wandb: Syncing run cnn_img_only
# wandb: ⭐️ View project at https://wandb.ai/belalofficial123-the-british-university-in-egypt/iot%20fusion
# wandb: 🚀 View run at https://wandb.ai/belalofficial123-the-british-university-in-egypt/iot%20fusion/runs/9btdhuh3
# Split sizes: {'train': 1838, 'val': 230, 'test': 230}
# Class mapping: {'ACK': 0, 'BCC': 1, 'MEL': 2, 'NEV': 3, 'SCC': 4, 'SEK': 5}
# cnn_img_only train epoch 1/60:   0%|          | 0/29 [00:00<?, ?it/s]
# cnn_img_only val epoch 1/60:   0%|          | 0/4 [00:00<?, ?it/s]
# Epoch 001/60 | train_loss=2.1171 train_acc=24.76% train_bacc=18.25% train_auc=0.5017 train_f1=0.1747 | val_loss=1.7905 val_acc=32.17% val_bacc=16.87% val_auc=0.5129 val_f1=0.0852
# cnn_img_only train epoch 2/60:   0%|          | 0/29 [00:00<?, ?it/s]
# cnn_img_only val epoch 2/60:   0%|          | 0/4 [00:00<?, ?it/s]
# Epoch 002/60 | train_loss=1.9266 train_acc=29.65% train_bacc=18.47% train_auc=0.5478 train_f1=0.1840 | val_loss=1.7388 val_acc=29.57% val_bacc=24.49% val_auc=0.6003 val_f1=0.1969
# cnn_img_only train epoch 3/60:   0%|          | 0/29 [00:00<?, ?it/s]
# cnn_img_only val epoch 3/60:   0%|          | 0/4 [00:00<?, ?it/s]
# Epoch 003/60 | train_loss=1.8713 train_acc=29.82% train_bacc=20.78% train_auc=0.5601 train_f1=0.2052 | val_loss=1.8038 val_acc=34.35% val_bacc=27.63% val_auc=0.6088 val_f1=0.1802
# cnn_img_only train epoch 4/60:   0%|          | 0/29 [00:00<?, ?it/s]
# cnn_img_only val epoch 4/60:   0%|          | 0/4 [00:00<?, ?it/s]
# Epoch 004/60 | train_loss=1.8767 train_acc=30.30% train_bacc=21.10% train_auc=0.5618 train_f1=0.2052 | val_loss=1.8176 val_acc=29.13% val_bacc=16.33% val_auc=0.5792 val_f1=0.1186
# cnn_img_only train epoch 5/60:   0%|          | 0/29 [00:00<?, ?it/s]
# cnn_img_only val epoch 5/60:   0%|          | 0/4 [00:00<?, ?it/s]
# Epoch 005/60 | train_loss=1.8614 train_acc=30.03% train_bacc=20.81% train_auc=0.5550 train_f1=0.2038 | val_loss=1.8122 val_acc=36.96% val_bacc=21.85% val_auc=0.6115 val_f1=0.2021
# cnn_img_only train epoch 6/60:   0%|          | 0/29 [00:00<?, ?it/s]
# cnn_img_only val epoch 6/60:   0%|          | 0/4 [00:00<?, ?it/s]
# Epoch 006/60 | train_loss=1.8613 train_acc=32.43% train_bacc=20.10% train_auc=0.5649 train_f1=0.1959 | val_loss=1.6957 val_acc=39.13% val_bacc=27.61% val_auc=0.6674 val_f1=0.2239
# cnn_img_only train epoch 7/60:   0%|          | 0/29 [00:00<?, ?it/s]
# cnn_img_only val epoch 7/60:   0%|          | 0/4 [00:00<?, ?it/s]
# Epoch 007/60 | train_loss=1.8018 train_acc=31.88% train_bacc=20.56% train_auc=0.5801 train_f1=0.2046 | val_loss=1.7211 val_acc=40.00% val_bacc=34.72% val_auc=0.6555 val_f1=0.2660
# cnn_img_only train epoch 8/60:   0%|          | 0/29 [00:00<?, ?it/s]
# cnn_img_only val epoch 8/60:   0%|          | 0/4 [00:00<?, ?it/s]
# Epoch 008/60 | train_loss=1.7783 train_acc=33.90% train_bacc=23.47% train_auc=0.6060 train_f1=0.2325 | val_loss=1.7090 val_acc=35.65% val_bacc=21.29% val_auc=0.6482 val_f1=0.2034
# cnn_img_only train epoch 9/60:   0%|          | 0/29 [00:00<?, ?it/s]
# cnn_img_only val epoch 9/60:   0%|          | 0/4 [00:00<?, ?it/s]
# Epoch 009/60 | train_loss=1.7726 train_acc=34.87% train_bacc=25.23% train_auc=0.6073 train_f1=0.2424 | val_loss=1.6992 val_acc=38.26% val_bacc=23.29% val_auc=0.6666 val_f1=0.2006
# cnn_img_only train epoch 10/60:   0%|          | 0/29 [00:00<?, ?it/s]
# cnn_img_only val epoch 10/60:   0%|          | 0/4 [00:00<?, ?it/s]
# Epoch 010/60 | train_loss=1.7660 train_acc=35.75% train_bacc=23.99% train_auc=0.6043 train_f1=0.2383 | val_loss=1.7395 val_acc=36.52% val_bacc=24.20% val_auc=0.6287 val_f1=0.2086
# cnn_img_only train epoch 11/60:   0%|          | 0/29 [00:00<?, ?it/s]
# cnn_img_only val epoch 11/60:   0%|          | 0/4 [00:00<?, ?it/s]
# Epoch 011/60 | train_loss=1.7493 train_acc=35.96% train_bacc=24.26% train_auc=0.6111 train_f1=0.2354 | val_loss=1.6300 val_acc=40.00% val_bacc=30.96% val_auc=0.6932 val_f1=0.2768
# cnn_img_only train epoch 12/60:   0%|          | 0/29 [00:00<?, ?it/s]
# cnn_img_only val epoch 12/60:   0%|          | 0/4 [00:00<?, ?it/s]
# Epoch 012/60 | train_loss=1.7383 train_acc=35.75% train_bacc=26.09% train_auc=0.6113 train_f1=0.2624 | val_loss=1.6588 val_acc=40.43% val_bacc=30.91% val_auc=0.6923 val_f1=0.2783
# cnn_img_only train epoch 13/60:   0%|          | 0/29 [00:00<?, ?it/s]
# cnn_img_only val epoch 13/60:   0%|          | 0/4 [00:00<?, ?it/s]
# Epoch 013/60 | train_loss=1.7164 train_acc=36.62% train_bacc=25.52% train_auc=0.6329 train_f1=0.2489 | val_loss=1.6456 val_acc=40.87% val_bacc=23.98% val_auc=0.7004 val_f1=0.2112
# cnn_img_only train epoch 14/60:   0%|          | 0/29 [00:00<?, ?it/s]
# cnn_img_only val epoch 14/60:   0%|          | 0/4 [00:00<?, ?it/s]
# Epoch 014/60 | train_loss=1.7185 train_acc=36.56% train_bacc=25.04% train_auc=0.6439 train_f1=0.2495 | val_loss=1.6624 val_acc=44.78% val_bacc=28.99% val_auc=0.6898 val_f1=0.2748
# cnn_img_only train epoch 15/60:   0%|          | 0/29 [00:00<?, ?it/s]
# cnn_img_only val epoch 15/60:   0%|          | 0/4 [00:00<?, ?it/s]
# Epoch 015/60 | train_loss=1.6976 train_acc=40.59% train_bacc=29.63% train_auc=0.6389 train_f1=0.2935 | val_loss=1.6417 val_acc=40.00% val_bacc=30.68% val_auc=0.6952 val_f1=0.3062
# cnn_img_only train epoch 16/60:   0%|          | 0/29 [00:00<?, ?it/s]
# cnn_img_only val epoch 16/60:   0%|          | 0/4 [00:00<?, ?it/s]
# Epoch 016/60 | train_loss=1.7188 train_acc=37.60% train_bacc=26.24% train_auc=0.6166 train_f1=0.2619 | val_loss=1.6064 val_acc=45.22% val_bacc=28.86% val_auc=0.7091 val_f1=0.2806
# cnn_img_only train epoch 17/60:   0%|          | 0/29 [00:00<?, ?it/s]
# cnn_img_only val epoch 17/60:   0%|          | 0/4 [00:00<?, ?it/s]
# Epoch 017/60 | train_loss=1.6787 train_acc=39.50% train_bacc=28.82% train_auc=0.6458 train_f1=0.2851 | val_loss=1.6412 val_acc=38.26% val_bacc=25.87% val_auc=0.6922 val_f1=0.2488
# cnn_img_only train epoch 18/60:   0%|          | 0/29 [00:00<?, ?it/s]
# cnn_img_only val epoch 18/60:   0%|          | 0/4 [00:00<?, ?it/s]
# Epoch 018/60 | train_loss=1.6626 train_acc=40.91% train_bacc=30.82% train_auc=0.6589 train_f1=0.2996 | val_loss=1.6155 val_acc=45.22% val_bacc=28.42% val_auc=0.7167 val_f1=0.2707
# cnn_img_only train epoch 19/60:   0%|          | 0/29 [00:00<?, ?it/s]
# cnn_img_only val epoch 19/60:   0%|          | 0/4 [00:00<?, ?it/s]
# Epoch 019/60 | train_loss=1.6531 train_acc=41.73% train_bacc=30.94% train_auc=0.6722 train_f1=0.2951 | val_loss=1.6264 val_acc=43.91% val_bacc=32.11% val_auc=0.6822 val_f1=0.3076
# cnn_img_only train epoch 20/60:   0%|          | 0/29 [00:00<?, ?it/s]
# cnn_img_only val epoch 20/60:   0%|          | 0/4 [00:00<?, ?it/s]
# Epoch 020/60 | train_loss=1.6495 train_acc=40.64% train_bacc=28.16% train_auc=0.6737 train_f1=0.2801 | val_loss=1.5910 val_acc=49.13% val_bacc=43.74% val_auc=0.7061 val_f1=0.3717
# cnn_img_only train epoch 21/60:   0%|          | 0/29 [00:00<?, ?it/s]
# cnn_img_only val epoch 21/60:   0%|          | 0/4 [00:00<?, ?it/s]
# Epoch 021/60 | train_loss=1.6238 train_acc=42.27% train_bacc=32.19% train_auc=0.6877 train_f1=0.3124 | val_loss=1.6521 val_acc=40.00% val_bacc=31.29% val_auc=0.6928 val_f1=0.2724
# cnn_img_only train epoch 22/60:   0%|          | 0/29 [00:00<?, ?it/s]
# cnn_img_only val epoch 22/60:   0%|          | 0/4 [00:00<?, ?it/s]
# Epoch 022/60 | train_loss=1.6487 train_acc=41.51% train_bacc=30.64% train_auc=0.6760 train_f1=0.3038 | val_loss=1.6424 val_acc=44.35% val_bacc=34.82% val_auc=0.6827 val_f1=0.2991
# cnn_img_only train epoch 23/60:   0%|          | 0/29 [00:00<?, ?it/s]
# cnn_img_only val epoch 23/60:   0%|          | 0/4 [00:00<?, ?it/s]
# Epoch 023/60 | train_loss=1.6184 train_acc=42.55% train_bacc=31.67% train_auc=0.6871 train_f1=0.3129 | val_loss=1.6749 val_acc=43.48% val_bacc=25.87% val_auc=0.6516 val_f1=0.2491
# cnn_img_only train epoch 24/60:   0%|          | 0/29 [00:00<?, ?it/s]
# cnn_img_only val epoch 24/60:   0%|          | 0/4 [00:00<?, ?it/s]
# Epoch 024/60 | train_loss=1.6251 train_acc=40.81% train_bacc=31.97% train_auc=0.6869 train_f1=0.3174 | val_loss=1.6021 val_acc=47.39% val_bacc=35.12% val_auc=0.7099 val_f1=0.3380
# cnn_img_only train epoch 25/60:   0%|          | 0/29 [00:00<?, ?it/s]
# cnn_img_only val epoch 25/60:   0%|          | 0/4 [00:00<?, ?it/s]
# Epoch 025/60 | train_loss=1.6023 train_acc=43.25% train_bacc=32.66% train_auc=0.6929 train_f1=0.3317 | val_loss=1.6224 val_acc=44.78% val_bacc=35.23% val_auc=0.6765 val_f1=0.3457
# cnn_img_only train epoch 26/60:   0%|          | 0/29 [00:00<?, ?it/s]
# cnn_img_only val epoch 26/60:   0%|          | 0/4 [00:00<?, ?it/s]
# Epoch 026/60 | train_loss=1.6095 train_acc=44.40% train_bacc=32.35% train_auc=0.7062 train_f1=0.3211 | val_loss=1.5808 val_acc=40.87% val_bacc=32.57% val_auc=0.7184 val_f1=0.3222
# cnn_img_only train epoch 27/60:   0%|          | 0/29 [00:00<?, ?it/s]
# cnn_img_only val epoch 27/60:   0%|          | 0/4 [00:00<?, ?it/s]
# Epoch 027/60 | train_loss=1.5932 train_acc=44.56% train_bacc=31.66% train_auc=0.7078 train_f1=0.3189 | val_loss=1.5767 val_acc=46.96% val_bacc=38.58% val_auc=0.7129 val_f1=0.3694
# cnn_img_only train epoch 28/60:   0%|          | 0/29 [00:00<?, ?it/s]
# cnn_img_only val epoch 28/60:   0%|          | 0/4 [00:00<?, ?it/s]
# Epoch 028/60 | train_loss=1.5305 train_acc=47.50% train_bacc=36.89% train_auc=0.7382 train_f1=0.3766 | val_loss=1.5853 val_acc=48.26% val_bacc=36.19% val_auc=0.7188 val_f1=0.3408
# cnn_img_only train epoch 29/60:   0%|          | 0/29 [00:00<?, ?it/s]
# cnn_img_only val epoch 29/60:   0%|          | 0/4 [00:00<?, ?it/s]
# Epoch 029/60 | train_loss=1.5353 train_acc=46.68% train_bacc=35.44% train_auc=0.7390 train_f1=0.3595 | val_loss=1.5545 val_acc=46.96% val_bacc=39.46% val_auc=0.7205 val_f1=0.3731
# cnn_img_only train epoch 30/60:   0%|          | 0/29 [00:00<?, ?it/s]
# cnn_img_only val epoch 30/60:   0%|          | 0/4 [00:00<?, ?it/s]
# Epoch 030/60 | train_loss=1.5405 train_acc=46.68% train_bacc=35.06% train_auc=0.7314 train_f1=0.3542 | val_loss=1.5526 val_acc=46.96% val_bacc=35.09% val_auc=0.7196 val_f1=0.3277
# cnn_img_only train epoch 31/60:   0%|          | 0/29 [00:00<?, ?it/s]
# cnn_img_only val epoch 31/60:   0%|          | 0/4 [00:00<?, ?it/s]
# Epoch 031/60 | train_loss=1.4992 train_acc=48.91% train_bacc=37.41% train_auc=0.7537 train_f1=0.3748 | val_loss=1.5901 val_acc=43.91% val_bacc=37.39% val_auc=0.7152 val_f1=0.3432
# cnn_img_only train epoch 32/60:   0%|          | 0/29 [00:00<?, ?it/s]
# cnn_img_only val epoch 32/60:   0%|          | 0/4 [00:00<?, ?it/s]
# Epoch 032/60 | train_loss=1.5057 train_acc=47.93% train_bacc=37.01% train_auc=0.7475 train_f1=0.3658 | val_loss=1.5823 val_acc=43.48% val_bacc=37.76% val_auc=0.7293 val_f1=0.3584
# cnn_img_only train epoch 33/60:   0%|          | 0/29 [00:00<?, ?it/s]
# cnn_img_only val epoch 33/60:   0%|          | 0/4 [00:00<?, ?it/s]
# Epoch 033/60 | train_loss=1.4923 train_acc=49.08% train_bacc=38.55% train_auc=0.7573 train_f1=0.3944 | val_loss=1.5830 val_acc=44.78% val_bacc=36.92% val_auc=0.7230 val_f1=0.3413
# cnn_img_only train epoch 34/60:   0%|          | 0/29 [00:00<?, ?it/s]
# cnn_img_only val epoch 34/60:   0%|          | 0/4 [00:00<?, ?it/s]
# Epoch 034/60 | train_loss=1.5183 train_acc=47.50% train_bacc=37.23% train_auc=0.7519 train_f1=0.3573 | val_loss=1.5476 val_acc=47.83% val_bacc=35.11% val_auc=0.7466 val_f1=0.3341
# cnn_img_only train epoch 35/60:   0%|          | 0/29 [00:00<?, ?it/s]
# cnn_img_only val epoch 35/60:   0%|          | 0/4 [00:00<?, ?it/s]
# Epoch 035/60 | train_loss=1.4979 train_acc=48.53% train_bacc=38.43% train_auc=0.7602 train_f1=0.3830 | val_loss=1.5586 val_acc=46.96% val_bacc=36.17% val_auc=0.7550 val_f1=0.3441
# cnn_img_only train epoch 36/60:   0%|          | 0/29 [00:00<?, ?it/s]
# cnn_img_only val epoch 36/60:   0%|          | 0/4 [00:00<?, ?it/s]
# Epoch 036/60 | train_loss=1.4677 train_acc=47.99% train_bacc=39.82% train_auc=0.7708 train_f1=0.3861 | val_loss=1.5587 val_acc=49.57% val_bacc=38.98% val_auc=0.7400 val_f1=0.3764
# cnn_img_only train epoch 37/60:   0%|          | 0/29 [00:00<?, ?it/s]
# cnn_img_only val epoch 37/60:   0%|          | 0/4 [00:00<?, ?it/s]
# Epoch 037/60 | train_loss=1.4509 train_acc=49.51% train_bacc=43.11% train_auc=0.7740 train_f1=0.4248 | val_loss=1.5705 val_acc=49.13% val_bacc=39.83% val_auc=0.7265 val_f1=0.3768
# cnn_img_only train epoch 38/60:   0%|          | 0/29 [00:00<?, ?it/s]
# cnn_img_only val epoch 38/60:   0%|          | 0/4 [00:00<?, ?it/s]
# Epoch 038/60 | train_loss=1.4616 train_acc=51.36% train_bacc=42.11% train_auc=0.7677 train_f1=0.4162 | val_loss=1.5090 val_acc=51.30% val_bacc=41.26% val_auc=0.7582 val_f1=0.3938
# cnn_img_only train epoch 39/60:   0%|          | 0/29 [00:00<?, ?it/s]
# cnn_img_only val epoch 39/60:   0%|          | 0/4 [00:00<?, ?it/s]
# Epoch 039/60 | train_loss=1.4596 train_acc=50.33% train_bacc=40.82% train_auc=0.7747 train_f1=0.4157 | val_loss=1.5367 val_acc=46.09% val_bacc=38.70% val_auc=0.7479 val_f1=0.3601
# cnn_img_only train epoch 40/60:   0%|          | 0/29 [00:00<?, ?it/s]
# cnn_img_only val epoch 40/60:   0%|          | 0/4 [00:00<?, ?it/s]
# Epoch 040/60 | train_loss=1.4040 train_acc=51.90% train_bacc=45.01% train_auc=0.7978 train_f1=0.4559 | val_loss=1.5286 val_acc=50.43% val_bacc=41.80% val_auc=0.7540 val_f1=0.3973
# cnn_img_only train epoch 41/60:   0%|          | 0/29 [00:00<?, ?it/s]
# cnn_img_only val epoch 41/60:   0%|          | 0/4 [00:00<?, ?it/s]
# Epoch 041/60 | train_loss=1.4310 train_acc=50.33% train_bacc=43.44% train_auc=0.7836 train_f1=0.4292 | val_loss=1.5566 val_acc=48.70% val_bacc=42.12% val_auc=0.7343 val_f1=0.4103
# cnn_img_only train epoch 42/60:   0%|          | 0/29 [00:00<?, ?it/s]
# cnn_img_only val epoch 42/60:   0%|          | 0/4 [00:00<?, ?it/s]
# Epoch 042/60 | train_loss=1.4333 train_acc=52.01% train_bacc=43.04% train_auc=0.7890 train_f1=0.4258 | val_loss=1.5156 val_acc=46.96% val_bacc=39.90% val_auc=0.7633 val_f1=0.3912
# cnn_img_only train epoch 43/60:   0%|          | 0/29 [00:00<?, ?it/s]
# cnn_img_only val epoch 43/60:   0%|          | 0/4 [00:00<?, ?it/s]
# Epoch 043/60 | train_loss=1.4423 train_acc=49.29% train_bacc=41.17% train_auc=0.7815 train_f1=0.4192 | val_loss=1.4969 val_acc=47.83% val_bacc=42.51% val_auc=0.7686 val_f1=0.3967
# cnn_img_only train epoch 44/60:   0%|          | 0/29 [00:00<?, ?it/s]
# cnn_img_only val epoch 44/60:   0%|          | 0/4 [00:00<?, ?it/s]
# Epoch 044/60 | train_loss=1.4294 train_acc=50.87% train_bacc=42.04% train_auc=0.7885 train_f1=0.4287 | val_loss=1.5172 val_acc=48.26% val_bacc=40.38% val_auc=0.7677 val_f1=0.3807
# cnn_img_only train epoch 45/60:   0%|          | 0/29 [00:00<?, ?it/s]
# cnn_img_only val epoch 45/60:   0%|          | 0/4 [00:00<?, ?it/s]
# Epoch 045/60 | train_loss=1.4388 train_acc=52.56% train_bacc=41.91% train_auc=0.7889 train_f1=0.4242 | val_loss=1.5144 val_acc=49.13% val_bacc=41.83% val_auc=0.7705 val_f1=0.4098
# cnn_img_only train epoch 46/60:   0%|          | 0/29 [00:00<?, ?it/s]
# cnn_img_only val epoch 46/60:   0%|          | 0/4 [00:00<?, ?it/s]
# Epoch 046/60 | train_loss=1.3900 train_acc=53.16% train_bacc=45.93% train_auc=0.8094 train_f1=0.4455 | val_loss=1.4969 val_acc=48.26% val_bacc=45.61% val_auc=0.7688 val_f1=0.4247
# cnn_img_only train epoch 47/60:   0%|          | 0/29 [00:00<?, ?it/s]
# cnn_img_only val epoch 47/60:   0%|          | 0/4 [00:00<?, ?it/s]
# Epoch 047/60 | train_loss=1.4074 train_acc=52.50% train_bacc=44.03% train_auc=0.8014 train_f1=0.4447 | val_loss=1.5569 val_acc=50.43% val_bacc=42.66% val_auc=0.7450 val_f1=0.4088
# cnn_img_only train epoch 48/60:   0%|          | 0/29 [00:00<?, ?it/s]
# cnn_img_only val epoch 48/60:   0%|          | 0/4 [00:00<?, ?it/s]
# Epoch 048/60 | train_loss=1.3990 train_acc=51.52% train_bacc=43.65% train_auc=0.8003 train_f1=0.4414 | val_loss=1.5612 val_acc=46.52% val_bacc=40.82% val_auc=0.7498 val_f1=0.3843
# cnn_img_only train epoch 49/60:   0%|          | 0/29 [00:00<?, ?it/s]
# cnn_img_only val epoch 49/60:   0%|          | 0/4 [00:00<?, ?it/s]
# Epoch 049/60 | train_loss=1.3921 train_acc=53.65% train_bacc=46.13% train_auc=0.8074 train_f1=0.4572 | val_loss=1.5470 val_acc=46.96% val_bacc=41.67% val_auc=0.7627 val_f1=0.4027
# cnn_img_only train epoch 50/60:   0%|          | 0/29 [00:00<?, ?it/s]
# cnn_img_only val epoch 50/60:   0%|          | 0/4 [00:00<?, ?it/s]
# Epoch 050/60 | train_loss=1.3807 train_acc=54.13% train_bacc=46.26% train_auc=0.8087 train_f1=0.4582 | val_loss=1.5613 val_acc=50.87% val_bacc=44.67% val_auc=0.7488 val_f1=0.4182
# cnn_img_only train epoch 51/60:   0%|          | 0/29 [00:00<?, ?it/s]
# cnn_img_only val epoch 51/60:   0%|          | 0/4 [00:00<?, ?it/s]
# Epoch 051/60 | train_loss=1.3820 train_acc=54.13% train_bacc=47.84% train_auc=0.8100 train_f1=0.4827 | val_loss=1.5392 val_acc=46.96% val_bacc=41.48% val_auc=0.7633 val_f1=0.3947
# cnn_img_only train epoch 52/60:   0%|          | 0/29 [00:00<?, ?it/s]
# cnn_img_only val epoch 52/60:   0%|          | 0/4 [00:00<?, ?it/s]
# Epoch 052/60 | train_loss=1.4016 train_acc=53.16% train_bacc=44.60% train_auc=0.8073 train_f1=0.4429 | val_loss=1.5279 val_acc=49.57% val_bacc=43.57% val_auc=0.7664 val_f1=0.4289
# cnn_img_only train epoch 53/60:   0%|          | 0/29 [00:00<?, ?it/s]
# cnn_img_only val epoch 53/60:   0%|          | 0/4 [00:00<?, ?it/s]
# Epoch 053/60 | train_loss=1.3969 train_acc=51.85% train_bacc=44.29% train_auc=0.8020 train_f1=0.4489 | val_loss=1.5654 val_acc=47.83% val_bacc=41.32% val_auc=0.7511 val_f1=0.3925
# cnn_img_only train epoch 54/60:   0%|          | 0/29 [00:00<?, ?it/s]
# cnn_img_only val epoch 54/60:   0%|          | 0/4 [00:00<?, ?it/s]
# Epoch 054/60 | train_loss=1.3633 train_acc=53.65% train_bacc=47.75% train_auc=0.8185 train_f1=0.4731 | val_loss=1.5554 val_acc=45.65% val_bacc=44.02% val_auc=0.7516 val_f1=0.3923
# cnn_img_only train epoch 55/60:   0%|          | 0/29 [00:00<?, ?it/s]
# cnn_img_only val epoch 55/60:   0%|          | 0/4 [00:00<?, ?it/s]
# Epoch 055/60 | train_loss=1.3902 train_acc=54.30% train_bacc=45.63% train_auc=0.8048 train_f1=0.4619 | val_loss=1.5471 val_acc=47.39% val_bacc=41.87% val_auc=0.7528 val_f1=0.4175
# cnn_img_only train epoch 56/60:   0%|          | 0/29 [00:00<?, ?it/s]
# cnn_img_only val epoch 56/60:   0%|          | 0/4 [00:00<?, ?it/s]
# Epoch 056/60 | train_loss=1.3698 train_acc=52.56% train_bacc=46.19% train_auc=0.8135 train_f1=0.4741 | val_loss=1.5509 val_acc=49.13% val_bacc=41.77% val_auc=0.7630 val_f1=0.3865
# cnn_img_only train epoch 57/60:   0%|          | 0/29 [00:00<?, ?it/s]
# cnn_img_only val epoch 57/60:   0%|          | 0/4 [00:00<?, ?it/s]
# Epoch 057/60 | train_loss=1.3635 train_acc=54.62% train_bacc=47.53% train_auc=0.8144 train_f1=0.4798 | val_loss=1.5150 val_acc=50.00% val_bacc=46.06% val_auc=0.7734 val_f1=0.4257
# cnn_img_only train epoch 58/60:   0%|          | 0/29 [00:00<?, ?it/s]
# cnn_img_only val epoch 58/60:   0%|          | 0/4 [00:00<?, ?it/s]
# Epoch 058/60 | train_loss=1.3840 train_acc=53.81% train_bacc=46.23% train_auc=0.8124 train_f1=0.4717 | val_loss=1.5615 val_acc=47.39% val_bacc=39.60% val_auc=0.7618 val_f1=0.3618
# cnn_img_only train epoch 59/60:   0%|          | 0/29 [00:00<?, ?it/s]
# cnn_img_only val epoch 59/60:   0%|          | 0/4 [00:00<?, ?it/s]
# Epoch 059/60 | train_loss=1.3413 train_acc=54.46% train_bacc=48.38% train_auc=0.8279 train_f1=0.4812 | val_loss=1.5406 val_acc=46.96% val_bacc=41.33% val_auc=0.7629 val_f1=0.3967
# cnn_img_only train epoch 60/60:   0%|          | 0/29 [00:00<?, ?it/s]
# cnn_img_only val epoch 60/60:   0%|          | 0/4 [00:00<?, ?it/s]
# Epoch 060/60 | train_loss=1.3568 train_acc=55.98% train_bacc=47.02% train_auc=0.8157 train_f1=0.4795 | val_loss=1.5716 val_acc=48.26% val_bacc=42.01% val_auc=0.7559 val_f1=0.3945
# cnn_img_only test:   0%|          | 0/4 [00:00<?, ?it/s]
# wandb: WARNING Saving files without folders. If you want to preserve subdirectories pass base_path to wandb.save, i.e. wandb.save("/mnt/folder/file.h5", base_path="/mnt")
# wandb: WARNING Symlinked 1 file into the W&B run directory; call wandb.save again to sync new files.
# wandb: WARNING Symlinked 1 file into the W&B run directory; call wandb.save again to sync new files.
# wandb: WARNING Symlinked 1 file into the W&B run directory; call wandb.save again to sync new files.
# wandb: WARNING Symlinked 1 file into the W&B run directory; call wandb.save again to sync new files.
# wandb: WARNING Symlinked 1 file into the W&B run directory; call wandb.save again to sync new files.
# wandb: updating run metadata
# wandb:
# wandb: Run history:
# wandb:                elapsed_sec ▁▁▁▁▁▂▂▂▂▂▃▃▃▃▃▄▄▄▄▄▄▅▅▅▅▅▅▆▆▆▆▆▆▇▇▇▇███
# wandb:                      epoch ▁▁▁▁▂▂▂▂▂▂▃▃▃▃▃▄▄▄▄▄▄▅▅▅▅▅▆▆▆▆▇▇▇▇▇█████
# wandb: epochs_without_improvement ▁▂▃▁▁▂▃▄▁▂▁▂▃▄▁▂▃▄▅▅█▁▃▄▅▁▁▁▂▃▅▁▂▃▅▃▄▅▆█
# wandb:                         lr █████████████████▄▄▄▄▄▄▄▂▂▂▂▂▂▂▂▂▂▂▂▂▂▂▁
# wandb:                  train_acc ▁▁▁▂▂▂▃▃▃▃▄▄▄▄▄▄▄▅▅▆▆▆▆▆▆▆▇▆▇▆▇▇██▇▇█▇██
# wandb:                  train_auc ▁▂▂▂▃▃▃▄▄▄▅▅▅▅▅▆▆▆▆▆▆▇▇▇▇█▇▇▇▇██████████
# wandb:                 train_bacc ▁▂▁▂▂▂▂▃▃▃▃▃▄▄▄▄▄▄▄▄▅▅▅▅▅▇▆▇▇▆▇▇▇▇█▇█▇▇█
# wandb:             train_f1_macro ▁▁▂▂▂▂▃▂▂▃▄▄▄▄▃▄▄▄▅▄▅▆▅▆▅▆▇▇▇▇▇▇▇█▇█████
# wandb:                 train_loss █▆▆▆▆▅▅▅▄▄▄▄▃▄▃▃▃▃▃▃▂▂▂▂▂▂▁▂▂▂▁▁▁▁▁▁▁▁▁▁
# wandb:                    val_acc ▂▃▁▃▃▃▄▅▆▄▄▆▆▇▄▆▅▇▇▇▆▇▇▇█▇▇▇▇█▇█▇▇▇▇▇█▇▇
# wandb:                         +4 ...
# wandb:
# wandb: Run summary:
# wandb:                 best_epoch 52
# wandb:               best_val_acc 49.56522
# wandb:               best_val_auc 0.76637
# wandb:              best_val_bacc 43.57386
# wandb:          best_val_f1_macro 0.42892
# wandb:                elapsed_sec 266.66849
# wandb:                      epoch 60
# wandb: epochs_without_improvement 8
# wandb:                         lr 4e-05
# wandb:                   test_acc 50.86957
# wandb:                        +13 ...
# wandb:
# wandb: 🚀 View run cnn_img_only at: https://wandb.ai/belalofficial123-the-british-university-in-egypt/iot%20fusion/runs/9btdhuh3
# wandb: ⭐️ View project at: https://wandb.ai/belalofficial123-the-british-university-in-egypt/iot%20fusion
# wandb: Synced 5 W&B file(s), 4 media file(s), 0 artifact file(s) and 5 other file(s)
# wandb: Find logs at: ./wandb/run-20260416_190706-9btdhuh3/logs
# Test performance:
# test_loss=1.6132 test_acc=50.87% test_bacc=35.88% test_auc=0.7409 test_f1=0.3497
# Classification report:
#               precision    recall  f1-score     support
# ACK            0.563830  0.726027  0.634731   73.000000
# BCC            0.626667  0.552941  0.587500   85.000000
# MEL            0.250000  0.200000  0.222222    5.000000
# NEV            0.461538  0.500000  0.480000   24.000000
# SCC            0.000000  0.000000  0.000000   20.000000
# SEK            0.173913  0.173913  0.173913   23.000000
# accuracy       0.508696  0.508696  0.508696    0.508696
# macro avg      0.345991  0.358814  0.349728  230.000000
# weighted avg   0.481535  0.508696  0.490887  230.000000
# cnn_img_only complete: best_epoch=52, test_acc=50.87%
# {'experiment_name': 'cnn_img_only',
#  'model_name': 'cnn',
#  'input_mode': 'images_only',
#  'epochs': 60,
#  'batch_size': 64,
#  'split': '80 train / 10 validation / 10 test',
#  'augment_train': True,
#  'class_weighted_loss': True,
#  'class_weight_power': 0.5,
#  'class_balanced_sampler': False,
#  'best_epoch': 52,
#  'best_val_acc': 49.56521739130435,
#  'best_val_bacc': 43.57385758917843,
#  'best_val_auc': 0.7663713085963474,
#  'best_val_f1_macro': 0.428920441495971,
#  'final_train_loss': 1.3567695516497058,
#  'final_train_acc': 55.984766050054404,
#  'final_train_bacc': 47.021888810504976,
#  'final_train_auc': 0.81566382508725,
#  'final_train_f1_macro': 0.4794896236395519,
#  'final_val_loss': 1.5716164537098096,
#  'final_val_acc': 48.26086956521739,
#  'final_val_bacc': 42.01309209095799,
#  'final_val_auc': 0.7558648833456997,
#  'final_val_f1_macro': 0.39448431402912787,
#  'test_loss': 1.6132314060045325,
#  'test_acc': 50.8695652173913,
#  'test_bacc': 35.88136028681872,
#  'test_auc': 0.7409398769338896,
#  'test_f1_macro': 0.34972763410377317,
#  'elapsed_sec': 266.66848707199097,
#  'metrics_path': '/home/zeus/content/IOT_fusion/Results_Logs/cnn_img_only/epoch_metrics.csv',
#  'epoch_log_path': '/home/zeus/content/IOT_fusion/Results_Logs/cnn_img_only/epoch_log.txt',
#  'split_summary_path': '/home/zeus/content/IOT_fusion/Results_Logs/cnn_img_only/split_summary.csv',
#  'checkpoint_path': '/home/zeus/content/IOT_fusion/outputs/ablations/cnn_img_only_best.pth',
#  'classification_report_path': '/home/zeus/content/IOT_fusion/Results_Logs/cnn_img_only/classification_report.csv',
#  'confusion_matrix_path': '/home/zeus/content/IOT_fusion/Results_Logs/cnn_img_only/confusion_matrix.csv',
#  'test_predictions_path': '/home/zeus/content/IOT_fusion/Results_Logs/cnn_img_only/test_predictions.csv',
#  'loss_curve_path': '/home/zeus/content/IOT_fusion/Results_Figures/cnn_img_only/loss_curve.png',
#  'epoch_metrics_curve_path': '/home/zeus/content/IOT_fusion/Results_Figures/cnn_img_only/epoch_metrics.png',
#  'confusion_matrix_plot_path': '/home/zeus/content/IOT_fusion/Results_Figures/cnn_img_only/confusion_matrix.png',
#  'roc_curve_path': '/home/zeus/content/IOT_fusion/Results_Figures/cnn_img_only/roc_curve.png',
#  'xai_paths': "{'image_saliency': '/home/zeus/content/IOT_fusion/Results_XAI/cnn_img_only/cnn_img_only_image_saliency.npy'}"}

# %% [markdown]
# ## Training Outputs

# %%
from pathlib import Path
output_dir = Path('outputs/ablations')
logs_dir = Path('Results_Logs') / 'cnn_img_only'
figures_dir = Path('Results_Figures') / 'cnn_img_only'
xai_dir = Path('Results_XAI') / 'cnn_img_only'
print('metrics:', logs_dir / 'epoch_metrics.csv')
print('epoch log:', logs_dir / 'epoch_log.txt')
print('result:', logs_dir / 'result_summary.csv')
print('checkpoint:', output_dir / 'cnn_img_only_best.pth')
print('classification report:', logs_dir / 'classification_report.csv')
print('confusion matrix CSV:', logs_dir / 'confusion_matrix.csv')
print('loss curve:', figures_dir / 'loss_curve.png')
print('roc curve:', figures_dir / 'roc_curve.png')
sorted(str(p) for p in list(logs_dir.glob('*')) + list(figures_dir.glob('*')) + list(xai_dir.glob('*')))
# Out:
# metrics: Results_Logs/cnn_img_only/epoch_metrics.csv
# epoch log: Results_Logs/cnn_img_only/epoch_log.txt
# result: Results_Logs/cnn_img_only/result_summary.csv
# checkpoint: outputs/ablations/cnn_img_only_best.pth
# classification report: Results_Logs/cnn_img_only/classification_report.csv
# confusion matrix CSV: Results_Logs/cnn_img_only/confusion_matrix.csv
# loss curve: Results_Figures/cnn_img_only/loss_curve.png
# roc curve: Results_Figures/cnn_img_only/roc_curve.png
# ['Results_Figures/cnn_img_only/confusion_matrix.png',
#  'Results_Figures/cnn_img_only/epoch_metrics.png',
#  'Results_Figures/cnn_img_only/loss_curve.png',
#  'Results_Figures/cnn_img_only/roc_curve.png',
#  'Results_Logs/cnn_img_only/classification_report.csv',
#  'Results_Logs/cnn_img_only/confusion_matrix.csv',
#  'Results_Logs/cnn_img_only/epoch_log.txt',
#  'Results_Logs/cnn_img_only/epoch_metrics.csv',
#  'Results_Logs/cnn_img_only/result_summary.csv',
#  'Results_Logs/cnn_img_only/split_summary.csv',
#  'Results_Logs/cnn_img_only/test_predictions.csv',
#  'Results_XAI/cnn_img_only/cnn_img_only_image_saliency.npy']
