# %% [markdown]
# # CNN Metadata Only Ablation
#
# Experiment: `cnn_meta_only`
#
# This notebook runs full GPU training on a stratified 80/10/10 train/validation/test split built from the extracted processed tabular data and image tensors. Image runs use tensor-safe train augmentation and class-weighted loss. CNN runs use tempered class-weighted loss, stronger paper-style augmentation, and early stopping to reduce overfitting; balanced sampling can be enabled manually, but is off by default because it over-corrected on this dataset. Fusion modes combine the tabular metadata vector with the image tensor. It prints per-epoch train/validation loss, accuracy, macro AUC, and macro F1 with tqdm progress bars. Epoch logs are written under `Results_Logs/<experiment>/`, figures under `Results_Figures/<experiment>/`, and XAI artifacts under `Results_XAI/<experiment>/`.

# %%
from pathlib import Path
import os, sys
REPO_ROOT = Path('/home/zeus/content/IOT_fusion')
os.chdir(REPO_ROOT)
sys.path.insert(0, str(REPO_ROOT / 'training'))
from ablation_utils import get_data_info, run_training

info = get_data_info()
print('classes:', info.class_to_idx)
print('metadata_dim:', info.metadata_dim)
# Out:
# classes: {'ACK': 0, 'BCC': 1, 'MEL': 2, 'NEV': 3, 'SCC': 4, 'SEK': 5}
# metadata_dim: 87

# %% [markdown]
# ## Full GPU Training
# Adjust `epochs` and `batch_size` if needed.

# %%
full_result = run_training(
    model_name='cnn',
    input_mode='metadata_only',
    experiment_name='cnn_meta_only',
    epochs=60,
    batch_size=64,
    lr=0.0003,
    num_workers=2,
    device_name='cuda',
    wandb_enabled=True,
    xai_enabled=True,
    augment_train=True,
    class_weighted_loss=True,
    class_weight_power=0.5,
    class_balanced_sampler=False,
    early_stopping_patience=12,
    min_epochs=15,
)
full_result
# Out:
# wandb: [wandb.login()] Loaded credentials for https://api.wandb.ai from WANDB_API_KEY.
# wandb: Currently logged in as: belalofficial123 (belalofficial123-the-british-university-in-egypt) to https://api.wandb.ai. Use `wandb login --relogin` to force relogin
# wandb: Tracking run with wandb version 0.26.0
# wandb: Run data is saved locally in /home/zeus/content/IOT_fusion/wandb/run-20260416_191147-ufrgk18s
# wandb: Run `wandb offline` to turn off syncing.
# wandb: Syncing run cnn_meta_only
# wandb: ⭐️ View project at https://wandb.ai/belalofficial123-the-british-university-in-egypt/iot%20fusion
# wandb: 🚀 View run at https://wandb.ai/belalofficial123-the-british-university-in-egypt/iot%20fusion/runs/ufrgk18s
# Split sizes: {'train': 1838, 'val': 230, 'test': 230}
# Class mapping: {'ACK': 0, 'BCC': 1, 'MEL': 2, 'NEV': 3, 'SCC': 4, 'SEK': 5}
# cnn_meta_only train epoch 1/60:   0%|          | 0/29 [00:00<?, ?it/s]
# cnn_meta_only val epoch 1/60:   0%|          | 0/4 [00:00<?, ?it/s]
# Epoch 001/60 | train_loss=1.7176 train_acc=35.85% train_bacc=31.13% train_auc=0.6979 train_f1=0.2510 | val_loss=1.6220 val_acc=50.00% val_bacc=38.50% val_auc=0.7707 val_f1=0.3223
# cnn_meta_only train epoch 2/60:   0%|          | 0/29 [00:00<?, ?it/s]
# cnn_meta_only val epoch 2/60:   0%|          | 0/4 [00:00<?, ?it/s]
# Epoch 002/60 | train_loss=1.5541 train_acc=49.46% train_bacc=36.69% train_auc=0.7879 train_f1=0.3164 | val_loss=1.4965 val_acc=50.87% val_bacc=35.66% val_auc=0.8260 val_f1=0.2887
# cnn_meta_only train epoch 3/60:   0%|          | 0/29 [00:00<?, ?it/s]
# cnn_meta_only val epoch 3/60:   0%|          | 0/4 [00:00<?, ?it/s]
# Epoch 003/60 | train_loss=1.3972 train_acc=60.66% train_bacc=40.64% train_auc=0.8337 train_f1=0.3756 | val_loss=1.3444 val_acc=60.43% val_bacc=39.56% val_auc=0.8658 val_f1=0.3778
# cnn_meta_only train epoch 4/60:   0%|          | 0/29 [00:00<?, ?it/s]
# cnn_meta_only val epoch 4/60:   0%|          | 0/4 [00:00<?, ?it/s]
# Epoch 004/60 | train_loss=1.2686 train_acc=66.16% train_bacc=45.78% train_auc=0.8669 train_f1=0.4494 | val_loss=1.2497 val_acc=65.65% val_bacc=45.92% val_auc=0.8919 val_f1=0.4431
# cnn_meta_only train epoch 5/60:   0%|          | 0/29 [00:00<?, ?it/s]
# cnn_meta_only val epoch 5/60:   0%|          | 0/4 [00:00<?, ?it/s]
# Epoch 005/60 | train_loss=1.1763 train_acc=71.22% train_bacc=50.08% train_auc=0.8940 train_f1=0.4919 | val_loss=1.1581 val_acc=71.30% val_bacc=50.09% val_auc=0.9144 val_f1=0.5027
# cnn_meta_only train epoch 6/60:   0%|          | 0/29 [00:00<?, ?it/s]
# cnn_meta_only val epoch 6/60:   0%|          | 0/4 [00:00<?, ?it/s]
# Epoch 006/60 | train_loss=1.1221 train_acc=72.85% train_bacc=54.61% train_auc=0.9044 train_f1=0.5572 | val_loss=1.1158 val_acc=70.00% val_bacc=52.97% val_auc=0.9237 val_f1=0.5321
# cnn_meta_only train epoch 7/60:   0%|          | 0/29 [00:00<?, ?it/s]
# cnn_meta_only val epoch 7/60:   0%|          | 0/4 [00:00<?, ?it/s]
# Epoch 007/60 | train_loss=1.0650 train_acc=75.08% train_bacc=60.85% train_auc=0.9197 train_f1=0.6271 | val_loss=1.0499 val_acc=74.35% val_bacc=58.58% val_auc=0.9320 val_f1=0.6007
# cnn_meta_only train epoch 8/60:   0%|          | 0/29 [00:00<?, ?it/s]
# cnn_meta_only val epoch 8/60:   0%|          | 0/4 [00:00<?, ?it/s]
# Epoch 008/60 | train_loss=1.0268 train_acc=75.46% train_bacc=63.19% train_auc=0.9271 train_f1=0.6352 | val_loss=1.0108 val_acc=75.65% val_bacc=64.91% val_auc=0.9351 val_f1=0.6528
# cnn_meta_only train epoch 9/60:   0%|          | 0/29 [00:00<?, ?it/s]
# cnn_meta_only val epoch 9/60:   0%|          | 0/4 [00:00<?, ?it/s]
# Epoch 009/60 | train_loss=1.0062 train_acc=74.92% train_bacc=64.08% train_auc=0.9318 train_f1=0.6341 | val_loss=0.9950 val_acc=76.09% val_bacc=63.93% val_auc=0.9372 val_f1=0.6283
# cnn_meta_only train epoch 10/60:   0%|          | 0/29 [00:00<?, ?it/s]
# cnn_meta_only val epoch 10/60:   0%|          | 0/4 [00:00<?, ?it/s]
# Epoch 010/60 | train_loss=0.9826 train_acc=75.46% train_bacc=66.61% train_auc=0.9348 train_f1=0.6392 | val_loss=0.9752 val_acc=77.39% val_bacc=71.51% val_auc=0.9414 val_f1=0.6812
# cnn_meta_only train epoch 11/60:   0%|          | 0/29 [00:00<?, ?it/s]
# cnn_meta_only val epoch 11/60:   0%|          | 0/4 [00:00<?, ?it/s]
# Epoch 011/60 | train_loss=0.9698 train_acc=75.84% train_bacc=69.99% train_auc=0.9376 train_f1=0.6562 | val_loss=0.9459 val_acc=77.39% val_bacc=72.49% val_auc=0.9416 val_f1=0.6685
# cnn_meta_only train epoch 12/60:   0%|          | 0/29 [00:00<?, ?it/s]
# cnn_meta_only val epoch 12/60:   0%|          | 0/4 [00:00<?, ?it/s]
# Epoch 012/60 | train_loss=0.9656 train_acc=76.01% train_bacc=67.48% train_auc=0.9362 train_f1=0.6475 | val_loss=0.9511 val_acc=76.52% val_bacc=70.62% val_auc=0.9449 val_f1=0.6724
# cnn_meta_only train epoch 13/60:   0%|          | 0/29 [00:00<?, ?it/s]
# cnn_meta_only val epoch 13/60:   0%|          | 0/4 [00:00<?, ?it/s]
# Epoch 013/60 | train_loss=0.9368 train_acc=76.88% train_bacc=70.79% train_auc=0.9413 train_f1=0.6727 | val_loss=0.9342 val_acc=77.83% val_bacc=73.56% val_auc=0.9425 val_f1=0.7104
# cnn_meta_only train epoch 14/60:   0%|          | 0/29 [00:00<?, ?it/s]
# cnn_meta_only val epoch 14/60:   0%|          | 0/4 [00:00<?, ?it/s]
# Epoch 014/60 | train_loss=0.9308 train_acc=76.50% train_bacc=70.49% train_auc=0.9427 train_f1=0.6708 | val_loss=0.9173 val_acc=77.39% val_bacc=73.17% val_auc=0.9436 val_f1=0.6836
# cnn_meta_only train epoch 15/60:   0%|          | 0/29 [00:00<?, ?it/s]
# cnn_meta_only val epoch 15/60:   0%|          | 0/4 [00:00<?, ?it/s]
# Epoch 015/60 | train_loss=0.9207 train_acc=76.99% train_bacc=71.02% train_auc=0.9450 train_f1=0.6650 | val_loss=0.9201 val_acc=76.52% val_bacc=74.26% val_auc=0.9433 val_f1=0.6906
# cnn_meta_only train epoch 16/60:   0%|          | 0/29 [00:00<?, ?it/s]
# cnn_meta_only val epoch 16/60:   0%|          | 0/4 [00:00<?, ?it/s]
# Epoch 016/60 | train_loss=0.9104 train_acc=78.07% train_bacc=72.92% train_auc=0.9478 train_f1=0.7017 | val_loss=0.9031 val_acc=76.52% val_bacc=73.12% val_auc=0.9494 val_f1=0.6946
# cnn_meta_only train epoch 17/60:   0%|          | 0/29 [00:00<?, ?it/s]
# cnn_meta_only val epoch 17/60:   0%|          | 0/4 [00:00<?, ?it/s]
# Epoch 017/60 | train_loss=0.9035 train_acc=77.91% train_bacc=73.60% train_auc=0.9473 train_f1=0.6972 | val_loss=0.8940 val_acc=78.70% val_bacc=75.38% val_auc=0.9474 val_f1=0.7039
# cnn_meta_only train epoch 18/60:   0%|          | 0/29 [00:00<?, ?it/s]
# cnn_meta_only val epoch 18/60:   0%|          | 0/4 [00:00<?, ?it/s]
# Epoch 018/60 | train_loss=0.9028 train_acc=78.13% train_bacc=72.93% train_auc=0.9480 train_f1=0.7026 | val_loss=0.8881 val_acc=77.83% val_bacc=73.39% val_auc=0.9511 val_f1=0.7030
# cnn_meta_only train epoch 19/60:   0%|          | 0/29 [00:00<?, ?it/s]
# cnn_meta_only val epoch 19/60:   0%|          | 0/4 [00:00<?, ?it/s]
# Epoch 019/60 | train_loss=0.8809 train_acc=78.67% train_bacc=74.28% train_auc=0.9536 train_f1=0.7072 | val_loss=0.8902 val_acc=77.83% val_bacc=78.52% val_auc=0.9494 val_f1=0.7284
# cnn_meta_only train epoch 20/60:   0%|          | 0/29 [00:00<?, ?it/s]
# cnn_meta_only val epoch 20/60:   0%|          | 0/4 [00:00<?, ?it/s]
# Epoch 020/60 | train_loss=0.8798 train_acc=78.13% train_bacc=75.87% train_auc=0.9527 train_f1=0.7219 | val_loss=0.8694 val_acc=80.43% val_bacc=76.65% val_auc=0.9528 val_f1=0.7410
# cnn_meta_only train epoch 21/60:   0%|          | 0/29 [00:00<?, ?it/s]
# cnn_meta_only val epoch 21/60:   0%|          | 0/4 [00:00<?, ?it/s]
# Epoch 021/60 | train_loss=0.8803 train_acc=78.24% train_bacc=75.23% train_auc=0.9534 train_f1=0.7153 | val_loss=0.8963 val_acc=76.52% val_bacc=74.76% val_auc=0.9457 val_f1=0.6760
# cnn_meta_only train epoch 22/60:   0%|          | 0/29 [00:00<?, ?it/s]
# cnn_meta_only val epoch 22/60:   0%|          | 0/4 [00:00<?, ?it/s]
# Epoch 022/60 | train_loss=0.8774 train_acc=78.29% train_bacc=73.71% train_auc=0.9516 train_f1=0.7121 | val_loss=0.8916 val_acc=76.09% val_bacc=75.79% val_auc=0.9517 val_f1=0.7101
# cnn_meta_only train epoch 23/60:   0%|          | 0/29 [00:00<?, ?it/s]
# cnn_meta_only val epoch 23/60:   0%|          | 0/4 [00:00<?, ?it/s]
# Epoch 023/60 | train_loss=0.8622 train_acc=78.94% train_bacc=75.45% train_auc=0.9549 train_f1=0.7216 | val_loss=0.8716 val_acc=80.00% val_bacc=78.80% val_auc=0.9509 val_f1=0.7423
# cnn_meta_only train epoch 24/60:   0%|          | 0/29 [00:00<?, ?it/s]
# cnn_meta_only val epoch 24/60:   0%|          | 0/4 [00:00<?, ?it/s]
# Epoch 024/60 | train_loss=0.8486 train_acc=80.30% train_bacc=77.15% train_auc=0.9580 train_f1=0.7424 | val_loss=0.8692 val_acc=79.13% val_bacc=77.36% val_auc=0.9523 val_f1=0.7187
# cnn_meta_only train epoch 25/60:   0%|          | 0/29 [00:00<?, ?it/s]
# cnn_meta_only val epoch 25/60:   0%|          | 0/4 [00:00<?, ?it/s]
# Epoch 025/60 | train_loss=0.8379 train_acc=80.03% train_bacc=77.25% train_auc=0.9600 train_f1=0.7433 | val_loss=0.8657 val_acc=79.13% val_bacc=78.03% val_auc=0.9538 val_f1=0.7295
# cnn_meta_only train epoch 26/60:   0%|          | 0/29 [00:00<?, ?it/s]
# cnn_meta_only val epoch 26/60:   0%|          | 0/4 [00:00<?, ?it/s]
# Epoch 026/60 | train_loss=0.8411 train_acc=80.03% train_bacc=77.55% train_auc=0.9595 train_f1=0.7388 | val_loss=0.8886 val_acc=76.96% val_bacc=68.33% val_auc=0.9566 val_f1=0.6796
# cnn_meta_only train epoch 27/60:   0%|          | 0/29 [00:00<?, ?it/s]
# cnn_meta_only val epoch 27/60:   0%|          | 0/4 [00:00<?, ?it/s]
# Epoch 027/60 | train_loss=0.8299 train_acc=80.58% train_bacc=77.67% train_auc=0.9617 train_f1=0.7526 | val_loss=0.8760 val_acc=77.83% val_bacc=77.62% val_auc=0.9532 val_f1=0.7078
# cnn_meta_only train epoch 28/60:   0%|          | 0/29 [00:00<?, ?it/s]
# cnn_meta_only val epoch 28/60:   0%|          | 0/4 [00:00<?, ?it/s]
# Epoch 028/60 | train_loss=0.8380 train_acc=79.92% train_bacc=77.18% train_auc=0.9592 train_f1=0.7356 | val_loss=0.8599 val_acc=79.57% val_bacc=75.30% val_auc=0.9575 val_f1=0.7297
# cnn_meta_only train epoch 29/60:   0%|          | 0/29 [00:00<?, ?it/s]
# cnn_meta_only val epoch 29/60:   0%|          | 0/4 [00:00<?, ?it/s]
# Epoch 029/60 | train_loss=0.8271 train_acc=80.79% train_bacc=77.63% train_auc=0.9616 train_f1=0.7549 | val_loss=0.8735 val_acc=78.26% val_bacc=76.61% val_auc=0.9563 val_f1=0.7293
# cnn_meta_only train epoch 30/60:   0%|          | 0/29 [00:00<?, ?it/s]
# cnn_meta_only val epoch 30/60:   0%|          | 0/4 [00:00<?, ?it/s]
# Epoch 030/60 | train_loss=0.8185 train_acc=80.74% train_bacc=77.16% train_auc=0.9639 train_f1=0.7470 | val_loss=0.8460 val_acc=80.87% val_bacc=79.44% val_auc=0.9568 val_f1=0.7522
# cnn_meta_only train epoch 31/60:   0%|          | 0/29 [00:00<?, ?it/s]
# cnn_meta_only val epoch 31/60:   0%|          | 0/4 [00:00<?, ?it/s]
# Epoch 031/60 | train_loss=0.8150 train_acc=81.23% train_bacc=78.03% train_auc=0.9630 train_f1=0.7521 | val_loss=0.8552 val_acc=80.00% val_bacc=78.63% val_auc=0.9553 val_f1=0.7527
# cnn_meta_only train epoch 32/60:   0%|          | 0/29 [00:00<?, ?it/s]
# cnn_meta_only val epoch 32/60:   0%|          | 0/4 [00:00<?, ?it/s]
# Epoch 032/60 | train_loss=0.8131 train_acc=81.34% train_bacc=77.89% train_auc=0.9644 train_f1=0.7559 | val_loss=0.8484 val_acc=79.57% val_bacc=77.34% val_auc=0.9571 val_f1=0.7431
# cnn_meta_only train epoch 33/60:   0%|          | 0/29 [00:00<?, ?it/s]
# cnn_meta_only val epoch 33/60:   0%|          | 0/4 [00:00<?, ?it/s]
# Epoch 033/60 | train_loss=0.8015 train_acc=81.99% train_bacc=79.73% train_auc=0.9666 train_f1=0.7751 | val_loss=0.8457 val_acc=79.57% val_bacc=78.02% val_auc=0.9570 val_f1=0.7480
# cnn_meta_only train epoch 34/60:   0%|          | 0/29 [00:00<?, ?it/s]
# cnn_meta_only val epoch 34/60:   0%|          | 0/4 [00:00<?, ?it/s]
# Epoch 034/60 | train_loss=0.8118 train_acc=80.63% train_bacc=76.91% train_auc=0.9648 train_f1=0.7446 | val_loss=0.8502 val_acc=79.57% val_bacc=78.97% val_auc=0.9551 val_f1=0.7399
# cnn_meta_only train epoch 35/60:   0%|          | 0/29 [00:00<?, ?it/s]
# cnn_meta_only val epoch 35/60:   0%|          | 0/4 [00:00<?, ?it/s]
# Epoch 035/60 | train_loss=0.8052 train_acc=80.36% train_bacc=77.55% train_auc=0.9661 train_f1=0.7434 | val_loss=0.8468 val_acc=78.70% val_bacc=75.98% val_auc=0.9580 val_f1=0.7306
# cnn_meta_only train epoch 36/60:   0%|          | 0/29 [00:00<?, ?it/s]
# cnn_meta_only val epoch 36/60:   0%|          | 0/4 [00:00<?, ?it/s]
# Epoch 036/60 | train_loss=0.8064 train_acc=82.43% train_bacc=79.57% train_auc=0.9652 train_f1=0.7721 | val_loss=0.8611 val_acc=80.00% val_bacc=80.98% val_auc=0.9549 val_f1=0.7497
# cnn_meta_only train epoch 37/60:   0%|          | 0/29 [00:00<?, ?it/s]
# cnn_meta_only val epoch 37/60:   0%|          | 0/4 [00:00<?, ?it/s]
# Epoch 037/60 | train_loss=0.7983 train_acc=81.23% train_bacc=78.13% train_auc=0.9668 train_f1=0.7575 | val_loss=0.8441 val_acc=79.57% val_bacc=76.88% val_auc=0.9578 val_f1=0.7357
# cnn_meta_only train epoch 38/60:   0%|          | 0/29 [00:00<?, ?it/s]
# cnn_meta_only val epoch 38/60:   0%|          | 0/4 [00:00<?, ?it/s]
# Epoch 038/60 | train_loss=0.8081 train_acc=81.61% train_bacc=79.06% train_auc=0.9650 train_f1=0.7647 | val_loss=0.8421 val_acc=79.13% val_bacc=76.65% val_auc=0.9586 val_f1=0.7383
# cnn_meta_only train epoch 39/60:   0%|          | 0/29 [00:00<?, ?it/s]
# cnn_meta_only val epoch 39/60:   0%|          | 0/4 [00:00<?, ?it/s]
# Epoch 039/60 | train_loss=0.8003 train_acc=82.32% train_bacc=79.24% train_auc=0.9656 train_f1=0.7754 | val_loss=0.8449 val_acc=78.70% val_bacc=76.45% val_auc=0.9581 val_f1=0.7349
# cnn_meta_only train epoch 40/60:   0%|          | 0/29 [00:00<?, ?it/s]
# cnn_meta_only val epoch 40/60:   0%|          | 0/4 [00:00<?, ?it/s]
# Epoch 040/60 | train_loss=0.7939 train_acc=81.56% train_bacc=79.52% train_auc=0.9669 train_f1=0.7645 | val_loss=0.8430 val_acc=80.00% val_bacc=78.01% val_auc=0.9583 val_f1=0.7508
# cnn_meta_only train epoch 41/60:   0%|          | 0/29 [00:00<?, ?it/s]
# cnn_meta_only val epoch 41/60:   0%|          | 0/4 [00:00<?, ?it/s]
# Epoch 041/60 | train_loss=0.7981 train_acc=81.94% train_bacc=79.59% train_auc=0.9663 train_f1=0.7679 | val_loss=0.8437 val_acc=78.70% val_bacc=75.98% val_auc=0.9582 val_f1=0.7334
# cnn_meta_only train epoch 42/60:   0%|          | 0/29 [00:00<?, ?it/s]
# cnn_meta_only val epoch 42/60:   0%|          | 0/4 [00:00<?, ?it/s]
# Epoch 042/60 | train_loss=0.7887 train_acc=81.83% train_bacc=79.88% train_auc=0.9688 train_f1=0.7677 | val_loss=0.8427 val_acc=79.57% val_bacc=76.85% val_auc=0.9584 val_f1=0.7418
# cnn_meta_only train epoch 43/60:   0%|          | 0/29 [00:00<?, ?it/s]
# cnn_meta_only val epoch 43/60:   0%|          | 0/4 [00:00<?, ?it/s]
# Epoch 043/60 | train_loss=0.7974 train_acc=80.79% train_bacc=78.04% train_auc=0.9668 train_f1=0.7518 | val_loss=0.8385 val_acc=78.26% val_bacc=75.78% val_auc=0.9585 val_f1=0.7285
# Early stopping at epoch 43: no validation macro-F1 improvement for 12 epochs.
# cnn_meta_only test:   0%|          | 0/4 [00:00<?, ?it/s]
# wandb: WARNING Saving files without folders. If you want to preserve subdirectories pass base_path to wandb.save, i.e. wandb.save("/mnt/folder/file.h5", base_path="/mnt")
# wandb: WARNING Symlinked 1 file into the W&B run directory; call wandb.save again to sync new files.
# wandb: WARNING Symlinked 1 file into the W&B run directory; call wandb.save again to sync new files.
# wandb: WARNING Symlinked 1 file into the W&B run directory; call wandb.save again to sync new files.
# wandb: WARNING Symlinked 1 file into the W&B run directory; call wandb.save again to sync new files.
# wandb: WARNING Symlinked 1 file into the W&B run directory; call wandb.save again to sync new files.
# wandb: updating run metadata
# wandb:
# wandb: Run history:
# wandb:                elapsed_sec ▁▁▁▂▂▂▂▂▂▃▃▃▃▃▃▄▄▄▄▄▄▅▅▅▅▅▆▆▆▆▆▆▇▇▇▇▇▇██
# wandb:                      epoch ▁▁▁▁▁▂▂▂▂▂▃▃▃▃▃▄▄▄▄▅▅▅▅▅▅▅▆▆▆▆▆▇▇▇▇▇████
# wandb: epochs_without_improvement ▁▂▁▁▁▁▁▁▂▁▂▂▁▂▃▃▄▁▁▂▂▁▂▂▃▃▅▁▁▂▂▃▃▄▅▅▆▆▇█
# wandb:                         lr ██████████████████████████▄▄▄▄▄▄▄▄▂▂▂▂▂▁
# wandb:                  train_acc ▁▃▅▆▆▇▇▇▇▇▇▇▇▇▇▇▇▇▇▇▇▇██████████████████
# wandb:                  train_auc ▁▃▅▅▆▆▇▇▇▇▇▇▇▇█▇████████████████████████
# wandb:                 train_bacc ▁▂▂▃▄▄▅▆▆▆▇▆▇▇▇▇▇▇▇▇▇▇██████████████████
# wandb:             train_f1_macro ▁▂▃▄▄▅▆▆▆▆▆▆▇▇▇▇▇▇▇▇▇▇██████████████████
# wandb:                 train_loss █▇▆▅▄▃▃▃▃▂▂▂▂▂▂▂▂▂▂▂▂▂▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁
# wandb:                    val_acc ▁▁▃▅▆▆▇▇▇▇▇▇▇▇▇█▇▇█▇▇███▇▇▇████████████▇
# wandb:                         +4 ...
# wandb:
# wandb: Run summary:
# wandb:                 best_epoch 31
# wandb:               best_val_acc 80
# wandb:               best_val_auc 0.9553
# wandb:              best_val_bacc 78.62923
# wandb:          best_val_f1_macro 0.75269
# wandb:                elapsed_sec 9.2137
# wandb:                      epoch 43
# wandb: epochs_without_improvement 12
# wandb:                         lr 4e-05
# wandb:                   test_acc 79.56522
# wandb:                        +13 ...
# wandb:
# wandb: 🚀 View run cnn_meta_only at: https://wandb.ai/belalofficial123-the-british-university-in-egypt/iot%20fusion/runs/ufrgk18s
# wandb: ⭐️ View project at: https://wandb.ai/belalofficial123-the-british-university-in-egypt/iot%20fusion
# wandb: Synced 5 W&B file(s), 4 media file(s), 0 artifact file(s) and 5 other file(s)
# wandb: Find logs at: ./wandb/run-20260416_191147-ufrgk18s/logs
# Test performance:
# test_loss=0.8818 test_acc=79.57% test_bacc=73.24% test_auc=0.9562 test_f1=0.7095
# Classification report:
#               precision    recall  f1-score     support
# ACK            0.906250  0.794521  0.846715   73.000000
# BCC            0.811111  0.858824  0.834286   85.000000
# MEL            0.428571  0.600000  0.500000    5.000000
# NEV            0.741935  0.958333  0.836364   24.000000
# SCC            0.533333  0.400000  0.457143   20.000000
# SEK            0.782609  0.782609  0.782609   23.000000
# accuracy       0.795652  0.795652  0.795652    0.795652
# macro avg      0.700635  0.732381  0.709519  230.000000
# weighted avg   0.798768  0.795652  0.793218  230.000000
# cnn_meta_only complete: best_epoch=31, test_acc=79.57%
# {'experiment_name': 'cnn_meta_only',
#  'model_name': 'cnn',
#  'input_mode': 'metadata_only',
#  'epochs': 60,
#  'batch_size': 64,
#  'split': '80 train / 10 validation / 10 test',
#  'augment_train': True,
#  'class_weighted_loss': True,
#  'class_weight_power': 0.5,
#  'class_balanced_sampler': False,
#  'best_epoch': 31,
#  'best_val_acc': 80.0,
#  'best_val_bacc': 78.62922717753288,
#  'best_val_auc': 0.9552958696583365,
#  'best_val_f1_macro': 0.7526856733504133,
#  'final_train_loss': 0.797415687677261,
#  'final_train_acc': 80.7943416757345,
#  'final_train_bacc': 78.04183416616833,
#  'final_train_auc': 0.9667822947437555,
#  'final_train_f1_macro': 0.7517922081863263,
#  'final_val_loss': 0.8385004924691242,
#  'final_val_acc': 78.26086956521739,
#  'final_val_bacc': 75.78193199894714,
#  'final_val_auc': 0.9585108608622858,
#  'final_val_f1_macro': 0.7284761203785465,
#  'test_loss': 0.8817545476167098,
#  'test_acc': 79.56521739130434,
#  'test_bacc': 73.23810177237462,
#  'test_auc': 0.9561538175701081,
#  'test_f1_macro': 0.7095193719852558,
#  'elapsed_sec': 9.213696956634521,
#  'metrics_path': '/home/zeus/content/IOT_fusion/Results_Logs/cnn_meta_only/epoch_metrics.csv',
#  'epoch_log_path': '/home/zeus/content/IOT_fusion/Results_Logs/cnn_meta_only/epoch_log.txt',
#  'split_summary_path': '/home/zeus/content/IOT_fusion/Results_Logs/cnn_meta_only/split_summary.csv',
#  'checkpoint_path': '/home/zeus/content/IOT_fusion/outputs/ablations/cnn_meta_only_best.pth',
#  'classification_report_path': '/home/zeus/content/IOT_fusion/Results_Logs/cnn_meta_only/classification_report.csv',
#  'confusion_matrix_path': '/home/zeus/content/IOT_fusion/Results_Logs/cnn_meta_only/confusion_matrix.csv',
#  'test_predictions_path': '/home/zeus/content/IOT_fusion/Results_Logs/cnn_meta_only/test_predictions.csv',
#  'loss_curve_path': '/home/zeus/content/IOT_fusion/Results_Figures/cnn_meta_only/loss_curve.png',
#  'epoch_metrics_curve_path': '/home/zeus/content/IOT_fusion/Results_Figures/cnn_meta_only/epoch_metrics.png',
#  'confusion_matrix_plot_path': '/home/zeus/content/IOT_fusion/Results_Figures/cnn_meta_only/confusion_matrix.png',
#  'roc_curve_path': '/home/zeus/content/IOT_fusion/Results_Figures/cnn_meta_only/roc_curve.png',
#  'xai_paths': "{'metadata_importance': '/home/zeus/content/IOT_fusion/Results_XAI/cnn_meta_only/cnn_meta_only_metadata_xai_top20.csv'}"}

# %% [markdown]
# ## Training Outputs

# %%
from pathlib import Path
output_dir = Path('outputs/ablations')
logs_dir = Path('Results_Logs') / 'cnn_meta_only'
figures_dir = Path('Results_Figures') / 'cnn_meta_only'
xai_dir = Path('Results_XAI') / 'cnn_meta_only'
print('metrics:', logs_dir / 'epoch_metrics.csv')
print('epoch log:', logs_dir / 'epoch_log.txt')
print('result:', logs_dir / 'result_summary.csv')
print('checkpoint:', output_dir / 'cnn_meta_only_best.pth')
print('classification report:', logs_dir / 'classification_report.csv')
print('confusion matrix CSV:', logs_dir / 'confusion_matrix.csv')
print('loss curve:', figures_dir / 'loss_curve.png')
print('roc curve:', figures_dir / 'roc_curve.png')
sorted(str(p) for p in list(logs_dir.glob('*')) + list(figures_dir.glob('*')) + list(xai_dir.glob('*')))
# Out:
# metrics: Results_Logs/cnn_meta_only/epoch_metrics.csv
# epoch log: Results_Logs/cnn_meta_only/epoch_log.txt
# result: Results_Logs/cnn_meta_only/result_summary.csv
# checkpoint: outputs/ablations/cnn_meta_only_best.pth
# classification report: Results_Logs/cnn_meta_only/classification_report.csv
# confusion matrix CSV: Results_Logs/cnn_meta_only/confusion_matrix.csv
# loss curve: Results_Figures/cnn_meta_only/loss_curve.png
# roc curve: Results_Figures/cnn_meta_only/roc_curve.png
# ['Results_Figures/cnn_meta_only/confusion_matrix.png',
#  'Results_Figures/cnn_meta_only/epoch_metrics.png',
#  'Results_Figures/cnn_meta_only/loss_curve.png',
#  'Results_Figures/cnn_meta_only/roc_curve.png',
#  'Results_Logs/cnn_meta_only/classification_report.csv',
#  'Results_Logs/cnn_meta_only/confusion_matrix.csv',
#  'Results_Logs/cnn_meta_only/epoch_log.txt',
#  'Results_Logs/cnn_meta_only/epoch_metrics.csv',
#  'Results_Logs/cnn_meta_only/result_summary.csv',
#  'Results_Logs/cnn_meta_only/split_summary.csv',
#  'Results_Logs/cnn_meta_only/test_predictions.csv',
#  'Results_XAI/cnn_meta_only/cnn_meta_only_metadata_xai_top20.csv']
