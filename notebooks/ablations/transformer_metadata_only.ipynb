# %% [markdown]
# # TRANSFORMER Metadata Only Ablation
#
# Experiment: `transformer_meta_only`
#
# This notebook runs full GPU training on a stratified 80/10/10 train/validation/test split built from the extracted processed tabular data and image tensors. Image runs use tensor-safe train augmentation and class-weighted loss. CNN runs use tempered class-weighted loss, stronger paper-style augmentation, and early stopping to reduce overfitting; balanced sampling can be enabled manually, but is off by default because it over-corrected on this dataset. Fusion modes combine the tabular metadata vector with the image tensor. It prints per-epoch train/validation loss, accuracy, macro AUC, and macro F1 with tqdm progress bars. Epoch logs are written under `Results_Logs/<experiment>/`, figures under `Results_Figures/<experiment>/`, and XAI artifacts under `Results_XAI/<experiment>/`.

# %%
from pathlib import Path
import os, sys
REPO_ROOT = Path('/home/zeus/content/IOT_fusion')
os.chdir(REPO_ROOT)
sys.path.insert(0, str(REPO_ROOT / 'training'))
from ablation_utils import get_data_info, run_training

info = get_data_info()
print('classes:', info.class_to_idx)
print('metadata_dim:', info.metadata_dim)
# Out:
# classes: {'ACK': 0, 'BCC': 1, 'MEL': 2, 'NEV': 3, 'SCC': 4, 'SEK': 5}
# metadata_dim: 87

# %% [markdown]
# ## Full GPU Training
# Adjust `epochs` and `batch_size` if needed.

# %%
full_result = run_training(
    model_name='transformer',
    input_mode='metadata_only',
    experiment_name='transformer_meta_only',
    epochs=25,
    batch_size=256,
    lr=0.0005,
    num_workers=2,
    device_name='cuda',
    wandb_enabled=True,
    xai_enabled=True,
    augment_train=True,
    class_weighted_loss=True,
    class_weight_power=0.5,
    class_balanced_sampler=False,
    early_stopping_patience=12,
    min_epochs=15,
)
full_result
# Out:
# wandb: [wandb.login()] Loaded credentials for https://api.wandb.ai from WANDB_API_KEY.
# wandb: Currently logged in as: belalofficial123 (belalofficial123-the-british-university-in-egypt) to https://api.wandb.ai. Use `wandb login --relogin` to force relogin
# wandb: Tracking run with wandb version 0.26.0
# wandb: Run data is saved locally in /home/zeus/content/IOT_fusion/wandb/run-20260416_192718-3f16am25
# wandb: Run `wandb offline` to turn off syncing.
# wandb: Syncing run transformer_meta_only
# wandb: ⭐️ View project at https://wandb.ai/belalofficial123-the-british-university-in-egypt/iot%20fusion
# wandb: 🚀 View run at https://wandb.ai/belalofficial123-the-british-university-in-egypt/iot%20fusion/runs/3f16am25
# Split sizes: {'train': 1838, 'val': 230, 'test': 230}
# Class mapping: {'ACK': 0, 'BCC': 1, 'MEL': 2, 'NEV': 3, 'SCC': 4, 'SEK': 5}
# transformer_meta_only train epoch 1/25:   0%|          | 0/8 [00:00<?, ?it/s]
# transformer_meta_only val epoch 1/25:   0%|          | 0/1 [00:00<?, ?it/s]
# Epoch 001/25 | train_loss=2.6978 train_acc=9.14% train_bacc=17.10% train_auc=0.5224 train_f1=0.0634 | val_loss=1.8725 val_acc=8.26% val_bacc=16.67% val_auc=0.6040 val_f1=0.0259
# transformer_meta_only train epoch 2/25:   0%|          | 0/8 [00:00<?, ?it/s]
# transformer_meta_only val epoch 2/25:   0%|          | 0/1 [00:00<?, ?it/s]
# Epoch 002/25 | train_loss=1.9845 train_acc=26.61% train_bacc=18.41% train_auc=0.5499 train_f1=0.1727 | val_loss=1.7954 val_acc=50.87% val_bacc=24.41% val_auc=0.6128 val_f1=0.1972
# transformer_meta_only train epoch 3/25:   0%|          | 0/8 [00:00<?, ?it/s]
# transformer_meta_only val epoch 3/25:   0%|          | 0/1 [00:00<?, ?it/s]
# Epoch 003/25 | train_loss=1.9544 train_acc=36.56% train_bacc=19.09% train_auc=0.5686 train_f1=0.1772 | val_loss=1.7178 val_acc=53.48% val_bacc=25.75% val_auc=0.6857 val_f1=0.2083
# transformer_meta_only train epoch 4/25:   0%|          | 0/8 [00:00<?, ?it/s]
# transformer_meta_only val epoch 4/25:   0%|          | 0/1 [00:00<?, ?it/s]
# Epoch 004/25 | train_loss=1.9010 train_acc=33.95% train_bacc=20.81% train_auc=0.5768 train_f1=0.2047 | val_loss=1.6387 val_acc=54.78% val_bacc=28.01% val_auc=0.7600 val_f1=0.2521
# transformer_meta_only train epoch 5/25:   0%|          | 0/8 [00:00<?, ?it/s]
# transformer_meta_only val epoch 5/25:   0%|          | 0/1 [00:00<?, ?it/s]
# Epoch 005/25 | train_loss=1.7768 train_acc=36.07% train_bacc=26.20% train_auc=0.6324 train_f1=0.2545 | val_loss=1.5871 val_acc=54.78% val_bacc=28.01% val_auc=0.7986 val_f1=0.2519
# transformer_meta_only train epoch 6/25:   0%|          | 0/8 [00:00<?, ?it/s]
# transformer_meta_only val epoch 6/25:   0%|          | 0/1 [00:00<?, ?it/s]
# Epoch 006/25 | train_loss=1.7208 train_acc=40.75% train_bacc=26.82% train_auc=0.6573 train_f1=0.2726 | val_loss=1.5513 val_acc=54.78% val_bacc=28.01% val_auc=0.8092 val_f1=0.2519
# transformer_meta_only train epoch 7/25:   0%|          | 0/8 [00:00<?, ?it/s]
# transformer_meta_only val epoch 7/25:   0%|          | 0/1 [00:00<?, ?it/s]
# Epoch 007/25 | train_loss=1.7191 train_acc=41.62% train_bacc=26.98% train_auc=0.6597 train_f1=0.2728 | val_loss=1.5103 val_acc=55.65% val_bacc=29.34% val_auc=0.8210 val_f1=0.2745
# transformer_meta_only train epoch 8/25:   0%|          | 0/8 [00:00<?, ?it/s]
# transformer_meta_only val epoch 8/25:   0%|          | 0/1 [00:00<?, ?it/s]
# Epoch 008/25 | train_loss=1.6563 train_acc=45.43% train_bacc=31.07% train_auc=0.6870 train_f1=0.3172 | val_loss=1.4689 val_acc=57.39% val_bacc=31.57% val_auc=0.8430 val_f1=0.3012
# transformer_meta_only train epoch 9/25:   0%|          | 0/8 [00:00<?, ?it/s]
# transformer_meta_only val epoch 9/25:   0%|          | 0/1 [00:00<?, ?it/s]
# Epoch 009/25 | train_loss=1.6179 train_acc=47.12% train_bacc=31.78% train_auc=0.7006 train_f1=0.3263 | val_loss=1.4386 val_acc=58.26% val_bacc=33.34% val_auc=0.8571 val_f1=0.3179
# transformer_meta_only train epoch 10/25:   0%|          | 0/8 [00:00<?, ?it/s]
# transformer_meta_only val epoch 10/25:   0%|          | 0/1 [00:00<?, ?it/s]
# Epoch 010/25 | train_loss=1.5382 train_acc=49.67% train_bacc=36.90% train_auc=0.7507 train_f1=0.3747 | val_loss=1.4028 val_acc=61.74% val_bacc=37.01% val_auc=0.8667 val_f1=0.3687
# transformer_meta_only train epoch 11/25:   0%|          | 0/8 [00:00<?, ?it/s]
# transformer_meta_only val epoch 11/25:   0%|          | 0/1 [00:00<?, ?it/s]
# Epoch 011/25 | train_loss=1.5018 train_acc=52.56% train_bacc=37.13% train_auc=0.7587 train_f1=0.3740 | val_loss=1.3798 val_acc=59.13% val_bacc=37.06% val_auc=0.8681 val_f1=0.3733
# transformer_meta_only train epoch 12/25:   0%|          | 0/8 [00:00<?, ?it/s]
# transformer_meta_only val epoch 12/25:   0%|          | 0/1 [00:00<?, ?it/s]
# Epoch 012/25 | train_loss=1.4598 train_acc=53.10% train_bacc=39.67% train_auc=0.7784 train_f1=0.3979 | val_loss=1.3493 val_acc=63.91% val_bacc=39.02% val_auc=0.8800 val_f1=0.3854
# transformer_meta_only train epoch 13/25:   0%|          | 0/8 [00:00<?, ?it/s]
# transformer_meta_only val epoch 13/25:   0%|          | 0/1 [00:00<?, ?it/s]
# Epoch 013/25 | train_loss=1.4368 train_acc=54.08% train_bacc=40.33% train_auc=0.7868 train_f1=0.4063 | val_loss=1.3244 val_acc=65.65% val_bacc=39.91% val_auc=0.8892 val_f1=0.3854
# transformer_meta_only train epoch 14/25:   0%|          | 0/8 [00:00<?, ?it/s]
# transformer_meta_only val epoch 14/25:   0%|          | 0/1 [00:00<?, ?it/s]
# Epoch 014/25 | train_loss=1.4049 train_acc=55.01% train_bacc=42.88% train_auc=0.7984 train_f1=0.4321 | val_loss=1.3090 val_acc=63.04% val_bacc=39.47% val_auc=0.8898 val_f1=0.3906
# transformer_meta_only train epoch 15/25:   0%|          | 0/8 [00:00<?, ?it/s]
# transformer_meta_only val epoch 15/25:   0%|          | 0/1 [00:00<?, ?it/s]
# Epoch 015/25 | train_loss=1.3522 train_acc=58.05% train_bacc=42.89% train_auc=0.8238 train_f1=0.4345 | val_loss=1.2848 val_acc=64.35% val_bacc=40.16% val_auc=0.8948 val_f1=0.3973
# transformer_meta_only train epoch 16/25:   0%|          | 0/8 [00:00<?, ?it/s]
# transformer_meta_only val epoch 16/25:   0%|          | 0/1 [00:00<?, ?it/s]
# Epoch 016/25 | train_loss=1.3535 train_acc=56.64% train_bacc=43.23% train_auc=0.8165 train_f1=0.4389 | val_loss=1.2621 val_acc=66.52% val_bacc=41.33% val_auc=0.9016 val_f1=0.4081
# transformer_meta_only train epoch 17/25:   0%|          | 0/8 [00:00<?, ?it/s]
# transformer_meta_only val epoch 17/25:   0%|          | 0/1 [00:00<?, ?it/s]
# Epoch 017/25 | train_loss=1.3392 train_acc=57.62% train_bacc=45.00% train_auc=0.8231 train_f1=0.4492 | val_loss=1.2536 val_acc=66.09% val_bacc=42.93% val_auc=0.9026 val_f1=0.4350
# transformer_meta_only train epoch 18/25:   0%|          | 0/8 [00:00<?, ?it/s]
# transformer_meta_only val epoch 18/25:   0%|          | 0/1 [00:00<?, ?it/s]
# Epoch 018/25 | train_loss=1.3174 train_acc=58.27% train_bacc=42.55% train_auc=0.8338 train_f1=0.4285 | val_loss=1.2268 val_acc=67.83% val_bacc=45.55% val_auc=0.9073 val_f1=0.4763
# transformer_meta_only train epoch 19/25:   0%|          | 0/8 [00:00<?, ?it/s]
# transformer_meta_only val epoch 19/25:   0%|          | 0/1 [00:00<?, ?it/s]
# Epoch 019/25 | train_loss=1.2788 train_acc=59.58% train_bacc=45.21% train_auc=0.8490 train_f1=0.4479 | val_loss=1.2077 val_acc=68.70% val_bacc=50.52% val_auc=0.9130 val_f1=0.5184
# transformer_meta_only train epoch 20/25:   0%|          | 0/8 [00:00<?, ?it/s]
# transformer_meta_only val epoch 20/25:   0%|          | 0/1 [00:00<?, ?it/s]
# Epoch 020/25 | train_loss=1.2697 train_acc=60.94% train_bacc=47.30% train_auc=0.8522 train_f1=0.4738 | val_loss=1.1996 val_acc=68.26% val_bacc=47.18% val_auc=0.9158 val_f1=0.4982
# transformer_meta_only train epoch 21/25:   0%|          | 0/8 [00:00<?, ?it/s]
# transformer_meta_only val epoch 21/25:   0%|          | 0/1 [00:00<?, ?it/s]
# Epoch 021/25 | train_loss=1.2472 train_acc=61.97% train_bacc=48.25% train_auc=0.8579 train_f1=0.4885 | val_loss=1.1776 val_acc=70.87% val_bacc=51.72% val_auc=0.9197 val_f1=0.5393
# transformer_meta_only train epoch 22/25:   0%|          | 0/8 [00:00<?, ?it/s]
# transformer_meta_only val epoch 22/25:   0%|          | 0/1 [00:00<?, ?it/s]
# Epoch 022/25 | train_loss=1.2348 train_acc=64.42% train_bacc=50.15% train_auc=0.8633 train_f1=0.5033 | val_loss=1.1681 val_acc=69.13% val_bacc=50.77% val_auc=0.9217 val_f1=0.5338
# transformer_meta_only train epoch 23/25:   0%|          | 0/8 [00:00<?, ?it/s]
# transformer_meta_only val epoch 23/25:   0%|          | 0/1 [00:00<?, ?it/s]
# Epoch 023/25 | train_loss=1.2298 train_acc=63.87% train_bacc=51.14% train_auc=0.8631 train_f1=0.5092 | val_loss=1.1552 val_acc=71.30% val_bacc=52.85% val_auc=0.9241 val_f1=0.5333
# transformer_meta_only train epoch 24/25:   0%|          | 0/8 [00:00<?, ?it/s]
# transformer_meta_only val epoch 24/25:   0%|          | 0/1 [00:00<?, ?it/s]
# Epoch 024/25 | train_loss=1.2001 train_acc=65.18% train_bacc=52.45% train_auc=0.8761 train_f1=0.5307 | val_loss=1.1395 val_acc=71.30% val_bacc=52.60% val_auc=0.9262 val_f1=0.5461
# transformer_meta_only train epoch 25/25:   0%|          | 0/8 [00:00<?, ?it/s]
# transformer_meta_only val epoch 25/25:   0%|          | 0/1 [00:00<?, ?it/s]
# Epoch 025/25 | train_loss=1.1880 train_acc=65.83% train_bacc=51.75% train_auc=0.8766 train_f1=0.5222 | val_loss=1.1234 val_acc=70.43% val_bacc=51.55% val_auc=0.9278 val_f1=0.5250
# transformer_meta_only test:   0%|          | 0/1 [00:00<?, ?it/s]
# wandb: WARNING Saving files without folders. If you want to preserve subdirectories pass base_path to wandb.save, i.e. wandb.save("/mnt/folder/file.h5", base_path="/mnt")
# wandb: WARNING Symlinked 1 file into the W&B run directory; call wandb.save again to sync new files.
# wandb: WARNING Symlinked 1 file into the W&B run directory; call wandb.save again to sync new files.
# wandb: WARNING Symlinked 1 file into the W&B run directory; call wandb.save again to sync new files.
# wandb: WARNING Symlinked 1 file into the W&B run directory; call wandb.save again to sync new files.
# wandb: WARNING Symlinked 1 file into the W&B run directory; call wandb.save again to sync new files.
# wandb: updating run metadata
# wandb: uploading history steps 0-53, summary, console lines 1-32
# wandb:
# wandb: Run history:
# wandb:                elapsed_sec ▁▁▂▂▂▂▃▃▃▄▄▄▄▅▅▅▆▆▆▆▇▇▇██
# wandb:                      epoch ▁▁▁▁▂▂▂▂▂▂▃▃▃▃▃▄▄▄▄▄▅▅▅▅▅▅▆▆▆▆▇▇▇▇▇▇▇███
# wandb: epochs_without_improvement ▁▁▁▁▅█▁▁▁▁▁▁▁▁▁▁▁▁▁▅▁▅█▁▅
# wandb:                         lr ▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁
# wandb:                  train_acc ▁▃▄▄▄▅▅▅▆▆▆▆▇▇▇▇▇▇▇▇█████
# wandb:                  train_auc ▁▂▂▂▃▄▄▄▅▆▆▆▆▆▇▇▇▇▇██████
# wandb:                 train_bacc ▁▁▁▂▃▃▃▄▄▅▅▅▆▆▆▆▇▆▇▇▇████
# wandb:             train_f1_macro ▁▃▃▃▄▄▄▅▅▆▆▆▆▇▇▇▇▆▇▇▇████
# wandb:                 train_loss █▅▅▄▄▃▃▃▃▃▂▂▂▂▂▂▂▂▁▁▁▁▁▁▁
# wandb:                    val_acc ▁▆▆▆▆▆▆▆▇▇▇▇▇▇▇▇▇████████
# wandb:                         +4 ...
# wandb:
# wandb: Run summary:
# wandb:                 best_epoch 24
# wandb:               best_val_acc 71.30435
# wandb:               best_val_auc 0.92615
# wandb:              best_val_bacc 52.59512
# wandb:          best_val_f1_macro 0.54607
# wandb:                elapsed_sec 7.27509
# wandb:                      epoch 25
# wandb: epochs_without_improvement 1
# wandb:                         lr 0.0005
# wandb:                   test_acc 76.08696
# wandb:                        +13 ...
# wandb:
# wandb: 🚀 View run transformer_meta_only at: https://wandb.ai/belalofficial123-the-british-university-in-egypt/iot%20fusion/runs/3f16am25
# wandb: ⭐️ View project at: https://wandb.ai/belalofficial123-the-british-university-in-egypt/iot%20fusion
# wandb: Synced 5 W&B file(s), 4 media file(s), 0 artifact file(s) and 5 other file(s)
# wandb: Find logs at: ./wandb/run-20260416_192718-3f16am25/logs
# Test performance:
# test_loss=1.0792 test_acc=76.09% test_bacc=53.95% test_auc=0.9336 test_f1=0.5186
# Classification report:
#               precision    recall  f1-score    support
# ACK            0.888889  0.767123  0.823529   73.00000
# BCC            0.705882  0.988235  0.823529   85.00000
# MEL            0.000000  0.000000  0.000000    5.00000
# NEV            0.733333  0.916667  0.814815   24.00000
# SCC            0.000000  0.000000  0.000000   20.00000
# SEK            0.764706  0.565217  0.650000   23.00000
# accuracy       0.760870  0.760870  0.760870    0.76087
# macro avg      0.515468  0.539540  0.518646  230.00000
# weighted avg   0.695987  0.760870  0.715753  230.00000
# transformer_meta_only complete: best_epoch=24, test_acc=76.09%
# {'experiment_name': 'transformer_meta_only',
#  'model_name': 'transformer',
#  'input_mode': 'metadata_only',
#  'epochs': 25,
#  'batch_size': 256,
#  'split': '80 train / 10 validation / 10 test',
#  'augment_train': True,
#  'class_weighted_loss': True,
#  'class_weight_power': 0.5,
#  'class_balanced_sampler': False,
#  'best_epoch': 24,
#  'best_val_acc': 71.30434782608695,
#  'best_val_bacc': 52.595120792849706,
#  'best_val_auc': 0.9261522266848647,
#  'best_val_f1_macro': 0.5460692427112409,
#  'final_train_loss': 1.1880289356389424,
#  'final_train_acc': 65.83242655059848,
#  'final_train_bacc': 51.75495637423811,
#  'final_train_auc': 0.8765706722623268,
#  'final_train_f1_macro': 0.5222377089175844,
#  'final_val_loss': 1.12339448928833,
#  'final_val_acc': 70.43478260869566,
#  'final_val_bacc': 51.54941291585128,
#  'final_val_auc': 0.9277866046057809,
#  'final_val_f1_macro': 0.5250093553116698,
#  'test_loss': 1.079239010810852,
#  'test_acc': 76.08695652173914,
#  'test_bacc': 53.954043995998234,
#  'test_auc': 0.9336149230666551,
#  'test_f1_macro': 0.5186456063907045,
#  'elapsed_sec': 7.275094032287598,
#  'metrics_path': '/home/zeus/content/IOT_fusion/Results_Logs/transformer_meta_only/epoch_metrics.csv',
#  'epoch_log_path': '/home/zeus/content/IOT_fusion/Results_Logs/transformer_meta_only/epoch_log.txt',
#  'split_summary_path': '/home/zeus/content/IOT_fusion/Results_Logs/transformer_meta_only/split_summary.csv',
#  'checkpoint_path': '/home/zeus/content/IOT_fusion/outputs/ablations/transformer_meta_only_best.pth',
#  'classification_report_path': '/home/zeus/content/IOT_fusion/Results_Logs/transformer_meta_only/classification_report.csv',
#  'confusion_matrix_path': '/home/zeus/content/IOT_fusion/Results_Logs/transformer_meta_only/confusion_matrix.csv',
#  'test_predictions_path': '/home/zeus/content/IOT_fusion/Results_Logs/transformer_meta_only/test_predictions.csv',
#  'loss_curve_path': '/home/zeus/content/IOT_fusion/Results_Figures/transformer_meta_only/loss_curve.png',
#  'epoch_metrics_curve_path': '/home/zeus/content/IOT_fusion/Results_Figures/transformer_meta_only/epoch_metrics.png',
#  'confusion_matrix_plot_path': '/home/zeus/content/IOT_fusion/Results_Figures/transformer_meta_only/confusion_matrix.png',
#  'roc_curve_path': '/home/zeus/content/IOT_fusion/Results_Figures/transformer_meta_only/roc_curve.png',
#  'xai_paths': "{'metadata_importance': '/home/zeus/content/IOT_fusion/Results_XAI/transformer_meta_only/transformer_meta_only_metadata_xai_top20.csv'}"}

# %% [markdown]
# ## Training Outputs

# %%
from pathlib import Path
output_dir = Path('outputs/ablations')
logs_dir = Path('Results_Logs') / 'transformer_meta_only'
figures_dir = Path('Results_Figures') / 'transformer_meta_only'
xai_dir = Path('Results_XAI') / 'transformer_meta_only'
print('metrics:', logs_dir / 'epoch_metrics.csv')
print('epoch log:', logs_dir / 'epoch_log.txt')
print('result:', logs_dir / 'result_summary.csv')
print('checkpoint:', output_dir / 'transformer_meta_only_best.pth')
print('classification report:', logs_dir / 'classification_report.csv')
print('confusion matrix CSV:', logs_dir / 'confusion_matrix.csv')
print('loss curve:', figures_dir / 'loss_curve.png')
print('roc curve:', figures_dir / 'roc_curve.png')
sorted(str(p) for p in list(logs_dir.glob('*')) + list(figures_dir.glob('*')) + list(xai_dir.glob('*')))
# Out:
# metrics: Results_Logs/transformer_meta_only/epoch_metrics.csv
# epoch log: Results_Logs/transformer_meta_only/epoch_log.txt
# result: Results_Logs/transformer_meta_only/result_summary.csv
# checkpoint: outputs/ablations/transformer_meta_only_best.pth
# classification report: Results_Logs/transformer_meta_only/classification_report.csv
# confusion matrix CSV: Results_Logs/transformer_meta_only/confusion_matrix.csv
# loss curve: Results_Figures/transformer_meta_only/loss_curve.png
# roc curve: Results_Figures/transformer_meta_only/roc_curve.png
# ['Results_Figures/transformer_meta_only/confusion_matrix.png',
#  'Results_Figures/transformer_meta_only/epoch_metrics.png',
#  'Results_Figures/transformer_meta_only/loss_curve.png',
#  'Results_Figures/transformer_meta_only/roc_curve.png',
#  'Results_Logs/transformer_meta_only/classification_report.csv',
#  'Results_Logs/transformer_meta_only/confusion_matrix.csv',
#  'Results_Logs/transformer_meta_only/epoch_log.txt',
#  'Results_Logs/transformer_meta_only/epoch_metrics.csv',
#  'Results_Logs/transformer_meta_only/result_summary.csv',
#  'Results_Logs/transformer_meta_only/split_summary.csv',
#  'Results_Logs/transformer_meta_only/test_predictions.csv',
#  'Results_XAI/transformer_meta_only/transformer_meta_only_metadata_xai_top20.csv']
