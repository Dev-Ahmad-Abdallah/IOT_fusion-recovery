# %% [markdown]
# # TRANSFORMER Late Fusion Ablation
#
# Experiment: `transformer_late_fusion`
#
# This notebook runs full GPU training on a stratified 80/10/10 train/validation/test split built from the extracted processed tabular data and image tensors. Image runs use tensor-safe train augmentation and class-weighted loss. CNN runs use tempered class-weighted loss, stronger paper-style augmentation, and early stopping to reduce overfitting; balanced sampling can be enabled manually, but is off by default because it over-corrected on this dataset. Fusion modes combine the tabular metadata vector with the image tensor. It prints per-epoch train/validation loss, accuracy, macro AUC, and macro F1 with tqdm progress bars. Epoch logs are written under `Results_Logs/<experiment>/`, figures under `Results_Figures/<experiment>/`, and XAI artifacts under `Results_XAI/<experiment>/`.

# %%
from pathlib import Path
import os, sys
REPO_ROOT = Path('/home/zeus/content/IOT_fusion')
os.chdir(REPO_ROOT)
sys.path.insert(0, str(REPO_ROOT / 'training'))
from ablation_utils import get_data_info, run_training

info = get_data_info()
print('classes:', info.class_to_idx)
print('metadata_dim:', info.metadata_dim)
# Out:
# classes: {'ACK': 0, 'BCC': 1, 'MEL': 2, 'NEV': 3, 'SCC': 4, 'SEK': 5}
# metadata_dim: 87

# %% [markdown]
# ## Full GPU Training
# Adjust `epochs` and `batch_size` if needed.

# %%
full_result = run_training(
    model_name='transformer',
    input_mode='late_fusion',
    experiment_name='transformer_late_fusion',
    epochs=25,
    batch_size=256,
    lr=0.0005,
    num_workers=2,
    device_name='cuda',
    wandb_enabled=True,
    xai_enabled=True,
    augment_train=True,
    class_weighted_loss=True,
    class_weight_power=0.5,
    class_balanced_sampler=False,
    early_stopping_patience=12,
    min_epochs=15,
)
full_result
# Out:
# wandb: [wandb.login()] Loaded credentials for https://api.wandb.ai from WANDB_API_KEY.
# wandb: Currently logged in as: belalofficial123 (belalofficial123-the-british-university-in-egypt) to https://api.wandb.ai. Use `wandb login --relogin` to force relogin
# wandb: Tracking run with wandb version 0.26.0
# wandb: Run data is saved locally in /home/zeus/content/IOT_fusion/wandb/run-20260416_193234-1kxpx5j8
# wandb: Run `wandb offline` to turn off syncing.
# wandb: Syncing run transformer_late_fusion
# wandb: ⭐️ View project at https://wandb.ai/belalofficial123-the-british-university-in-egypt/iot%20fusion
# wandb: 🚀 View run at https://wandb.ai/belalofficial123-the-british-university-in-egypt/iot%20fusion/runs/1kxpx5j8
# Split sizes: {'train': 1838, 'val': 230, 'test': 230}
# Class mapping: {'ACK': 0, 'BCC': 1, 'MEL': 2, 'NEV': 3, 'SCC': 4, 'SEK': 5}
# /home/zeus/miniconda3/envs/cloudspace/lib/python3.12/site-packages/torch/nn/modules/transformer.py:392: UserWarning: enable_nested_tensor is True, but self.use_nested_tensor is False because encoder_layer.norm_first was True
#   warnings.warn(
# transformer_late_fusion train epoch 1/25:   0%|          | 0/8 [00:00<?, ?it/s]
# transformer_late_fusion val epoch 1/25:   0%|          | 0/1 [00:00<?, ?it/s]
# Epoch 001/25 | train_loss=2.2980 train_acc=25.79% train_bacc=18.12% train_auc=0.5093 train_f1=0.1810 | val_loss=1.7939 val_acc=34.35% val_bacc=18.78% val_auc=0.6102 val_f1=0.1525
# transformer_late_fusion train epoch 2/25:   0%|          | 0/8 [00:00<?, ?it/s]
# transformer_late_fusion val epoch 2/25:   0%|          | 0/1 [00:00<?, ?it/s]
# Epoch 002/25 | train_loss=1.8372 train_acc=28.07% train_bacc=19.65% train_auc=0.5660 train_f1=0.1948 | val_loss=1.7569 val_acc=32.61% val_bacc=18.43% val_auc=0.6065 val_f1=0.1588
# transformer_late_fusion train epoch 3/25:   0%|          | 0/8 [00:00<?, ?it/s]
# transformer_late_fusion val epoch 3/25:   0%|          | 0/1 [00:00<?, ?it/s]
# Epoch 003/25 | train_loss=1.7566 train_acc=38.74% train_bacc=25.74% train_auc=0.5997 train_f1=0.2479 | val_loss=1.6427 val_acc=37.83% val_bacc=25.96% val_auc=0.7143 val_f1=0.1933
# transformer_late_fusion train epoch 4/25:   0%|          | 0/8 [00:00<?, ?it/s]
# transformer_late_fusion val epoch 4/25:   0%|          | 0/1 [00:00<?, ?it/s]
# Epoch 004/25 | train_loss=1.6818 train_acc=38.25% train_bacc=28.72% train_auc=0.6451 train_f1=0.2846 | val_loss=1.6181 val_acc=52.61% val_bacc=28.84% val_auc=0.7737 val_f1=0.2659
# transformer_late_fusion train epoch 5/25:   0%|          | 0/8 [00:00<?, ?it/s]
# transformer_late_fusion val epoch 5/25:   0%|          | 0/1 [00:00<?, ?it/s]
# Epoch 005/25 | train_loss=1.6419 train_acc=45.43% train_bacc=30.42% train_auc=0.6700 train_f1=0.3064 | val_loss=1.5636 val_acc=57.83% val_bacc=40.93% val_auc=0.7858 val_f1=0.3656
# transformer_late_fusion train epoch 6/25:   0%|          | 0/8 [00:00<?, ?it/s]
# transformer_late_fusion val epoch 6/25:   0%|          | 0/1 [00:00<?, ?it/s]
# Epoch 006/25 | train_loss=1.5760 train_acc=48.86% train_bacc=34.83% train_auc=0.7178 train_f1=0.3409 | val_loss=1.5052 val_acc=58.26% val_bacc=45.52% val_auc=0.8112 val_f1=0.4041
# transformer_late_fusion train epoch 7/25:   0%|          | 0/8 [00:00<?, ?it/s]
# transformer_late_fusion val epoch 7/25:   0%|          | 0/1 [00:00<?, ?it/s]
# Epoch 007/25 | train_loss=1.5149 train_acc=52.29% train_bacc=41.93% train_auc=0.7570 train_f1=0.3946 | val_loss=1.4613 val_acc=63.04% val_bacc=48.77% val_auc=0.8325 val_f1=0.4513
# transformer_late_fusion train epoch 8/25:   0%|          | 0/8 [00:00<?, ?it/s]
# transformer_late_fusion val epoch 8/25:   0%|          | 0/1 [00:00<?, ?it/s]
# Epoch 008/25 | train_loss=1.5000 train_acc=51.09% train_bacc=39.97% train_auc=0.7658 train_f1=0.3999 | val_loss=1.4175 val_acc=59.13% val_bacc=41.67% val_auc=0.8390 val_f1=0.3950
# transformer_late_fusion train epoch 9/25:   0%|          | 0/8 [00:00<?, ?it/s]
# transformer_late_fusion val epoch 9/25:   0%|          | 0/1 [00:00<?, ?it/s]
# Epoch 009/25 | train_loss=1.4537 train_acc=57.51% train_bacc=43.00% train_auc=0.7815 train_f1=0.4399 | val_loss=1.4019 val_acc=60.00% val_bacc=50.52% val_auc=0.8373 val_f1=0.4443
# transformer_late_fusion train epoch 10/25:   0%|          | 0/8 [00:00<?, ?it/s]
# transformer_late_fusion val epoch 10/25:   0%|          | 0/1 [00:00<?, ?it/s]
# Epoch 010/25 | train_loss=1.4211 train_acc=56.64% train_bacc=45.50% train_auc=0.8053 train_f1=0.4324 | val_loss=1.3440 val_acc=64.35% val_bacc=43.94% val_auc=0.8658 val_f1=0.4199
# transformer_late_fusion train epoch 11/25:   0%|          | 0/8 [00:00<?, ?it/s]
# transformer_late_fusion val epoch 11/25:   0%|          | 0/1 [00:00<?, ?it/s]
# Epoch 011/25 | train_loss=1.3698 train_acc=59.63% train_bacc=46.63% train_auc=0.8260 train_f1=0.4569 | val_loss=1.3292 val_acc=64.35% val_bacc=44.35% val_auc=0.8728 val_f1=0.4220
# transformer_late_fusion train epoch 12/25:   0%|          | 0/8 [00:00<?, ?it/s]
# transformer_late_fusion val epoch 12/25:   0%|          | 0/1 [00:00<?, ?it/s]
# Epoch 012/25 | train_loss=1.3676 train_acc=60.01% train_bacc=46.96% train_auc=0.8155 train_f1=0.4825 | val_loss=1.2934 val_acc=63.48% val_bacc=45.26% val_auc=0.8811 val_f1=0.4434
# transformer_late_fusion train epoch 13/25:   0%|          | 0/8 [00:00<?, ?it/s]
# transformer_late_fusion val epoch 13/25:   0%|          | 0/1 [00:00<?, ?it/s]
# Epoch 013/25 | train_loss=1.3406 train_acc=62.19% train_bacc=45.94% train_auc=0.8387 train_f1=0.4614 | val_loss=1.2788 val_acc=61.74% val_bacc=52.23% val_auc=0.8804 val_f1=0.4797
# transformer_late_fusion train epoch 14/25:   0%|          | 0/8 [00:00<?, ?it/s]
# transformer_late_fusion val epoch 14/25:   0%|          | 0/1 [00:00<?, ?it/s]
# Epoch 014/25 | train_loss=1.3069 train_acc=61.15% train_bacc=49.53% train_auc=0.8429 train_f1=0.5007 | val_loss=1.2730 val_acc=65.65% val_bacc=51.23% val_auc=0.8775 val_f1=0.4711
# transformer_late_fusion train epoch 15/25:   0%|          | 0/8 [00:00<?, ?it/s]
# transformer_late_fusion val epoch 15/25:   0%|          | 0/1 [00:00<?, ?it/s]
# Epoch 015/25 | train_loss=1.2687 train_acc=62.68% train_bacc=50.62% train_auc=0.8601 train_f1=0.4895 | val_loss=1.2370 val_acc=61.30% val_bacc=53.37% val_auc=0.8874 val_f1=0.4814
# transformer_late_fusion train epoch 16/25:   0%|          | 0/8 [00:00<?, ?it/s]
# transformer_late_fusion val epoch 16/25:   0%|          | 0/1 [00:00<?, ?it/s]
# Epoch 016/25 | train_loss=1.2670 train_acc=62.13% train_bacc=48.35% train_auc=0.8566 train_f1=0.4996 | val_loss=1.2119 val_acc=66.09% val_bacc=57.96% val_auc=0.8962 val_f1=0.5045
# transformer_late_fusion train epoch 17/25:   0%|          | 0/8 [00:00<?, ?it/s]
# transformer_late_fusion val epoch 17/25:   0%|          | 0/1 [00:00<?, ?it/s]
# Epoch 017/25 | train_loss=1.2382 train_acc=62.57% train_bacc=53.20% train_auc=0.8617 train_f1=0.5020 | val_loss=1.2379 val_acc=66.96% val_bacc=48.21% val_auc=0.8962 val_f1=0.4785
# transformer_late_fusion train epoch 18/25:   0%|          | 0/8 [00:00<?, ?it/s]
# transformer_late_fusion val epoch 18/25:   0%|          | 0/1 [00:00<?, ?it/s]
# Epoch 018/25 | train_loss=1.2424 train_acc=64.53% train_bacc=49.02% train_auc=0.8619 train_f1=0.4975 | val_loss=1.2014 val_acc=64.35% val_bacc=59.15% val_auc=0.8921 val_f1=0.5114
# transformer_late_fusion train epoch 19/25:   0%|          | 0/8 [00:00<?, ?it/s]
# transformer_late_fusion val epoch 19/25:   0%|          | 0/1 [00:00<?, ?it/s]
# Epoch 019/25 | train_loss=1.2133 train_acc=64.42% train_bacc=53.77% train_auc=0.8735 train_f1=0.5324 | val_loss=1.1852 val_acc=68.26% val_bacc=54.05% val_auc=0.9052 val_f1=0.5214
# transformer_late_fusion train epoch 20/25:   0%|          | 0/8 [00:00<?, ?it/s]
# transformer_late_fusion val epoch 20/25:   0%|          | 0/1 [00:00<?, ?it/s]
# Epoch 020/25 | train_loss=1.2106 train_acc=63.98% train_bacc=53.93% train_auc=0.8705 train_f1=0.5442 | val_loss=1.1461 val_acc=70.87% val_bacc=58.74% val_auc=0.9055 val_f1=0.5606
# transformer_late_fusion train epoch 21/25:   0%|          | 0/8 [00:00<?, ?it/s]
# transformer_late_fusion val epoch 21/25:   0%|          | 0/1 [00:00<?, ?it/s]
# Epoch 021/25 | train_loss=1.1975 train_acc=67.14% train_bacc=51.49% train_auc=0.8787 train_f1=0.5237 | val_loss=1.1659 val_acc=66.96% val_bacc=58.83% val_auc=0.8970 val_f1=0.5352
# transformer_late_fusion train epoch 22/25:   0%|          | 0/8 [00:00<?, ?it/s]
# transformer_late_fusion val epoch 22/25:   0%|          | 0/1 [00:00<?, ?it/s]
# Epoch 022/25 | train_loss=1.1682 train_acc=61.86% train_bacc=53.69% train_auc=0.8871 train_f1=0.5283 | val_loss=1.1568 val_acc=71.30% val_bacc=54.74% val_auc=0.9068 val_f1=0.5281
# transformer_late_fusion train epoch 23/25:   0%|          | 0/8 [00:00<?, ?it/s]
# transformer_late_fusion val epoch 23/25:   0%|          | 0/1 [00:00<?, ?it/s]
# Epoch 023/25 | train_loss=1.1666 train_acc=68.17% train_bacc=53.49% train_auc=0.8811 train_f1=0.5399 | val_loss=1.1454 val_acc=67.83% val_bacc=59.29% val_auc=0.9035 val_f1=0.5416
# transformer_late_fusion train epoch 24/25:   0%|          | 0/8 [00:00<?, ?it/s]
# transformer_late_fusion val epoch 24/25:   0%|          | 0/1 [00:00<?, ?it/s]
# Epoch 024/25 | train_loss=1.1416 train_acc=68.28% train_bacc=54.41% train_auc=0.8941 train_f1=0.5658 | val_loss=1.1169 val_acc=66.96% val_bacc=64.80% val_auc=0.9143 val_f1=0.5844
# transformer_late_fusion train epoch 25/25:   0%|          | 0/8 [00:00<?, ?it/s]
# transformer_late_fusion val epoch 25/25:   0%|          | 0/1 [00:00<?, ?it/s]
# Epoch 025/25 | train_loss=1.1181 train_acc=69.31% train_bacc=58.44% train_auc=0.8977 train_f1=0.5925 | val_loss=1.1084 val_acc=70.87% val_bacc=60.91% val_auc=0.9147 val_f1=0.5633
# transformer_late_fusion test:   0%|          | 0/1 [00:00<?, ?it/s]
# wandb: WARNING Saving files without folders. If you want to preserve subdirectories pass base_path to wandb.save, i.e. wandb.save("/mnt/folder/file.h5", base_path="/mnt")
# wandb: WARNING Symlinked 1 file into the W&B run directory; call wandb.save again to sync new files.
# wandb: WARNING Symlinked 1 file into the W&B run directory; call wandb.save again to sync new files.
# wandb: WARNING Symlinked 1 file into the W&B run directory; call wandb.save again to sync new files.
# wandb: WARNING Symlinked 1 file into the W&B run directory; call wandb.save again to sync new files.
# wandb: WARNING Symlinked 1 file into the W&B run directory; call wandb.save again to sync new files.
# wandb: updating run metadata
# wandb:
# wandb: Run history:
# wandb:                elapsed_sec ▁▁▂▂▂▂▃▃▃▄▄▄▅▅▅▅▆▆▆▇▇▇▇██
# wandb:                      epoch ▁▁▁▁▂▂▂▂▂▂▃▃▃▃▄▄▄▄▄▅▅▅▅▅▅▆▆▆▆▆▇▇▇▇▇▇▇███
# wandb: epochs_without_improvement ▁▁▁▁▁▁▁▂▄▅▇█▁▂▁▁▂▁▁▁▂▄▅▁▂
# wandb:                         lr ▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁
# wandb:                  train_acc ▁▁▃▃▄▅▅▅▆▆▆▇▇▇▇▇▇▇▇▇█▇███
# wandb:                  train_auc ▁▂▃▃▄▅▅▆▆▆▇▇▇▇▇▇▇▇███████
# wandb:                 train_bacc ▁▁▂▃▃▄▅▅▅▆▆▆▆▆▇▆▇▆▇▇▇▇▇▇█
# wandb:             train_f1_macro ▁▁▂▃▃▄▅▅▅▅▆▆▆▆▆▆▆▆▇▇▇▇▇██
# wandb:                 train_loss █▅▅▄▄▄▃▃▃▃▂▂▂▂▂▂▂▂▂▂▁▁▁▁▁
# wandb:                    val_acc ▁▁▂▅▆▆▇▆▆▇▇▇▆▇▆▇▇▇▇█▇█▇▇█
# wandb:                         +4 ...
# wandb:
# wandb: Run summary:
# wandb:                 best_epoch 24
# wandb:               best_val_acc 66.95652
# wandb:               best_val_auc 0.91428
# wandb:              best_val_bacc 64.79884
# wandb:          best_val_f1_macro 0.5844
# wandb:                elapsed_sec 154.2362
# wandb:                      epoch 25
# wandb: epochs_without_improvement 1
# wandb:                         lr 0.0005
# wandb:                   test_acc 67.3913
# wandb:                        +13 ...
# wandb:
# wandb: 🚀 View run transformer_late_fusion at: https://wandb.ai/belalofficial123-the-british-university-in-egypt/iot%20fusion/runs/1kxpx5j8
# wandb: ⭐️ View project at: https://wandb.ai/belalofficial123-the-british-university-in-egypt/iot%20fusion
# wandb: Synced 5 W&B file(s), 4 media file(s), 0 artifact file(s) and 5 other file(s)
# wandb: Find logs at: ./wandb/run-20260416_193234-1kxpx5j8/logs
# Test performance:
# test_loss=1.0917 test_acc=67.39% test_bacc=59.18% test_auc=0.9140 test_f1=0.5658
# Classification report:
#               precision    recall  f1-score     support
# ACK            0.857143  0.739726  0.794118   73.000000
# BCC            0.789474  0.705882  0.745342   85.000000
# MEL            0.166667  0.400000  0.235294    5.000000
# NEV            0.740741  0.833333  0.784314   24.000000
# SCC            0.212121  0.350000  0.264151   20.000000
# SEK            0.631579  0.521739  0.571429   23.000000
# accuracy       0.673913  0.673913  0.673913    0.673913
# macro avg      0.566287  0.591780  0.565774  230.000000
# weighted avg   0.726333  0.673913  0.694567  230.000000
# transformer_late_fusion complete: best_epoch=24, test_acc=67.39%
# {'experiment_name': 'transformer_late_fusion',
#  'model_name': 'transformer',
#  'input_mode': 'late_fusion',
#  'epochs': 25,
#  'batch_size': 256,
#  'split': '80 train / 10 validation / 10 test',
#  'augment_train': True,
#  'class_weighted_loss': True,
#  'class_weight_power': 0.5,
#  'class_balanced_sampler': False,
#  'best_epoch': 24,
#  'best_val_acc': 66.95652173913044,
#  'best_val_bacc': 64.79883784804477,
#  'best_val_auc': 0.9142814986833278,
#  'best_val_f1_macro': 0.5844006481596972,
#  'final_train_loss': 1.118125248136925,
#  'final_train_acc': 69.31447225244831,
#  'final_train_bacc': 58.44102315737367,
#  'final_train_auc': 0.897663731361258,
#  'final_train_f1_macro': 0.5925354693435542,
#  'final_val_loss': 1.1083884239196777,
#  'final_val_acc': 70.86956521739131,
#  'final_val_bacc': 60.91388574175164,
#  'final_val_auc': 0.9146862611104553,
#  'final_val_f1_macro': 0.5632550425558838,
#  'test_loss': 1.09172523021698,
#  'test_acc': 67.3913043478261,
#  'test_bacc': 59.17801406844255,
#  'test_auc': 0.9140099343191967,
#  'test_f1_macro': 0.5657744366546181,
#  'elapsed_sec': 154.23620128631592,
#  'metrics_path': '/home/zeus/content/IOT_fusion/Results_Logs/transformer_late_fusion/epoch_metrics.csv',
#  'epoch_log_path': '/home/zeus/content/IOT_fusion/Results_Logs/transformer_late_fusion/epoch_log.txt',
#  'split_summary_path': '/home/zeus/content/IOT_fusion/Results_Logs/transformer_late_fusion/split_summary.csv',
#  'checkpoint_path': '/home/zeus/content/IOT_fusion/outputs/ablations/transformer_late_fusion_best.pth',
#  'classification_report_path': '/home/zeus/content/IOT_fusion/Results_Logs/transformer_late_fusion/classification_report.csv',
#  'confusion_matrix_path': '/home/zeus/content/IOT_fusion/Results_Logs/transformer_late_fusion/confusion_matrix.csv',
#  'test_predictions_path': '/home/zeus/content/IOT_fusion/Results_Logs/transformer_late_fusion/test_predictions.csv',
#  'loss_curve_path': '/home/zeus/content/IOT_fusion/Results_Figures/transformer_late_fusion/loss_curve.png',
#  'epoch_metrics_curve_path': '/home/zeus/content/IOT_fusion/Results_Figures/transformer_late_fusion/epoch_metrics.png',
#  'confusion_matrix_plot_path': '/home/zeus/content/IOT_fusion/Results_Figures/transformer_late_fusion/confusion_matrix.png',
#  'roc_curve_path': '/home/zeus/content/IOT_fusion/Results_Figures/transformer_late_fusion/roc_curve.png',
#  'xai_paths': "{'image_saliency': '/home/zeus/content/IOT_fusion/Results_XAI/transformer_late_fusion/transformer_late_fusion_image_saliency.npy', 'metadata_importance': '/home/zeus/content/IOT_fusion/Results_XAI/transformer_late_fusion/transformer_late_fusion_metadata_xai_top20.csv'}"}

# %% [markdown]
# ## Training Outputs

# %%
from pathlib import Path
output_dir = Path('outputs/ablations')
logs_dir = Path('Results_Logs') / 'transformer_late_fusion'
figures_dir = Path('Results_Figures') / 'transformer_late_fusion'
xai_dir = Path('Results_XAI') / 'transformer_late_fusion'
print('metrics:', logs_dir / 'epoch_metrics.csv')
print('epoch log:', logs_dir / 'epoch_log.txt')
print('result:', logs_dir / 'result_summary.csv')
print('checkpoint:', output_dir / 'transformer_late_fusion_best.pth')
print('classification report:', logs_dir / 'classification_report.csv')
print('confusion matrix CSV:', logs_dir / 'confusion_matrix.csv')
print('loss curve:', figures_dir / 'loss_curve.png')
print('roc curve:', figures_dir / 'roc_curve.png')
sorted(str(p) for p in list(logs_dir.glob('*')) + list(figures_dir.glob('*')) + list(xai_dir.glob('*')))
# Out:
# metrics: Results_Logs/transformer_late_fusion/epoch_metrics.csv
# epoch log: Results_Logs/transformer_late_fusion/epoch_log.txt
# result: Results_Logs/transformer_late_fusion/result_summary.csv
# checkpoint: outputs/ablations/transformer_late_fusion_best.pth
# classification report: Results_Logs/transformer_late_fusion/classification_report.csv
# confusion matrix CSV: Results_Logs/transformer_late_fusion/confusion_matrix.csv
# loss curve: Results_Figures/transformer_late_fusion/loss_curve.png
# roc curve: Results_Figures/transformer_late_fusion/roc_curve.png
# ['Results_Figures/transformer_late_fusion/confusion_matrix.png',
#  'Results_Figures/transformer_late_fusion/epoch_metrics.png',
#  'Results_Figures/transformer_late_fusion/loss_curve.png',
#  'Results_Figures/transformer_late_fusion/roc_curve.png',
#  'Results_Logs/transformer_late_fusion/classification_report.csv',
#  'Results_Logs/transformer_late_fusion/confusion_matrix.csv',
#  'Results_Logs/transformer_late_fusion/epoch_log.txt',
#  'Results_Logs/transformer_late_fusion/epoch_metrics.csv',
#  'Results_Logs/transformer_late_fusion/result_summary.csv',
#  'Results_Logs/transformer_late_fusion/split_summary.csv',
#  'Results_Logs/transformer_late_fusion/test_predictions.csv',
#  'Results_XAI/transformer_late_fusion/transformer_late_fusion_image_saliency.npy',
#  'Results_XAI/transformer_late_fusion/transformer_late_fusion_metadata_xai_top20.csv']
