# %% [markdown]
# # CNN Early Fusion Ablation
#
# Experiment: `cnn_early_fusion`
#
# This notebook runs full GPU training on a stratified 80/10/10 train/validation/test split built from the extracted processed tabular data and image tensors. Image runs use tensor-safe train augmentation and class-weighted loss. CNN runs use tempered class-weighted loss, stronger paper-style augmentation, and early stopping to reduce overfitting; balanced sampling can be enabled manually, but is off by default because it over-corrected on this dataset. Fusion modes combine the tabular metadata vector with the image tensor. It prints per-epoch train/validation loss, accuracy, macro AUC, and macro F1 with tqdm progress bars. Epoch logs are written under `Results_Logs/<experiment>/`, figures under `Results_Figures/<experiment>/`, and XAI artifacts under `Results_XAI/<experiment>/`.

# %%
from pathlib import Path
import os, sys
REPO_ROOT = Path('/home/zeus/content/IOT_fusion')
os.chdir(REPO_ROOT)
sys.path.insert(0, str(REPO_ROOT / 'training'))
from ablation_utils import get_data_info, run_training

info = get_data_info()
print('classes:', info.class_to_idx)
print('metadata_dim:', info.metadata_dim)
# Out:
# classes: {'ACK': 0, 'BCC': 1, 'MEL': 2, 'NEV': 3, 'SCC': 4, 'SEK': 5}
# metadata_dim: 87

# %% [markdown]
# ## Full GPU Training
# Adjust `epochs` and `batch_size` if needed.

# %%
full_result = run_training(
    model_name='cnn',
    input_mode='early_fusion',
    experiment_name='cnn_early_fusion',
    epochs=60,
    batch_size=64,
    lr=0.0003,
    num_workers=2,
    device_name='cuda',
    wandb_enabled=True,
    xai_enabled=True,
    augment_train=True,
    class_weighted_loss=True,
    class_weight_power=0.5,
    class_balanced_sampler=False,
    early_stopping_patience=12,
    min_epochs=15,
)
full_result
# Out:
# wandb: [wandb.login()] Loaded credentials for https://api.wandb.ai from WANDB_API_KEY.
# wandb: Currently logged in as: belalofficial123 (belalofficial123-the-british-university-in-egypt) to https://api.wandb.ai. Use `wandb login --relogin` to force relogin
# wandb: Tracking run with wandb version 0.26.0
# wandb: Run data is saved locally in /home/zeus/content/IOT_fusion/wandb/run-20260416_191204-zt5k3wnk
# wandb: Run `wandb offline` to turn off syncing.
# wandb: Syncing run cnn_early_fusion
# wandb: ⭐️ View project at https://wandb.ai/belalofficial123-the-british-university-in-egypt/iot%20fusion
# wandb: 🚀 View run at https://wandb.ai/belalofficial123-the-british-university-in-egypt/iot%20fusion/runs/zt5k3wnk
# Split sizes: {'train': 1838, 'val': 230, 'test': 230}
# Class mapping: {'ACK': 0, 'BCC': 1, 'MEL': 2, 'NEV': 3, 'SCC': 4, 'SEK': 5}
# cnn_early_fusion train epoch 1/60:   0%|          | 0/29 [00:00<?, ?it/s]
# cnn_early_fusion val epoch 1/60:   0%|          | 0/4 [00:00<?, ?it/s]
# Epoch 001/60 | train_loss=2.0605 train_acc=23.72% train_bacc=18.65% train_auc=0.5180 train_f1=0.1757 | val_loss=1.8141 val_acc=32.17% val_bacc=17.77% val_auc=0.5841 val_f1=0.1028
# cnn_early_fusion train epoch 2/60:   0%|          | 0/29 [00:00<?, ?it/s]
# cnn_early_fusion val epoch 2/60:   0%|          | 0/4 [00:00<?, ?it/s]
# Epoch 002/60 | train_loss=1.8681 train_acc=29.43% train_bacc=20.97% train_auc=0.5559 train_f1=0.2050 | val_loss=1.7440 val_acc=31.74% val_bacc=22.31% val_auc=0.6681 val_f1=0.1722
# cnn_early_fusion train epoch 3/60:   0%|          | 0/29 [00:00<?, ?it/s]
# cnn_early_fusion val epoch 3/60:   0%|          | 0/4 [00:00<?, ?it/s]
# Epoch 003/60 | train_loss=1.8358 train_acc=32.97% train_bacc=23.10% train_auc=0.5749 train_f1=0.2272 | val_loss=1.7379 val_acc=35.22% val_bacc=20.85% val_auc=0.6601 val_f1=0.1813
# cnn_early_fusion train epoch 4/60:   0%|          | 0/29 [00:00<?, ?it/s]
# cnn_early_fusion val epoch 4/60:   0%|          | 0/4 [00:00<?, ?it/s]
# Epoch 004/60 | train_loss=1.8335 train_acc=31.88% train_bacc=22.02% train_auc=0.5822 train_f1=0.2193 | val_loss=1.7335 val_acc=40.87% val_bacc=30.11% val_auc=0.6594 val_f1=0.2273
# cnn_early_fusion train epoch 5/60:   0%|          | 0/29 [00:00<?, ?it/s]
# cnn_early_fusion val epoch 5/60:   0%|          | 0/4 [00:00<?, ?it/s]
# Epoch 005/60 | train_loss=1.8074 train_acc=32.32% train_bacc=25.21% train_auc=0.5971 train_f1=0.2387 | val_loss=1.6797 val_acc=38.70% val_bacc=23.75% val_auc=0.6841 val_f1=0.2163
# cnn_early_fusion train epoch 6/60:   0%|          | 0/29 [00:00<?, ?it/s]
# cnn_early_fusion val epoch 6/60:   0%|          | 0/4 [00:00<?, ?it/s]
# Epoch 006/60 | train_loss=1.7931 train_acc=34.87% train_bacc=24.60% train_auc=0.6049 train_f1=0.2459 | val_loss=1.6478 val_acc=41.74% val_bacc=36.66% val_auc=0.7184 val_f1=0.2923
# cnn_early_fusion train epoch 7/60:   0%|          | 0/29 [00:00<?, ?it/s]
# cnn_early_fusion val epoch 7/60:   0%|          | 0/4 [00:00<?, ?it/s]
# Epoch 007/60 | train_loss=1.7550 train_acc=36.67% train_bacc=26.45% train_auc=0.6263 train_f1=0.2547 | val_loss=1.6688 val_acc=48.26% val_bacc=31.77% val_auc=0.7019 val_f1=0.3172
# cnn_early_fusion train epoch 8/60:   0%|          | 0/29 [00:00<?, ?it/s]
# cnn_early_fusion val epoch 8/60:   0%|          | 0/4 [00:00<?, ?it/s]
# Epoch 008/60 | train_loss=1.7437 train_acc=38.08% train_bacc=25.97% train_auc=0.6285 train_f1=0.2539 | val_loss=1.6105 val_acc=45.65% val_bacc=28.37% val_auc=0.7400 val_f1=0.2663
# cnn_early_fusion train epoch 9/60:   0%|          | 0/29 [00:00<?, ?it/s]
# cnn_early_fusion val epoch 9/60:   0%|          | 0/4 [00:00<?, ?it/s]
# Epoch 009/60 | train_loss=1.7453 train_acc=35.04% train_bacc=24.43% train_auc=0.6317 train_f1=0.2441 | val_loss=1.6134 val_acc=35.22% val_bacc=20.83% val_auc=0.7173 val_f1=0.1822
# cnn_early_fusion train epoch 10/60:   0%|          | 0/29 [00:00<?, ?it/s]
# cnn_early_fusion val epoch 10/60:   0%|          | 0/4 [00:00<?, ?it/s]
# Epoch 010/60 | train_loss=1.6796 train_acc=40.53% train_bacc=29.12% train_auc=0.6613 train_f1=0.2869 | val_loss=1.5832 val_acc=48.26% val_bacc=34.12% val_auc=0.7204 val_f1=0.3280
# cnn_early_fusion train epoch 11/60:   0%|          | 0/29 [00:00<?, ?it/s]
# cnn_early_fusion val epoch 11/60:   0%|          | 0/4 [00:00<?, ?it/s]
# Epoch 011/60 | train_loss=1.6511 train_acc=40.59% train_bacc=28.92% train_auc=0.6707 train_f1=0.2867 | val_loss=1.5280 val_acc=46.52% val_bacc=40.26% val_auc=0.7650 val_f1=0.3832
# cnn_early_fusion train epoch 12/60:   0%|          | 0/29 [00:00<?, ?it/s]
# cnn_early_fusion val epoch 12/60:   0%|          | 0/4 [00:00<?, ?it/s]
# Epoch 012/60 | train_loss=1.6495 train_acc=41.13% train_bacc=30.40% train_auc=0.6845 train_f1=0.3023 | val_loss=1.5199 val_acc=43.04% val_bacc=35.24% val_auc=0.7784 val_f1=0.3543
# cnn_early_fusion train epoch 13/60:   0%|          | 0/29 [00:00<?, ?it/s]
# cnn_early_fusion val epoch 13/60:   0%|          | 0/4 [00:00<?, ?it/s]
# Epoch 013/60 | train_loss=1.6189 train_acc=43.63% train_bacc=32.40% train_auc=0.6902 train_f1=0.3223 | val_loss=1.5051 val_acc=51.30% val_bacc=39.91% val_auc=0.7719 val_f1=0.4058
# cnn_early_fusion train epoch 14/60:   0%|          | 0/29 [00:00<?, ?it/s]
# cnn_early_fusion val epoch 14/60:   0%|          | 0/4 [00:00<?, ?it/s]
# Epoch 014/60 | train_loss=1.5933 train_acc=45.38% train_bacc=32.50% train_auc=0.7055 train_f1=0.3325 | val_loss=1.4415 val_acc=54.78% val_bacc=43.15% val_auc=0.7995 val_f1=0.4192
# cnn_early_fusion train epoch 15/60:   0%|          | 0/29 [00:00<?, ?it/s]
# cnn_early_fusion val epoch 15/60:   0%|          | 0/4 [00:00<?, ?it/s]
# Epoch 015/60 | train_loss=1.6047 train_acc=44.07% train_bacc=32.87% train_auc=0.7016 train_f1=0.3267 | val_loss=1.4333 val_acc=53.04% val_bacc=39.67% val_auc=0.8051 val_f1=0.3743
# cnn_early_fusion train epoch 16/60:   0%|          | 0/29 [00:00<?, ?it/s]
# cnn_early_fusion val epoch 16/60:   0%|          | 0/4 [00:00<?, ?it/s]
# Epoch 016/60 | train_loss=1.5638 train_acc=46.46% train_bacc=33.51% train_auc=0.7214 train_f1=0.3391 | val_loss=1.4156 val_acc=54.78% val_bacc=42.75% val_auc=0.8163 val_f1=0.4126
# cnn_early_fusion train epoch 17/60:   0%|          | 0/29 [00:00<?, ?it/s]
# cnn_early_fusion val epoch 17/60:   0%|          | 0/4 [00:00<?, ?it/s]
# Epoch 017/60 | train_loss=1.5701 train_acc=46.46% train_bacc=33.88% train_auc=0.7165 train_f1=0.3397 | val_loss=1.4025 val_acc=59.57% val_bacc=43.79% val_auc=0.8194 val_f1=0.4019
# cnn_early_fusion train epoch 18/60:   0%|          | 0/29 [00:00<?, ?it/s]
# cnn_early_fusion val epoch 18/60:   0%|          | 0/4 [00:00<?, ?it/s]
# Epoch 018/60 | train_loss=1.5678 train_acc=46.41% train_bacc=33.80% train_auc=0.7233 train_f1=0.3382 | val_loss=1.4260 val_acc=57.83% val_bacc=44.05% val_auc=0.7999 val_f1=0.3923
# cnn_early_fusion train epoch 19/60:   0%|          | 0/29 [00:00<?, ?it/s]
# cnn_early_fusion val epoch 19/60:   0%|          | 0/4 [00:00<?, ?it/s]
# Epoch 019/60 | train_loss=1.5537 train_acc=46.74% train_bacc=34.89% train_auc=0.7216 train_f1=0.3470 | val_loss=1.4036 val_acc=55.22% val_bacc=36.47% val_auc=0.8196 val_f1=0.3383
# cnn_early_fusion train epoch 20/60:   0%|          | 0/29 [00:00<?, ?it/s]
# cnn_early_fusion val epoch 20/60:   0%|          | 0/4 [00:00<?, ?it/s]
# Epoch 020/60 | train_loss=1.5415 train_acc=46.74% train_bacc=34.68% train_auc=0.7230 train_f1=0.3396 | val_loss=1.3929 val_acc=56.09% val_bacc=46.14% val_auc=0.8158 val_f1=0.4202
# cnn_early_fusion train epoch 21/60:   0%|          | 0/29 [00:00<?, ?it/s]
# cnn_early_fusion val epoch 21/60:   0%|          | 0/4 [00:00<?, ?it/s]
# Epoch 021/60 | train_loss=1.4972 train_acc=48.97% train_bacc=38.08% train_auc=0.7612 train_f1=0.3844 | val_loss=1.3933 val_acc=58.26% val_bacc=44.52% val_auc=0.8219 val_f1=0.4561
# cnn_early_fusion train epoch 22/60:   0%|          | 0/29 [00:00<?, ?it/s]
# cnn_early_fusion val epoch 22/60:   0%|          | 0/4 [00:00<?, ?it/s]
# Epoch 022/60 | train_loss=1.4762 train_acc=50.98% train_bacc=36.89% train_auc=0.7818 train_f1=0.3661 | val_loss=1.3945 val_acc=54.78% val_bacc=40.59% val_auc=0.8109 val_f1=0.3876
# cnn_early_fusion train epoch 23/60:   0%|          | 0/29 [00:00<?, ?it/s]
# cnn_early_fusion val epoch 23/60:   0%|          | 0/4 [00:00<?, ?it/s]
# Epoch 023/60 | train_loss=1.4151 train_acc=51.20% train_bacc=41.20% train_auc=0.8040 train_f1=0.4072 | val_loss=1.3408 val_acc=54.78% val_bacc=49.41% val_auc=0.8360 val_f1=0.4332
# cnn_early_fusion train epoch 24/60:   0%|          | 0/29 [00:00<?, ?it/s]
# cnn_early_fusion val epoch 24/60:   0%|          | 0/4 [00:00<?, ?it/s]
# Epoch 024/60 | train_loss=1.3837 train_acc=58.65% train_bacc=45.80% train_auc=0.8120 train_f1=0.4570 | val_loss=1.3886 val_acc=56.09% val_bacc=46.69% val_auc=0.8020 val_f1=0.4345
# cnn_early_fusion train epoch 25/60:   0%|          | 0/29 [00:00<?, ?it/s]
# cnn_early_fusion val epoch 25/60:   0%|          | 0/4 [00:00<?, ?it/s]
# Epoch 025/60 | train_loss=1.3675 train_acc=58.49% train_bacc=44.53% train_auc=0.8168 train_f1=0.4350 | val_loss=1.4041 val_acc=52.17% val_bacc=46.33% val_auc=0.8216 val_f1=0.3957
# cnn_early_fusion train epoch 26/60:   0%|          | 0/29 [00:00<?, ?it/s]
# cnn_early_fusion val epoch 26/60:   0%|          | 0/4 [00:00<?, ?it/s]
# Epoch 026/60 | train_loss=1.3297 train_acc=57.51% train_bacc=45.73% train_auc=0.8316 train_f1=0.4408 | val_loss=1.3811 val_acc=55.22% val_bacc=45.18% val_auc=0.8114 val_f1=0.4176
# cnn_early_fusion train epoch 27/60:   0%|          | 0/29 [00:00<?, ?it/s]
# cnn_early_fusion val epoch 27/60:   0%|          | 0/4 [00:00<?, ?it/s]
# Epoch 027/60 | train_loss=1.3226 train_acc=59.90% train_bacc=45.61% train_auc=0.8331 train_f1=0.4486 | val_loss=1.4099 val_acc=57.83% val_bacc=44.15% val_auc=0.8153 val_f1=0.4236
# cnn_early_fusion train epoch 28/60:   0%|          | 0/29 [00:00<?, ?it/s]
# cnn_early_fusion val epoch 28/60:   0%|          | 0/4 [00:00<?, ?it/s]
# Epoch 028/60 | train_loss=1.2767 train_acc=61.64% train_bacc=46.44% train_auc=0.8502 train_f1=0.4602 | val_loss=1.4268 val_acc=52.17% val_bacc=44.10% val_auc=0.8047 val_f1=0.4103
# cnn_early_fusion train epoch 29/60:   0%|          | 0/29 [00:00<?, ?it/s]
# cnn_early_fusion val epoch 29/60:   0%|          | 0/4 [00:00<?, ?it/s]
# Epoch 029/60 | train_loss=1.2487 train_acc=63.22% train_bacc=50.51% train_auc=0.8586 train_f1=0.4965 | val_loss=1.3857 val_acc=58.70% val_bacc=48.73% val_auc=0.8224 val_f1=0.4438
# cnn_early_fusion train epoch 30/60:   0%|          | 0/29 [00:00<?, ?it/s]
# cnn_early_fusion val epoch 30/60:   0%|          | 0/4 [00:00<?, ?it/s]
# Epoch 030/60 | train_loss=1.2521 train_acc=63.00% train_bacc=50.25% train_auc=0.8618 train_f1=0.5051 | val_loss=1.3222 val_acc=60.00% val_bacc=50.06% val_auc=0.8383 val_f1=0.4697
# cnn_early_fusion train epoch 31/60:   0%|          | 0/29 [00:00<?, ?it/s]
# cnn_early_fusion val epoch 31/60:   0%|          | 0/4 [00:00<?, ?it/s]
# Epoch 031/60 | train_loss=1.2315 train_acc=64.42% train_bacc=52.20% train_auc=0.8684 train_f1=0.5104 | val_loss=1.3938 val_acc=56.09% val_bacc=48.27% val_auc=0.8087 val_f1=0.4587
# cnn_early_fusion train epoch 32/60:   0%|          | 0/29 [00:00<?, ?it/s]
# cnn_early_fusion val epoch 32/60:   0%|          | 0/4 [00:00<?, ?it/s]
# Epoch 032/60 | train_loss=1.2135 train_acc=65.18% train_bacc=53.91% train_auc=0.8698 train_f1=0.5234 | val_loss=1.3296 val_acc=60.43% val_bacc=55.21% val_auc=0.8327 val_f1=0.5210
# cnn_early_fusion train epoch 33/60:   0%|          | 0/29 [00:00<?, ?it/s]
# cnn_early_fusion val epoch 33/60:   0%|          | 0/4 [00:00<?, ?it/s]
# Epoch 033/60 | train_loss=1.1959 train_acc=63.98% train_bacc=53.57% train_auc=0.8728 train_f1=0.5163 | val_loss=1.3247 val_acc=61.30% val_bacc=54.90% val_auc=0.8267 val_f1=0.5536
# cnn_early_fusion train epoch 34/60:   0%|          | 0/29 [00:00<?, ?it/s]
# cnn_early_fusion val epoch 34/60:   0%|          | 0/4 [00:00<?, ?it/s]
# Epoch 034/60 | train_loss=1.2067 train_acc=63.71% train_bacc=52.30% train_auc=0.8723 train_f1=0.5087 | val_loss=1.3978 val_acc=49.57% val_bacc=47.72% val_auc=0.8155 val_f1=0.4180
# cnn_early_fusion train epoch 35/60:   0%|          | 0/29 [00:00<?, ?it/s]
# cnn_early_fusion val epoch 35/60:   0%|          | 0/4 [00:00<?, ?it/s]
# Epoch 035/60 | train_loss=1.1723 train_acc=66.38% train_bacc=56.71% train_auc=0.8802 train_f1=0.5427 | val_loss=1.3955 val_acc=57.39% val_bacc=50.13% val_auc=0.8275 val_f1=0.4653
# cnn_early_fusion train epoch 36/60:   0%|          | 0/29 [00:00<?, ?it/s]
# cnn_early_fusion val epoch 36/60:   0%|          | 0/4 [00:00<?, ?it/s]
# Epoch 036/60 | train_loss=1.1592 train_acc=66.38% train_bacc=56.13% train_auc=0.8847 train_f1=0.5447 | val_loss=1.3910 val_acc=60.43% val_bacc=54.71% val_auc=0.8212 val_f1=0.5173
# cnn_early_fusion train epoch 37/60:   0%|          | 0/29 [00:00<?, ?it/s]
# cnn_early_fusion val epoch 37/60:   0%|          | 0/4 [00:00<?, ?it/s]
# Epoch 037/60 | train_loss=1.1712 train_acc=65.02% train_bacc=55.62% train_auc=0.8861 train_f1=0.5361 | val_loss=1.4227 val_acc=51.74% val_bacc=50.27% val_auc=0.8062 val_f1=0.4723
# cnn_early_fusion train epoch 38/60:   0%|          | 0/29 [00:00<?, ?it/s]
# cnn_early_fusion val epoch 38/60:   0%|          | 0/4 [00:00<?, ?it/s]
# Epoch 038/60 | train_loss=1.1658 train_acc=66.32% train_bacc=57.23% train_auc=0.8838 train_f1=0.5482 | val_loss=1.4299 val_acc=55.65% val_bacc=44.78% val_auc=0.8067 val_f1=0.4172
# cnn_early_fusion train epoch 39/60:   0%|          | 0/29 [00:00<?, ?it/s]
# cnn_early_fusion val epoch 39/60:   0%|          | 0/4 [00:00<?, ?it/s]
# Epoch 039/60 | train_loss=1.1213 train_acc=67.25% train_bacc=59.83% train_auc=0.8950 train_f1=0.5723 | val_loss=1.4457 val_acc=53.48% val_bacc=50.89% val_auc=0.8120 val_f1=0.4675
# cnn_early_fusion train epoch 40/60:   0%|          | 0/29 [00:00<?, ?it/s]
# cnn_early_fusion val epoch 40/60:   0%|          | 0/4 [00:00<?, ?it/s]
# Epoch 040/60 | train_loss=1.1107 train_acc=68.34% train_bacc=59.40% train_auc=0.8960 train_f1=0.5810 | val_loss=1.4257 val_acc=56.52% val_bacc=52.58% val_auc=0.8125 val_f1=0.4938
# cnn_early_fusion train epoch 41/60:   0%|          | 0/29 [00:00<?, ?it/s]
# cnn_early_fusion val epoch 41/60:   0%|          | 0/4 [00:00<?, ?it/s]
# Epoch 041/60 | train_loss=1.1054 train_acc=66.87% train_bacc=58.97% train_auc=0.9006 train_f1=0.5727 | val_loss=1.3870 val_acc=58.26% val_bacc=53.01% val_auc=0.8171 val_f1=0.4897
# cnn_early_fusion train epoch 42/60:   0%|          | 0/29 [00:00<?, ?it/s]
# cnn_early_fusion val epoch 42/60:   0%|          | 0/4 [00:00<?, ?it/s]
# Epoch 042/60 | train_loss=1.0840 train_acc=69.37% train_bacc=61.16% train_auc=0.9013 train_f1=0.5831 | val_loss=1.3692 val_acc=57.83% val_bacc=54.22% val_auc=0.8159 val_f1=0.4964
# cnn_early_fusion train epoch 43/60:   0%|          | 0/29 [00:00<?, ?it/s]
# cnn_early_fusion val epoch 43/60:   0%|          | 0/4 [00:00<?, ?it/s]
# Epoch 043/60 | train_loss=1.0571 train_acc=69.10% train_bacc=61.00% train_auc=0.9121 train_f1=0.5920 | val_loss=1.4678 val_acc=54.35% val_bacc=48.09% val_auc=0.8075 val_f1=0.4331
# cnn_early_fusion train epoch 44/60:   0%|          | 0/29 [00:00<?, ?it/s]
# cnn_early_fusion val epoch 44/60:   0%|          | 0/4 [00:00<?, ?it/s]
# Epoch 044/60 | train_loss=1.1018 train_acc=67.63% train_bacc=58.61% train_auc=0.8979 train_f1=0.5753 | val_loss=1.3722 val_acc=59.57% val_bacc=54.85% val_auc=0.8190 val_f1=0.5146
# cnn_early_fusion train epoch 45/60:   0%|          | 0/29 [00:00<?, ?it/s]
# cnn_early_fusion val epoch 45/60:   0%|          | 0/4 [00:00<?, ?it/s]
# Epoch 045/60 | train_loss=1.0907 train_acc=69.37% train_bacc=60.50% train_auc=0.9017 train_f1=0.5810 | val_loss=1.3778 val_acc=57.39% val_bacc=51.39% val_auc=0.8237 val_f1=0.4889
# Early stopping at epoch 45: no validation macro-F1 improvement for 12 epochs.
# cnn_early_fusion test:   0%|          | 0/4 [00:00<?, ?it/s]
# wandb: WARNING Saving files without folders. If you want to preserve subdirectories pass base_path to wandb.save, i.e. wandb.save("/mnt/folder/file.h5", base_path="/mnt")
# wandb: WARNING Symlinked 1 file into the W&B run directory; call wandb.save again to sync new files.
# wandb: WARNING Symlinked 1 file into the W&B run directory; call wandb.save again to sync new files.
# wandb: WARNING Symlinked 1 file into the W&B run directory; call wandb.save again to sync new files.
# wandb: WARNING Symlinked 1 file into the W&B run directory; call wandb.save again to sync new files.
# wandb: WARNING Symlinked 1 file into the W&B run directory; call wandb.save again to sync new files.
# wandb: updating run metadata
# wandb:
# wandb: Run history:
# wandb:                elapsed_sec ▁▁▁▁▂▂▂▂▂▃▃▃▃▃▃▄▄▄▄▄▅▅▅▅▅▅▆▆▆▆▆▆▇▇▇▇▇███
# wandb:                      epoch ▁▁▂▂▂▂▂▂▃▃▃▃▃▃▄▄▄▄▄▄▅▅▅▅▅▅▆▆▆▆▆▆▆▇▇▇▇███
# wandb: epochs_without_improvement ▁▁▁▁▂▁▁▂▁▁▂▁▁▂▂▃▄▁▁▂▂▃▃▄▅▆▁▂▁▁▂▂▃▄▅▅▆▆▇█
# wandb:                         lr ████████████████████████▄▄▄▄▄▄▄▄▄▄▂▂▂▂▂▁
# wandb:                  train_acc ▁▂▂▂▂▃▃▃▄▄▄▄▄▄▄▄▅▅▅▅▅▆▆▆▇▇▇▇▇▇▇█▇███████
# wandb:                  train_auc ▁▂▂▂▂▃▃▃▄▄▄▄▄▄▅▅▅▅▅▆▆▆▆▇▇▇▇▇▇▇▇▇█▇██████
# wandb:                 train_bacc ▁▁▂▂▂▂▂▂▃▃▃▃▃▃▃▄▄▄▄▄▅▅▅▅▆▆▆▇▇▇▇▇▇▇██████
# wandb:             train_f1_macro ▁▁▂▂▂▂▂▂▃▃▃▃▄▄▄▄▄▄▅▄▅▆▅▅▆▆▇▇▇▇▇▇▇▇██████
# wandb:                 train_loss █▇▆▆▆▆▆▆▅▅▅▅▅▅▅▅▄▄▄▄▃▃▃▃▃▂▂▂▂▂▂▂▂▂▁▁▁▁▁▁
# wandb:                    val_acc ▁▁▂▃▃▃▅▄▅▅▄▆▆▆▆█▇▇▇▆▆▇▆▇▆▇█▇██▅▇▆▇▆▇▇▇▆▇
# wandb:                         +4 ...
# wandb:
# wandb: Run summary:
# wandb:                 best_epoch 33
# wandb:               best_val_acc 61.30435
# wandb:               best_val_auc 0.82665
# wandb:              best_val_bacc 54.90398
# wandb:          best_val_f1_macro 0.55358
# wandb:                elapsed_sec 202.3693
# wandb:                      epoch 45
# wandb: epochs_without_improvement 12
# wandb:                         lr 4e-05
# wandb:                   test_acc 59.56522
# wandb:                        +13 ...
# wandb:
# wandb: 🚀 View run cnn_early_fusion at: https://wandb.ai/belalofficial123-the-british-university-in-egypt/iot%20fusion/runs/zt5k3wnk
# wandb: ⭐️ View project at: https://wandb.ai/belalofficial123-the-british-university-in-egypt/iot%20fusion
# wandb: Synced 5 W&B file(s), 4 media file(s), 0 artifact file(s) and 5 other file(s)
# wandb: Find logs at: ./wandb/run-20260416_191204-zt5k3wnk/logs
# Test performance:
# test_loss=1.4751 test_acc=59.57% test_bacc=41.53% test_auc=0.7682 test_f1=0.4089
# Classification report:
#               precision    recall  f1-score     support
# ACK            0.693548  0.589041  0.637037   73.000000
# BCC            0.623932  0.858824  0.722772   85.000000
# MEL            0.250000  0.200000  0.222222    5.000000
# NEV            0.560000  0.583333  0.571429   24.000000
# SCC            0.000000  0.000000  0.000000   20.000000
# SEK            0.352941  0.260870  0.300000   23.000000
# accuracy       0.595652  0.595652  0.595652    0.595652
# macro avg      0.413404  0.415345  0.408910  230.000000
# weighted avg   0.549873  0.595652  0.563760  230.000000
# cnn_early_fusion complete: best_epoch=33, test_acc=59.57%
# {'experiment_name': 'cnn_early_fusion',
#  'model_name': 'cnn',
#  'input_mode': 'early_fusion',
#  'epochs': 60,
#  'batch_size': 64,
#  'split': '80 train / 10 validation / 10 test',
#  'augment_train': True,
#  'class_weighted_loss': True,
#  'class_weight_power': 0.5,
#  'class_balanced_sampler': False,
#  'best_epoch': 33,
#  'best_val_acc': 61.30434782608696,
#  'best_val_bacc': 54.903983703551106,
#  'best_val_auc': 0.8266507217763643,
#  'best_val_f1_macro': 0.5535758907237781,
#  'final_train_loss': 1.0906576889772799,
#  'final_train_acc': 69.36887921653971,
#  'final_train_bacc': 60.49638894981004,
#  'final_train_auc': 0.9017377577194442,
#  'final_train_f1_macro': 0.5810384079082557,
#  'final_val_loss': 1.377805901610333,
#  'final_val_acc': 57.391304347826086,
#  'final_val_bacc': 51.394344880466,
#  'final_val_auc': 0.8236813890779796,
#  'final_val_f1_macro': 0.4888647981831515,
#  'test_loss': 1.4751374472742496,
#  'test_acc': 59.56521739130435,
#  'test_bacc': 41.53445873088167,
#  'test_auc': 0.7681845029584795,
#  'test_f1_macro': 0.4089100179859256,
#  'elapsed_sec': 202.3693027496338,
#  'metrics_path': '/home/zeus/content/IOT_fusion/Results_Logs/cnn_early_fusion/epoch_metrics.csv',
#  'epoch_log_path': '/home/zeus/content/IOT_fusion/Results_Logs/cnn_early_fusion/epoch_log.txt',
#  'split_summary_path': '/home/zeus/content/IOT_fusion/Results_Logs/cnn_early_fusion/split_summary.csv',
#  'checkpoint_path': '/home/zeus/content/IOT_fusion/outputs/ablations/cnn_early_fusion_best.pth',
#  'classification_report_path': '/home/zeus/content/IOT_fusion/Results_Logs/cnn_early_fusion/classification_report.csv',
#  'confusion_matrix_path': '/home/zeus/content/IOT_fusion/Results_Logs/cnn_early_fusion/confusion_matrix.csv',
#  'test_predictions_path': '/home/zeus/content/IOT_fusion/Results_Logs/cnn_early_fusion/test_predictions.csv',
#  'loss_curve_path': '/home/zeus/content/IOT_fusion/Results_Figures/cnn_early_fusion/loss_curve.png',
#  'epoch_metrics_curve_path': '/home/zeus/content/IOT_fusion/Results_Figures/cnn_early_fusion/epoch_metrics.png',
#  'confusion_matrix_plot_path': '/home/zeus/content/IOT_fusion/Results_Figures/cnn_early_fusion/confusion_matrix.png',
#  'roc_curve_path': '/home/zeus/content/IOT_fusion/Results_Figures/cnn_early_fusion/roc_curve.png',
#  'xai_paths': "{'image_saliency': '/home/zeus/content/IOT_fusion/Results_XAI/cnn_early_fusion/cnn_early_fusion_image_saliency.npy', 'metadata_importance': '/home/zeus/content/IOT_fusion/Results_XAI/cnn_early_fusion/cnn_early_fusion_metadata_xai_top20.csv'}"}

# %% [markdown]
# ## Training Outputs

# %%
from pathlib import Path
output_dir = Path('outputs/ablations')
logs_dir = Path('Results_Logs') / 'cnn_early_fusion'
figures_dir = Path('Results_Figures') / 'cnn_early_fusion'
xai_dir = Path('Results_XAI') / 'cnn_early_fusion'
print('metrics:', logs_dir / 'epoch_metrics.csv')
print('epoch log:', logs_dir / 'epoch_log.txt')
print('result:', logs_dir / 'result_summary.csv')
print('checkpoint:', output_dir / 'cnn_early_fusion_best.pth')
print('classification report:', logs_dir / 'classification_report.csv')
print('confusion matrix CSV:', logs_dir / 'confusion_matrix.csv')
print('loss curve:', figures_dir / 'loss_curve.png')
print('roc curve:', figures_dir / 'roc_curve.png')
sorted(str(p) for p in list(logs_dir.glob('*')) + list(figures_dir.glob('*')) + list(xai_dir.glob('*')))
# Out:
# metrics: Results_Logs/cnn_early_fusion/epoch_metrics.csv
# epoch log: Results_Logs/cnn_early_fusion/epoch_log.txt
# result: Results_Logs/cnn_early_fusion/result_summary.csv
# checkpoint: outputs/ablations/cnn_early_fusion_best.pth
# classification report: Results_Logs/cnn_early_fusion/classification_report.csv
# confusion matrix CSV: Results_Logs/cnn_early_fusion/confusion_matrix.csv
# loss curve: Results_Figures/cnn_early_fusion/loss_curve.png
# roc curve: Results_Figures/cnn_early_fusion/roc_curve.png
# ['Results_Figures/cnn_early_fusion/confusion_matrix.png',
#  'Results_Figures/cnn_early_fusion/epoch_metrics.png',
#  'Results_Figures/cnn_early_fusion/loss_curve.png',
#  'Results_Figures/cnn_early_fusion/roc_curve.png',
#  'Results_Logs/cnn_early_fusion/classification_report.csv',
#  'Results_Logs/cnn_early_fusion/confusion_matrix.csv',
#  'Results_Logs/cnn_early_fusion/epoch_log.txt',
#  'Results_Logs/cnn_early_fusion/epoch_metrics.csv',
#  'Results_Logs/cnn_early_fusion/result_summary.csv',
#  'Results_Logs/cnn_early_fusion/split_summary.csv',
#  'Results_Logs/cnn_early_fusion/test_predictions.csv',
#  'Results_XAI/cnn_early_fusion/cnn_early_fusion_image_saliency.npy',
#  'Results_XAI/cnn_early_fusion/cnn_early_fusion_metadata_xai_top20.csv']
