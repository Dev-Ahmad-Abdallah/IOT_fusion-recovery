# %% [markdown]
# # TRANSFORMER Images Only Ablation
#
# Experiment: `transformer_img_only`
#
# This notebook runs full GPU training on a stratified 80/10/10 train/validation/test split built from the extracted processed tabular data and image tensors. Image runs use tensor-safe train augmentation and class-weighted loss. CNN runs use tempered class-weighted loss, stronger paper-style augmentation, and early stopping to reduce overfitting; balanced sampling can be enabled manually, but is off by default because it over-corrected on this dataset. Fusion modes combine the tabular metadata vector with the image tensor. It prints per-epoch train/validation loss, accuracy, macro AUC, and macro F1 with tqdm progress bars. Epoch logs are written under `Results_Logs/<experiment>/`, figures under `Results_Figures/<experiment>/`, and XAI artifacts under `Results_XAI/<experiment>/`.

# %%
from pathlib import Path
import os, sys
REPO_ROOT = Path('/home/zeus/content/IOT_fusion')
os.chdir(REPO_ROOT)
sys.path.insert(0, str(REPO_ROOT / 'training'))
from ablation_utils import get_data_info, run_training

info = get_data_info()
print('classes:', info.class_to_idx)
print('metadata_dim:', info.metadata_dim)
# Out:
# classes: {'ACK': 0, 'BCC': 1, 'MEL': 2, 'NEV': 3, 'SCC': 4, 'SEK': 5}
# metadata_dim: 87

# %% [markdown]
# ## Full GPU Training
# Adjust `epochs` and `batch_size` if needed.

# %%
full_result = run_training(
    model_name='transformer',
    input_mode='images_only',
    experiment_name='transformer_img_only',
    epochs=25,
    batch_size=256,
    lr=0.0005,
    num_workers=2,
    device_name='cuda',
    wandb_enabled=True,
    xai_enabled=True,
    augment_train=True,
    class_weighted_loss=True,
    class_weight_power=0.5,
    class_balanced_sampler=False,
    early_stopping_patience=12,
    min_epochs=15,
)
full_result
# Out:
# wandb: [wandb.login()] Loaded credentials for https://api.wandb.ai from WANDB_API_KEY.
# wandb: Currently logged in as: belalofficial123 (belalofficial123-the-british-university-in-egypt) to https://api.wandb.ai. Use `wandb login --relogin` to force relogin
# wandb: Tracking run with wandb version 0.26.0
# wandb: Run data is saved locally in /home/zeus/content/IOT_fusion/wandb/run-20260416_192436-0cg4v0ye
# wandb: Run `wandb offline` to turn off syncing.
# wandb: Syncing run transformer_img_only
# wandb: ⭐️ View project at https://wandb.ai/belalofficial123-the-british-university-in-egypt/iot%20fusion
# wandb: 🚀 View run at https://wandb.ai/belalofficial123-the-british-university-in-egypt/iot%20fusion/runs/0cg4v0ye
# Split sizes: {'train': 1838, 'val': 230, 'test': 230}
# Class mapping: {'ACK': 0, 'BCC': 1, 'MEL': 2, 'NEV': 3, 'SCC': 4, 'SEK': 5}
# /home/zeus/miniconda3/envs/cloudspace/lib/python3.12/site-packages/torch/nn/modules/transformer.py:392: UserWarning: enable_nested_tensor is True, but self.use_nested_tensor is False because encoder_layer.norm_first was True
#   warnings.warn(
# transformer_img_only train epoch 1/25:   0%|          | 0/8 [00:00<?, ?it/s]
# transformer_img_only val epoch 1/25:   0%|          | 0/1 [00:00<?, ?it/s]
# Epoch 001/25 | train_loss=2.4972 train_acc=28.02% train_bacc=18.79% train_auc=0.5157 train_f1=0.1817 | val_loss=2.0991 val_acc=23.48% val_bacc=20.12% val_auc=0.5088 val_f1=0.0891
# transformer_img_only train epoch 2/25:   0%|          | 0/8 [00:00<?, ?it/s]
# transformer_img_only val epoch 2/25:   0%|          | 0/1 [00:00<?, ?it/s]
# Epoch 002/25 | train_loss=1.8946 train_acc=28.94% train_bacc=17.36% train_auc=0.5179 train_f1=0.1424 | val_loss=1.7570 val_acc=33.91% val_bacc=20.03% val_auc=0.6315 val_f1=0.1471
# transformer_img_only train epoch 3/25:   0%|          | 0/8 [00:00<?, ?it/s]
# transformer_img_only val epoch 3/25:   0%|          | 0/1 [00:00<?, ?it/s]
# Epoch 003/25 | train_loss=1.7910 train_acc=34.71% train_bacc=21.38% train_auc=0.5726 train_f1=0.1842 | val_loss=1.7325 val_acc=33.91% val_bacc=20.58% val_auc=0.6046 val_f1=0.1722
# transformer_img_only train epoch 4/25:   0%|          | 0/8 [00:00<?, ?it/s]
# transformer_img_only val epoch 4/25:   0%|          | 0/1 [00:00<?, ?it/s]
# Epoch 004/25 | train_loss=1.7419 train_acc=38.41% train_bacc=21.86% train_auc=0.5910 train_f1=0.2132 | val_loss=1.7276 val_acc=33.48% val_bacc=23.19% val_auc=0.6261 val_f1=0.2104
# transformer_img_only train epoch 5/25:   0%|          | 0/8 [00:00<?, ?it/s]
# transformer_img_only val epoch 5/25:   0%|          | 0/1 [00:00<?, ?it/s]
# Epoch 005/25 | train_loss=1.7450 train_acc=35.26% train_bacc=20.72% train_auc=0.5963 train_f1=0.1935 | val_loss=1.7254 val_acc=40.43% val_bacc=27.43% val_auc=0.6133 val_f1=0.2287
# transformer_img_only train epoch 6/25:   0%|          | 0/8 [00:00<?, ?it/s]
# transformer_img_only val epoch 6/25:   0%|          | 0/1 [00:00<?, ?it/s]
# Epoch 006/25 | train_loss=1.7168 train_acc=36.62% train_bacc=25.37% train_auc=0.6262 train_f1=0.2187 | val_loss=1.7123 val_acc=36.96% val_bacc=21.21% val_auc=0.6424 val_f1=0.1894
# transformer_img_only train epoch 7/25:   0%|          | 0/8 [00:00<?, ?it/s]
# transformer_img_only val epoch 7/25:   0%|          | 0/1 [00:00<?, ?it/s]
# Epoch 007/25 | train_loss=1.7171 train_acc=37.27% train_bacc=23.50% train_auc=0.6252 train_f1=0.2279 | val_loss=1.7005 val_acc=34.78% val_bacc=25.36% val_auc=0.6553 val_f1=0.2151
# transformer_img_only train epoch 8/25:   0%|          | 0/8 [00:00<?, ?it/s]
# transformer_img_only val epoch 8/25:   0%|          | 0/1 [00:00<?, ?it/s]
# Epoch 008/25 | train_loss=1.7040 train_acc=36.67% train_bacc=26.62% train_auc=0.6370 train_f1=0.2541 | val_loss=1.7150 val_acc=37.39% val_bacc=21.44% val_auc=0.6541 val_f1=0.1880
# transformer_img_only train epoch 9/25:   0%|          | 0/8 [00:00<?, ?it/s]
# transformer_img_only val epoch 9/25:   0%|          | 0/1 [00:00<?, ?it/s]
# Epoch 009/25 | train_loss=1.7243 train_acc=37.16% train_bacc=25.01% train_auc=0.6290 train_f1=0.2376 | val_loss=1.7156 val_acc=38.26% val_bacc=30.09% val_auc=0.6291 val_f1=0.2357
# transformer_img_only train epoch 10/25:   0%|          | 0/8 [00:00<?, ?it/s]
# transformer_img_only val epoch 10/25:   0%|          | 0/1 [00:00<?, ?it/s]
# Epoch 010/25 | train_loss=1.7460 train_acc=32.97% train_bacc=22.46% train_auc=0.6127 train_f1=0.2232 | val_loss=1.6842 val_acc=40.43% val_bacc=24.99% val_auc=0.6805 val_f1=0.2373
# transformer_img_only train epoch 11/25:   0%|          | 0/8 [00:00<?, ?it/s]
# transformer_img_only val epoch 11/25:   0%|          | 0/1 [00:00<?, ?it/s]
# Epoch 011/25 | train_loss=1.7053 train_acc=38.30% train_bacc=24.41% train_auc=0.6329 train_f1=0.2282 | val_loss=1.6598 val_acc=40.43% val_bacc=30.36% val_auc=0.6909 val_f1=0.2775
# transformer_img_only train epoch 12/25:   0%|          | 0/8 [00:00<?, ?it/s]
# transformer_img_only val epoch 12/25:   0%|          | 0/1 [00:00<?, ?it/s]
# Epoch 012/25 | train_loss=1.6973 train_acc=40.53% train_bacc=24.33% train_auc=0.6450 train_f1=0.2380 | val_loss=1.6584 val_acc=38.70% val_bacc=24.96% val_auc=0.6903 val_f1=0.2069
# transformer_img_only train epoch 13/25:   0%|          | 0/8 [00:00<?, ?it/s]
# transformer_img_only val epoch 13/25:   0%|          | 0/1 [00:00<?, ?it/s]
# Epoch 013/25 | train_loss=1.6762 train_acc=41.51% train_bacc=25.63% train_auc=0.6581 train_f1=0.2512 | val_loss=1.6594 val_acc=41.74% val_bacc=35.29% val_auc=0.6899 val_f1=0.2938
# transformer_img_only train epoch 14/25:   0%|          | 0/8 [00:00<?, ?it/s]
# transformer_img_only val epoch 14/25:   0%|          | 0/1 [00:00<?, ?it/s]
# Epoch 014/25 | train_loss=1.6792 train_acc=39.34% train_bacc=26.94% train_auc=0.6530 train_f1=0.2605 | val_loss=1.6498 val_acc=41.30% val_bacc=24.38% val_auc=0.6906 val_f1=0.2174
# transformer_img_only train epoch 15/25:   0%|          | 0/8 [00:00<?, ?it/s]
# transformer_img_only val epoch 15/25:   0%|          | 0/1 [00:00<?, ?it/s]
# Epoch 015/25 | train_loss=1.6677 train_acc=40.97% train_bacc=28.21% train_auc=0.6610 train_f1=0.2797 | val_loss=1.6385 val_acc=39.57% val_bacc=31.05% val_auc=0.6873 val_f1=0.2640
# transformer_img_only train epoch 16/25:   0%|          | 0/8 [00:00<?, ?it/s]
# transformer_img_only val epoch 16/25:   0%|          | 0/1 [00:00<?, ?it/s]
# Epoch 016/25 | train_loss=1.6908 train_acc=38.47% train_bacc=26.48% train_auc=0.6465 train_f1=0.2554 | val_loss=1.6446 val_acc=44.35% val_bacc=35.12% val_auc=0.7195 val_f1=0.3118
# transformer_img_only train epoch 17/25:   0%|          | 0/8 [00:00<?, ?it/s]
# transformer_img_only val epoch 17/25:   0%|          | 0/1 [00:00<?, ?it/s]
# Epoch 017/25 | train_loss=1.6651 train_acc=40.42% train_bacc=26.24% train_auc=0.6667 train_f1=0.2618 | val_loss=1.6613 val_acc=40.43% val_bacc=31.21% val_auc=0.6909 val_f1=0.2738
# transformer_img_only train epoch 18/25:   0%|          | 0/8 [00:00<?, ?it/s]
# transformer_img_only val epoch 18/25:   0%|          | 0/1 [00:00<?, ?it/s]
# Epoch 018/25 | train_loss=1.6611 train_acc=40.75% train_bacc=27.47% train_auc=0.6672 train_f1=0.2762 | val_loss=1.6669 val_acc=39.13% val_bacc=31.22% val_auc=0.6836 val_f1=0.2477
# transformer_img_only train epoch 19/25:   0%|          | 0/8 [00:00<?, ?it/s]
# transformer_img_only val epoch 19/25:   0%|          | 0/1 [00:00<?, ?it/s]
# Epoch 019/25 | train_loss=1.6610 train_acc=40.53% train_bacc=30.26% train_auc=0.6705 train_f1=0.2853 | val_loss=1.6393 val_acc=43.91% val_bacc=25.50% val_auc=0.7120 val_f1=0.2307
# transformer_img_only train epoch 20/25:   0%|          | 0/8 [00:00<?, ?it/s]
# transformer_img_only val epoch 20/25:   0%|          | 0/1 [00:00<?, ?it/s]
# Epoch 020/25 | train_loss=1.6522 train_acc=42.27% train_bacc=28.23% train_auc=0.6876 train_f1=0.2688 | val_loss=1.6433 val_acc=41.30% val_bacc=27.65% val_auc=0.7159 val_f1=0.2406
# transformer_img_only train epoch 21/25:   0%|          | 0/8 [00:00<?, ?it/s]
# transformer_img_only val epoch 21/25:   0%|          | 0/1 [00:00<?, ?it/s]
# Epoch 021/25 | train_loss=1.6732 train_acc=40.97% train_bacc=26.33% train_auc=0.6770 train_f1=0.2658 | val_loss=1.6428 val_acc=43.48% val_bacc=32.63% val_auc=0.7050 val_f1=0.2636
# transformer_img_only train epoch 22/25:   0%|          | 0/8 [00:00<?, ?it/s]
# transformer_img_only val epoch 22/25:   0%|          | 0/1 [00:00<?, ?it/s]
# Epoch 022/25 | train_loss=1.6579 train_acc=41.35% train_bacc=28.39% train_auc=0.6826 train_f1=0.2767 | val_loss=1.6074 val_acc=40.43% val_bacc=29.05% val_auc=0.7305 val_f1=0.2736
# transformer_img_only train epoch 23/25:   0%|          | 0/8 [00:00<?, ?it/s]
# transformer_img_only val epoch 23/25:   0%|          | 0/1 [00:00<?, ?it/s]
# Epoch 023/25 | train_loss=1.6246 train_acc=42.93% train_bacc=31.78% train_auc=0.6992 train_f1=0.3077 | val_loss=1.5898 val_acc=46.09% val_bacc=37.00% val_auc=0.7370 val_f1=0.3128
# transformer_img_only train epoch 24/25:   0%|          | 0/8 [00:00<?, ?it/s]
# transformer_img_only val epoch 24/25:   0%|          | 0/1 [00:00<?, ?it/s]
# Epoch 024/25 | train_loss=1.5969 train_acc=43.31% train_bacc=31.71% train_auc=0.7184 train_f1=0.2976 | val_loss=1.5665 val_acc=46.96% val_bacc=37.55% val_auc=0.7473 val_f1=0.3607
# transformer_img_only train epoch 25/25:   0%|          | 0/8 [00:00<?, ?it/s]
# transformer_img_only val epoch 25/25:   0%|          | 0/1 [00:00<?, ?it/s]
# Epoch 025/25 | train_loss=1.5967 train_acc=44.83% train_bacc=31.51% train_auc=0.7207 train_f1=0.2993 | val_loss=1.5657 val_acc=46.52% val_bacc=38.99% val_auc=0.7364 val_f1=0.3464
# transformer_img_only test:   0%|          | 0/1 [00:00<?, ?it/s]
# wandb: WARNING Saving files without folders. If you want to preserve subdirectories pass base_path to wandb.save, i.e. wandb.save("/mnt/folder/file.h5", base_path="/mnt")
# wandb: WARNING Symlinked 1 file into the W&B run directory; call wandb.save again to sync new files.
# wandb: WARNING Symlinked 1 file into the W&B run directory; call wandb.save again to sync new files.
# wandb: WARNING Symlinked 1 file into the W&B run directory; call wandb.save again to sync new files.
# wandb: WARNING Symlinked 1 file into the W&B run directory; call wandb.save again to sync new files.
# wandb: WARNING Symlinked 1 file into the W&B run directory; call wandb.save again to sync new files.
# wandb: updating run metadata
# wandb:
# wandb: Run history:
# wandb:                elapsed_sec ▁▁▂▂▂▂▃▃▃▄▄▄▅▅▅▅▆▆▆▇▇▇▇██
# wandb:                      epoch ▁▁▁▁▂▂▂▂▂▂▃▃▃▃▄▄▄▄▄▅▅▅▅▅▅▆▆▆▆▆▇▇▇▇▇▇▇███
# wandb: epochs_without_improvement ▁▁▁▁▁▂▃▅▁▁▁▂▁▂▃▁▂▃▅▆▇█▁▁▂
# wandb:                         lr █████████████████████▁▁▁▁
# wandb:                  train_acc ▁▁▄▅▄▅▅▅▅▃▅▆▇▆▆▅▆▆▆▇▆▇▇▇█
# wandb:                  train_auc ▁▁▃▄▄▅▅▅▅▄▅▅▆▆▆▅▆▆▆▇▇▇▇██
# wandb:                 train_bacc ▂▁▃▃▃▅▄▅▅▃▄▄▅▆▆▅▅▆▇▆▅▆███
# wandb:             train_f1_macro ▃▁▃▄▃▄▅▆▅▄▅▅▆▆▇▆▆▇▇▆▆▇███
# wandb:                 train_loss █▃▃▂▂▂▂▂▂▂▂▂▂▂▂▂▂▂▁▁▂▁▁▁▁
# wandb:                    val_acc ▁▄▄▄▆▅▄▅▅▆▆▆▆▆▆▇▆▆▇▆▇▆███
# wandb:                         +4 ...
# wandb:
# wandb: Run summary:
# wandb:                 best_epoch 24
# wandb:               best_val_acc 46.95652
# wandb:               best_val_auc 0.74728
# wandb:              best_val_bacc 37.54724
# wandb:          best_val_f1_macro 0.36073
# wandb:                elapsed_sec 152.50265
# wandb:                      epoch 25
# wandb: epochs_without_improvement 1
# wandb:                         lr 0.00025
# wandb:                   test_acc 49.56522
# wandb:                        +13 ...
# wandb:
# wandb: 🚀 View run transformer_img_only at: https://wandb.ai/belalofficial123-the-british-university-in-egypt/iot%20fusion/runs/0cg4v0ye
# wandb: ⭐️ View project at: https://wandb.ai/belalofficial123-the-british-university-in-egypt/iot%20fusion
# wandb: Synced 5 W&B file(s), 4 media file(s), 0 artifact file(s) and 5 other file(s)
# wandb: Find logs at: ./wandb/run-20260416_192436-0cg4v0ye/logs
# Test performance:
# test_loss=1.5787 test_acc=49.57% test_bacc=33.36% test_auc=0.7290 test_f1=0.3262
# Classification report:
#               precision    recall  f1-score     support
# ACK            0.488372  0.575342  0.528302   73.000000
# BCC            0.569892  0.623529  0.595506   85.000000
# MEL            0.000000  0.000000  0.000000    5.000000
# NEV            0.448276  0.541667  0.490566   24.000000
# SCC            0.000000  0.000000  0.000000   20.000000
# SEK            0.500000  0.260870  0.342857   23.000000
# accuracy       0.495652  0.495652  0.495652    0.495652
# macro avg      0.334423  0.333568  0.326205  230.000000
# weighted avg   0.462394  0.495652  0.473232  230.000000
# transformer_img_only complete: best_epoch=24, test_acc=49.57%
# {'experiment_name': 'transformer_img_only',
#  'model_name': 'transformer',
#  'input_mode': 'images_only',
#  'epochs': 25,
#  'batch_size': 256,
#  'split': '80 train / 10 validation / 10 test',
#  'augment_train': True,
#  'class_weighted_loss': True,
#  'class_weight_power': 0.5,
#  'class_balanced_sampler': False,
#  'best_epoch': 24,
#  'best_val_acc': 46.95652173913044,
#  'best_val_bacc': 37.54723853011524,
#  'best_val_auc': 0.7472814507063342,
#  'best_val_f1_macro': 0.36073172198172193,
#  'final_train_loss': 1.5966777033593111,
#  'final_train_acc': 44.83133841131664,
#  'final_train_bacc': 31.509160944837582,
#  'final_train_auc': 0.7207057473979752,
#  'final_train_f1_macro': 0.29929621227654196,
#  'final_val_loss': 1.565685749053955,
#  'final_val_acc': 46.52173913043478,
#  'final_val_bacc': 38.99141117634268,
#  'final_val_auc': 0.7363716347181021,
#  'final_val_f1_macro': 0.34639921710851773,
#  'test_loss': 1.5786614418029785,
#  'test_acc': 49.56521739130435,
#  'test_bacc': 33.3568018233698,
#  'test_auc': 0.72904194692876,
#  'test_f1_macro': 0.32620511422716214,
#  'elapsed_sec': 152.5026454925537,
#  'metrics_path': '/home/zeus/content/IOT_fusion/Results_Logs/transformer_img_only/epoch_metrics.csv',
#  'epoch_log_path': '/home/zeus/content/IOT_fusion/Results_Logs/transformer_img_only/epoch_log.txt',
#  'split_summary_path': '/home/zeus/content/IOT_fusion/Results_Logs/transformer_img_only/split_summary.csv',
#  'checkpoint_path': '/home/zeus/content/IOT_fusion/outputs/ablations/transformer_img_only_best.pth',
#  'classification_report_path': '/home/zeus/content/IOT_fusion/Results_Logs/transformer_img_only/classification_report.csv',
#  'confusion_matrix_path': '/home/zeus/content/IOT_fusion/Results_Logs/transformer_img_only/confusion_matrix.csv',
#  'test_predictions_path': '/home/zeus/content/IOT_fusion/Results_Logs/transformer_img_only/test_predictions.csv',
#  'loss_curve_path': '/home/zeus/content/IOT_fusion/Results_Figures/transformer_img_only/loss_curve.png',
#  'epoch_metrics_curve_path': '/home/zeus/content/IOT_fusion/Results_Figures/transformer_img_only/epoch_metrics.png',
#  'confusion_matrix_plot_path': '/home/zeus/content/IOT_fusion/Results_Figures/transformer_img_only/confusion_matrix.png',
#  'roc_curve_path': '/home/zeus/content/IOT_fusion/Results_Figures/transformer_img_only/roc_curve.png',
#  'xai_paths': "{'image_saliency': '/home/zeus/content/IOT_fusion/Results_XAI/transformer_img_only/transformer_img_only_image_saliency.npy'}"}

# %% [markdown]
# ## Training Outputs

# %%
from pathlib import Path
output_dir = Path('outputs/ablations')
logs_dir = Path('Results_Logs') / 'transformer_img_only'
figures_dir = Path('Results_Figures') / 'transformer_img_only'
xai_dir = Path('Results_XAI') / 'transformer_img_only'
print('metrics:', logs_dir / 'epoch_metrics.csv')
print('epoch log:', logs_dir / 'epoch_log.txt')
print('result:', logs_dir / 'result_summary.csv')
print('checkpoint:', output_dir / 'transformer_img_only_best.pth')
print('classification report:', logs_dir / 'classification_report.csv')
print('confusion matrix CSV:', logs_dir / 'confusion_matrix.csv')
print('loss curve:', figures_dir / 'loss_curve.png')
print('roc curve:', figures_dir / 'roc_curve.png')
sorted(str(p) for p in list(logs_dir.glob('*')) + list(figures_dir.glob('*')) + list(xai_dir.glob('*')))
# Out:
# metrics: Results_Logs/transformer_img_only/epoch_metrics.csv
# epoch log: Results_Logs/transformer_img_only/epoch_log.txt
# result: Results_Logs/transformer_img_only/result_summary.csv
# checkpoint: outputs/ablations/transformer_img_only_best.pth
# classification report: Results_Logs/transformer_img_only/classification_report.csv
# confusion matrix CSV: Results_Logs/transformer_img_only/confusion_matrix.csv
# loss curve: Results_Figures/transformer_img_only/loss_curve.png
# roc curve: Results_Figures/transformer_img_only/roc_curve.png
# ['Results_Figures/transformer_img_only/confusion_matrix.png',
#  'Results_Figures/transformer_img_only/epoch_metrics.png',
#  'Results_Figures/transformer_img_only/loss_curve.png',
#  'Results_Figures/transformer_img_only/roc_curve.png',
#  'Results_Logs/transformer_img_only/classification_report.csv',
#  'Results_Logs/transformer_img_only/confusion_matrix.csv',
#  'Results_Logs/transformer_img_only/epoch_log.txt',
#  'Results_Logs/transformer_img_only/epoch_metrics.csv',
#  'Results_Logs/transformer_img_only/result_summary.csv',
#  'Results_Logs/transformer_img_only/split_summary.csv',
#  'Results_Logs/transformer_img_only/test_predictions.csv',
#  'Results_XAI/transformer_img_only/transformer_img_only_image_saliency.npy']
