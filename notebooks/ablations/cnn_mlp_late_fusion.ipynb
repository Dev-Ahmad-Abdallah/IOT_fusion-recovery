# %% [markdown]
# # CNN Late Fusion Ablation
#
# Experiment: `cnn_late_fusion`
#
# This notebook runs full GPU training on a stratified 80/10/10 train/validation/test split built from the extracted processed tabular data and image tensors. Image runs use tensor-safe train augmentation and class-weighted loss. CNN runs use tempered class-weighted loss, stronger paper-style augmentation, and early stopping to reduce overfitting; balanced sampling can be enabled manually, but is off by default because it over-corrected on this dataset. Fusion modes combine the tabular metadata vector with the image tensor. It prints per-epoch train/validation loss, accuracy, macro AUC, and macro F1 with tqdm progress bars. Epoch logs are written under `Results_Logs/<experiment>/`, figures under `Results_Figures/<experiment>/`, and XAI artifacts under `Results_XAI/<experiment>/`.

# %%
from pathlib import Path
import os, sys
REPO_ROOT = Path('/home/zeus/content/IOT_fusion')
os.chdir(REPO_ROOT)
sys.path.insert(0, str(REPO_ROOT / 'training'))
from ablation_utils import get_data_info, run_training

info = get_data_info()
print('classes:', info.class_to_idx)
print('metadata_dim:', info.metadata_dim)
# Out:
# classes: {'ACK': 0, 'BCC': 1, 'MEL': 2, 'NEV': 3, 'SCC': 4, 'SEK': 5}
# metadata_dim: 87

# %% [markdown]
# ## Full GPU Training
# Adjust `epochs` and `batch_size` if needed.

# %%
full_result = run_training(
    model_name='cnn',
    input_mode='late_fusion',
    experiment_name='cnn_late_fusion',
    epochs=60,
    batch_size=64,
    lr=0.0003,
    num_workers=2,
    device_name='cuda',
    wandb_enabled=True,
    xai_enabled=True,
    augment_train=True,
    class_weighted_loss=True,
    class_weight_power=0.5,
    class_balanced_sampler=False,
    early_stopping_patience=12,
    min_epochs=15,
)
full_result
# Out:
# wandb: [wandb.login()] Loaded credentials for https://api.wandb.ai from WANDB_API_KEY.
# wandb: Currently logged in as: belalofficial123 (belalofficial123-the-british-university-in-egypt) to https://api.wandb.ai. Use `wandb login --relogin` to force relogin
# wandb: Tracking run with wandb version 0.26.0
# wandb: Run data is saved locally in /home/zeus/content/IOT_fusion/wandb/run-20260416_192019-b0jmmpw8
# wandb: Run `wandb offline` to turn off syncing.
# wandb: Syncing run cnn_late_fusion
# wandb: ⭐️ View project at https://wandb.ai/belalofficial123-the-british-university-in-egypt/iot%20fusion
# wandb: 🚀 View run at https://wandb.ai/belalofficial123-the-british-university-in-egypt/iot%20fusion/runs/b0jmmpw8
# Split sizes: {'train': 1838, 'val': 230, 'test': 230}
# Class mapping: {'ACK': 0, 'BCC': 1, 'MEL': 2, 'NEV': 3, 'SCC': 4, 'SEK': 5}
# cnn_late_fusion train epoch 1/60:   0%|          | 0/29 [00:00<?, ?it/s]
# cnn_late_fusion val epoch 1/60:   0%|          | 0/4 [00:00<?, ?it/s]
# Epoch 001/60 | train_loss=1.7799 train_acc=34.00% train_bacc=22.66% train_auc=0.5639 train_f1=0.2249 | val_loss=1.6359 val_acc=53.91% val_bacc=29.31% val_auc=0.7806 val_f1=0.2752
# cnn_late_fusion train epoch 2/60:   0%|          | 0/29 [00:00<?, ?it/s]
# cnn_late_fusion val epoch 2/60:   0%|          | 0/4 [00:00<?, ?it/s]
# Epoch 002/60 | train_loss=1.5853 train_acc=45.10% train_bacc=34.25% train_auc=0.6963 train_f1=0.3355 | val_loss=1.4903 val_acc=48.26% val_bacc=34.12% val_auc=0.8008 val_f1=0.3127
# cnn_late_fusion train epoch 3/60:   0%|          | 0/29 [00:00<?, ?it/s]
# cnn_late_fusion val epoch 3/60:   0%|          | 0/4 [00:00<?, ?it/s]
# Epoch 003/60 | train_loss=1.4670 train_acc=54.19% train_bacc=39.81% train_auc=0.7693 train_f1=0.3890 | val_loss=1.3842 val_acc=54.78% val_bacc=42.08% val_auc=0.8438 val_f1=0.3864
# cnn_late_fusion train epoch 4/60:   0%|          | 0/29 [00:00<?, ?it/s]
# cnn_late_fusion val epoch 4/60:   0%|          | 0/4 [00:00<?, ?it/s]
# Epoch 004/60 | train_loss=1.3353 train_acc=61.48% train_bacc=45.15% train_auc=0.8256 train_f1=0.4543 | val_loss=1.2895 val_acc=59.13% val_bacc=53.42% val_auc=0.8631 val_f1=0.4645
# cnn_late_fusion train epoch 5/60:   0%|          | 0/29 [00:00<?, ?it/s]
# cnn_late_fusion val epoch 5/60:   0%|          | 0/4 [00:00<?, ?it/s]
# Epoch 005/60 | train_loss=1.2721 train_acc=63.44% train_bacc=49.88% train_auc=0.8450 train_f1=0.4942 | val_loss=1.2099 val_acc=62.61% val_bacc=51.51% val_auc=0.8897 val_f1=0.4708
# cnn_late_fusion train epoch 6/60:   0%|          | 0/29 [00:00<?, ?it/s]
# cnn_late_fusion val epoch 6/60:   0%|          | 0/4 [00:00<?, ?it/s]
# Epoch 006/60 | train_loss=1.1726 train_acc=67.90% train_bacc=53.04% train_auc=0.8843 train_f1=0.5420 | val_loss=1.1345 val_acc=67.39% val_bacc=56.78% val_auc=0.9021 val_f1=0.4987
# cnn_late_fusion train epoch 7/60:   0%|          | 0/29 [00:00<?, ?it/s]
# cnn_late_fusion val epoch 7/60:   0%|          | 0/4 [00:00<?, ?it/s]
# Epoch 007/60 | train_loss=1.0986 train_acc=71.87% train_bacc=57.50% train_auc=0.9003 train_f1=0.5836 | val_loss=1.0687 val_acc=73.91% val_bacc=59.55% val_auc=0.9214 val_f1=0.5945
# cnn_late_fusion train epoch 8/60:   0%|          | 0/29 [00:00<?, ?it/s]
# cnn_late_fusion val epoch 8/60:   0%|          | 0/4 [00:00<?, ?it/s]
# Epoch 008/60 | train_loss=1.0512 train_acc=73.34% train_bacc=63.37% train_auc=0.9160 train_f1=0.6343 | val_loss=1.0619 val_acc=69.57% val_bacc=56.83% val_auc=0.9245 val_f1=0.5303
# cnn_late_fusion train epoch 9/60:   0%|          | 0/29 [00:00<?, ?it/s]
# cnn_late_fusion val epoch 9/60:   0%|          | 0/4 [00:00<?, ?it/s]
# Epoch 009/60 | train_loss=1.0199 train_acc=73.72% train_bacc=62.13% train_auc=0.9198 train_f1=0.6213 | val_loss=1.0244 val_acc=72.17% val_bacc=60.37% val_auc=0.9312 val_f1=0.6006
# cnn_late_fusion train epoch 10/60:   0%|          | 0/29 [00:00<?, ?it/s]
# cnn_late_fusion val epoch 10/60:   0%|          | 0/4 [00:00<?, ?it/s]
# Epoch 010/60 | train_loss=0.9882 train_acc=74.21% train_bacc=63.82% train_auc=0.9316 train_f1=0.6360 | val_loss=0.9998 val_acc=72.61% val_bacc=61.85% val_auc=0.9369 val_f1=0.5798
# cnn_late_fusion train epoch 11/60:   0%|          | 0/29 [00:00<?, ?it/s]
# cnn_late_fusion val epoch 11/60:   0%|          | 0/4 [00:00<?, ?it/s]
# Epoch 011/60 | train_loss=0.9708 train_acc=75.79% train_bacc=68.46% train_auc=0.9316 train_f1=0.6608 | val_loss=0.9562 val_acc=75.22% val_bacc=68.62% val_auc=0.9357 val_f1=0.6610
# cnn_late_fusion train epoch 12/60:   0%|          | 0/29 [00:00<?, ?it/s]
# cnn_late_fusion val epoch 12/60:   0%|          | 0/4 [00:00<?, ?it/s]
# Epoch 012/60 | train_loss=0.9494 train_acc=75.52% train_bacc=69.20% train_auc=0.9400 train_f1=0.6804 | val_loss=0.9758 val_acc=72.17% val_bacc=65.00% val_auc=0.9313 val_f1=0.6005
# cnn_late_fusion train epoch 13/60:   0%|          | 0/29 [00:00<?, ?it/s]
# cnn_late_fusion val epoch 13/60:   0%|          | 0/4 [00:00<?, ?it/s]
# Epoch 013/60 | train_loss=0.9412 train_acc=76.44% train_bacc=71.16% train_auc=0.9390 train_f1=0.6824 | val_loss=0.9465 val_acc=75.65% val_bacc=70.95% val_auc=0.9390 val_f1=0.6578
# cnn_late_fusion train epoch 14/60:   0%|          | 0/29 [00:00<?, ?it/s]
# cnn_late_fusion val epoch 14/60:   0%|          | 0/4 [00:00<?, ?it/s]
# Epoch 014/60 | train_loss=0.9242 train_acc=75.68% train_bacc=70.22% train_auc=0.9431 train_f1=0.6826 | val_loss=0.9581 val_acc=73.48% val_bacc=65.24% val_auc=0.9322 val_f1=0.6280
# cnn_late_fusion train epoch 15/60:   0%|          | 0/29 [00:00<?, ?it/s]
# cnn_late_fusion val epoch 15/60:   0%|          | 0/4 [00:00<?, ?it/s]
# Epoch 015/60 | train_loss=0.9187 train_acc=75.03% train_bacc=71.22% train_auc=0.9434 train_f1=0.6779 | val_loss=0.9261 val_acc=73.91% val_bacc=70.50% val_auc=0.9416 val_f1=0.6707
# cnn_late_fusion train epoch 16/60:   0%|          | 0/29 [00:00<?, ?it/s]
# cnn_late_fusion val epoch 16/60:   0%|          | 0/4 [00:00<?, ?it/s]
# Epoch 016/60 | train_loss=0.9034 train_acc=76.93% train_bacc=72.63% train_auc=0.9459 train_f1=0.7014 | val_loss=0.9341 val_acc=72.61% val_bacc=68.82% val_auc=0.9375 val_f1=0.6289
# cnn_late_fusion train epoch 17/60:   0%|          | 0/29 [00:00<?, ?it/s]
# cnn_late_fusion val epoch 17/60:   0%|          | 0/4 [00:00<?, ?it/s]
# Epoch 017/60 | train_loss=0.8980 train_acc=77.91% train_bacc=74.51% train_auc=0.9467 train_f1=0.7024 | val_loss=0.9271 val_acc=76.52% val_bacc=71.10% val_auc=0.9397 val_f1=0.6670
# cnn_late_fusion train epoch 18/60:   0%|          | 0/29 [00:00<?, ?it/s]
# cnn_late_fusion val epoch 18/60:   0%|          | 0/4 [00:00<?, ?it/s]
# Epoch 018/60 | train_loss=0.9064 train_acc=77.53% train_bacc=73.83% train_auc=0.9463 train_f1=0.7128 | val_loss=0.9476 val_acc=73.04% val_bacc=68.72% val_auc=0.9379 val_f1=0.6166
# cnn_late_fusion train epoch 19/60:   0%|          | 0/29 [00:00<?, ?it/s]
# cnn_late_fusion val epoch 19/60:   0%|          | 0/4 [00:00<?, ?it/s]
# Epoch 019/60 | train_loss=0.8771 train_acc=79.05% train_bacc=74.84% train_auc=0.9502 train_f1=0.7227 | val_loss=0.9364 val_acc=73.04% val_bacc=73.49% val_auc=0.9383 val_f1=0.6710
# cnn_late_fusion train epoch 20/60:   0%|          | 0/29 [00:00<?, ?it/s]
# cnn_late_fusion val epoch 20/60:   0%|          | 0/4 [00:00<?, ?it/s]
# Epoch 020/60 | train_loss=0.8620 train_acc=78.51% train_bacc=74.40% train_auc=0.9563 train_f1=0.7192 | val_loss=0.9034 val_acc=75.65% val_bacc=71.26% val_auc=0.9435 val_f1=0.6595
# cnn_late_fusion train epoch 21/60:   0%|          | 0/29 [00:00<?, ?it/s]
# cnn_late_fusion val epoch 21/60:   0%|          | 0/4 [00:00<?, ?it/s]
# Epoch 021/60 | train_loss=0.8728 train_acc=77.80% train_bacc=74.45% train_auc=0.9542 train_f1=0.7219 | val_loss=0.9231 val_acc=74.78% val_bacc=73.37% val_auc=0.9412 val_f1=0.6759
# cnn_late_fusion train epoch 22/60:   0%|          | 0/29 [00:00<?, ?it/s]
# cnn_late_fusion val epoch 22/60:   0%|          | 0/4 [00:00<?, ?it/s]
# Epoch 022/60 | train_loss=0.8555 train_acc=78.35% train_bacc=74.81% train_auc=0.9550 train_f1=0.7178 | val_loss=0.9157 val_acc=75.65% val_bacc=74.80% val_auc=0.9432 val_f1=0.6927
# cnn_late_fusion train epoch 23/60:   0%|          | 0/29 [00:00<?, ?it/s]
# cnn_late_fusion val epoch 23/60:   0%|          | 0/4 [00:00<?, ?it/s]
# Epoch 023/60 | train_loss=0.8474 train_acc=79.82% train_bacc=76.70% train_auc=0.9575 train_f1=0.7465 | val_loss=0.9228 val_acc=73.91% val_bacc=70.25% val_auc=0.9416 val_f1=0.6390
# cnn_late_fusion train epoch 24/60:   0%|          | 0/29 [00:00<?, ?it/s]
# cnn_late_fusion val epoch 24/60:   0%|          | 0/4 [00:00<?, ?it/s]
# Epoch 024/60 | train_loss=0.8426 train_acc=79.82% train_bacc=75.99% train_auc=0.9586 train_f1=0.7295 | val_loss=0.9166 val_acc=75.65% val_bacc=75.31% val_auc=0.9413 val_f1=0.6983
# cnn_late_fusion train epoch 25/60:   0%|          | 0/29 [00:00<?, ?it/s]
# cnn_late_fusion val epoch 25/60:   0%|          | 0/4 [00:00<?, ?it/s]
# Epoch 025/60 | train_loss=0.8393 train_acc=80.74% train_bacc=76.86% train_auc=0.9581 train_f1=0.7475 | val_loss=0.9057 val_acc=76.52% val_bacc=75.24% val_auc=0.9458 val_f1=0.7003
# cnn_late_fusion train epoch 26/60:   0%|          | 0/29 [00:00<?, ?it/s]
# cnn_late_fusion val epoch 26/60:   0%|          | 0/4 [00:00<?, ?it/s]
# Epoch 026/60 | train_loss=0.8391 train_acc=79.60% train_bacc=75.38% train_auc=0.9599 train_f1=0.7420 | val_loss=0.9349 val_acc=74.35% val_bacc=73.55% val_auc=0.9381 val_f1=0.6696
# cnn_late_fusion train epoch 27/60:   0%|          | 0/29 [00:00<?, ?it/s]
# cnn_late_fusion val epoch 27/60:   0%|          | 0/4 [00:00<?, ?it/s]
# Epoch 027/60 | train_loss=0.8191 train_acc=80.79% train_bacc=78.21% train_auc=0.9614 train_f1=0.7553 | val_loss=0.9285 val_acc=74.35% val_bacc=72.63% val_auc=0.9428 val_f1=0.6733
# cnn_late_fusion train epoch 28/60:   0%|          | 0/29 [00:00<?, ?it/s]
# cnn_late_fusion val epoch 28/60:   0%|          | 0/4 [00:00<?, ?it/s]
# Epoch 028/60 | train_loss=0.8410 train_acc=79.98% train_bacc=76.44% train_auc=0.9590 train_f1=0.7457 | val_loss=0.8867 val_acc=79.13% val_bacc=76.87% val_auc=0.9505 val_f1=0.7245
# cnn_late_fusion train epoch 29/60:   0%|          | 0/29 [00:00<?, ?it/s]
# cnn_late_fusion val epoch 29/60:   0%|          | 0/4 [00:00<?, ?it/s]
# Epoch 029/60 | train_loss=0.8353 train_acc=80.69% train_bacc=78.35% train_auc=0.9587 train_f1=0.7563 | val_loss=0.9049 val_acc=78.26% val_bacc=71.86% val_auc=0.9437 val_f1=0.6883
# cnn_late_fusion train epoch 30/60:   0%|          | 0/29 [00:00<?, ?it/s]
# cnn_late_fusion val epoch 30/60:   0%|          | 0/4 [00:00<?, ?it/s]
# Epoch 030/60 | train_loss=0.8116 train_acc=80.96% train_bacc=78.30% train_auc=0.9637 train_f1=0.7597 | val_loss=0.8780 val_acc=78.26% val_bacc=75.37% val_auc=0.9492 val_f1=0.7276
# cnn_late_fusion train epoch 31/60:   0%|          | 0/29 [00:00<?, ?it/s]
# cnn_late_fusion val epoch 31/60:   0%|          | 0/4 [00:00<?, ?it/s]
# Epoch 031/60 | train_loss=0.8111 train_acc=81.45% train_bacc=77.91% train_auc=0.9632 train_f1=0.7624 | val_loss=0.8985 val_acc=76.52% val_bacc=75.48% val_auc=0.9483 val_f1=0.7032
# cnn_late_fusion train epoch 32/60:   0%|          | 0/29 [00:00<?, ?it/s]
# cnn_late_fusion val epoch 32/60:   0%|          | 0/4 [00:00<?, ?it/s]
# Epoch 032/60 | train_loss=0.8070 train_acc=81.77% train_bacc=78.32% train_auc=0.9653 train_f1=0.7647 | val_loss=0.8954 val_acc=77.39% val_bacc=76.15% val_auc=0.9462 val_f1=0.7165
# cnn_late_fusion train epoch 33/60:   0%|          | 0/29 [00:00<?, ?it/s]
# cnn_late_fusion val epoch 33/60:   0%|          | 0/4 [00:00<?, ?it/s]
# Epoch 033/60 | train_loss=0.8030 train_acc=81.23% train_bacc=77.91% train_auc=0.9660 train_f1=0.7564 | val_loss=0.8757 val_acc=76.96% val_bacc=75.74% val_auc=0.9491 val_f1=0.7180
# cnn_late_fusion train epoch 34/60:   0%|          | 0/29 [00:00<?, ?it/s]
# cnn_late_fusion val epoch 34/60:   0%|          | 0/4 [00:00<?, ?it/s]
# Epoch 034/60 | train_loss=0.7871 train_acc=82.05% train_bacc=78.77% train_auc=0.9684 train_f1=0.7675 | val_loss=0.8770 val_acc=76.96% val_bacc=76.03% val_auc=0.9489 val_f1=0.7200
# cnn_late_fusion train epoch 35/60:   0%|          | 0/29 [00:00<?, ?it/s]
# cnn_late_fusion val epoch 35/60:   0%|          | 0/4 [00:00<?, ?it/s]
# Epoch 035/60 | train_loss=0.8023 train_acc=81.12% train_bacc=78.45% train_auc=0.9657 train_f1=0.7573 | val_loss=0.9042 val_acc=78.26% val_bacc=73.45% val_auc=0.9500 val_f1=0.7105
# cnn_late_fusion train epoch 36/60:   0%|          | 0/29 [00:00<?, ?it/s]
# cnn_late_fusion val epoch 36/60:   0%|          | 0/4 [00:00<?, ?it/s]
# Epoch 036/60 | train_loss=0.7927 train_acc=81.83% train_bacc=78.88% train_auc=0.9676 train_f1=0.7668 | val_loss=0.8763 val_acc=77.83% val_bacc=77.44% val_auc=0.9508 val_f1=0.7258
# cnn_late_fusion train epoch 37/60:   0%|          | 0/29 [00:00<?, ?it/s]
# cnn_late_fusion val epoch 37/60:   0%|          | 0/4 [00:00<?, ?it/s]
# Epoch 037/60 | train_loss=0.7683 train_acc=83.62% train_bacc=82.69% train_auc=0.9719 train_f1=0.7964 | val_loss=0.8678 val_acc=77.39% val_bacc=74.28% val_auc=0.9530 val_f1=0.7180
# cnn_late_fusion train epoch 38/60:   0%|          | 0/29 [00:00<?, ?it/s]
# cnn_late_fusion val epoch 38/60:   0%|          | 0/4 [00:00<?, ?it/s]
# Epoch 038/60 | train_loss=0.7657 train_acc=83.51% train_bacc=80.10% train_auc=0.9720 train_f1=0.7898 | val_loss=0.8768 val_acc=76.52% val_bacc=75.30% val_auc=0.9504 val_f1=0.6959
# cnn_late_fusion train epoch 39/60:   0%|          | 0/29 [00:00<?, ?it/s]
# cnn_late_fusion val epoch 39/60:   0%|          | 0/4 [00:00<?, ?it/s]
# Epoch 039/60 | train_loss=0.7754 train_acc=81.72% train_bacc=80.78% train_auc=0.9709 train_f1=0.7698 | val_loss=0.8790 val_acc=79.13% val_bacc=76.12% val_auc=0.9519 val_f1=0.7217
# cnn_late_fusion train epoch 40/60:   0%|          | 0/29 [00:00<?, ?it/s]
# cnn_late_fusion val epoch 40/60:   0%|          | 0/4 [00:00<?, ?it/s]
# Epoch 040/60 | train_loss=0.7635 train_acc=83.90% train_bacc=81.01% train_auc=0.9726 train_f1=0.7974 | val_loss=0.8749 val_acc=76.52% val_bacc=78.33% val_auc=0.9493 val_f1=0.7108
# cnn_late_fusion train epoch 41/60:   0%|          | 0/29 [00:00<?, ?it/s]
# cnn_late_fusion val epoch 41/60:   0%|          | 0/4 [00:00<?, ?it/s]
# Epoch 041/60 | train_loss=0.7548 train_acc=83.95% train_bacc=82.51% train_auc=0.9738 train_f1=0.7957 | val_loss=0.8762 val_acc=78.26% val_bacc=76.58% val_auc=0.9505 val_f1=0.7291
# cnn_late_fusion train epoch 42/60:   0%|          | 0/29 [00:00<?, ?it/s]
# cnn_late_fusion val epoch 42/60:   0%|          | 0/4 [00:00<?, ?it/s]
# Epoch 042/60 | train_loss=0.7516 train_acc=83.90% train_bacc=81.05% train_auc=0.9739 train_f1=0.7941 | val_loss=0.8669 val_acc=75.65% val_bacc=75.56% val_auc=0.9507 val_f1=0.6971
# cnn_late_fusion train epoch 43/60:   0%|          | 0/29 [00:00<?, ?it/s]
# cnn_late_fusion val epoch 43/60:   0%|          | 0/4 [00:00<?, ?it/s]
# Epoch 043/60 | train_loss=0.7536 train_acc=84.06% train_bacc=80.92% train_auc=0.9737 train_f1=0.7979 | val_loss=0.8691 val_acc=79.57% val_bacc=78.61% val_auc=0.9512 val_f1=0.7319
# cnn_late_fusion train epoch 44/60:   0%|          | 0/29 [00:00<?, ?it/s]
# cnn_late_fusion val epoch 44/60:   0%|          | 0/4 [00:00<?, ?it/s]
# Epoch 044/60 | train_loss=0.7471 train_acc=84.44% train_bacc=82.86% train_auc=0.9736 train_f1=0.8066 | val_loss=0.8814 val_acc=79.13% val_bacc=76.09% val_auc=0.9504 val_f1=0.7211
# cnn_late_fusion train epoch 45/60:   0%|          | 0/29 [00:00<?, ?it/s]
# cnn_late_fusion val epoch 45/60:   0%|          | 0/4 [00:00<?, ?it/s]
# Epoch 045/60 | train_loss=0.7449 train_acc=84.06% train_bacc=81.58% train_auc=0.9754 train_f1=0.7928 | val_loss=0.8867 val_acc=73.48% val_bacc=73.48% val_auc=0.9486 val_f1=0.6615
# cnn_late_fusion train epoch 46/60:   0%|          | 0/29 [00:00<?, ?it/s]
# cnn_late_fusion val epoch 46/60:   0%|          | 0/4 [00:00<?, ?it/s]
# Epoch 046/60 | train_loss=0.7397 train_acc=84.44% train_bacc=82.54% train_auc=0.9770 train_f1=0.8033 | val_loss=0.9003 val_acc=75.65% val_bacc=75.61% val_auc=0.9460 val_f1=0.6919
# cnn_late_fusion train epoch 47/60:   0%|          | 0/29 [00:00<?, ?it/s]
# cnn_late_fusion val epoch 47/60:   0%|          | 0/4 [00:00<?, ?it/s]
# Epoch 047/60 | train_loss=0.7274 train_acc=85.15% train_bacc=84.09% train_auc=0.9772 train_f1=0.8214 | val_loss=0.8920 val_acc=76.96% val_bacc=74.60% val_auc=0.9487 val_f1=0.6936
# cnn_late_fusion train epoch 48/60:   0%|          | 0/29 [00:00<?, ?it/s]
# cnn_late_fusion val epoch 48/60:   0%|          | 0/4 [00:00<?, ?it/s]
# Epoch 048/60 | train_loss=0.7521 train_acc=83.79% train_bacc=80.97% train_auc=0.9750 train_f1=0.7856 | val_loss=0.8654 val_acc=76.96% val_bacc=76.21% val_auc=0.9526 val_f1=0.7123
# cnn_late_fusion train epoch 49/60:   0%|          | 0/29 [00:00<?, ?it/s]
# cnn_late_fusion val epoch 49/60:   0%|          | 0/4 [00:00<?, ?it/s]
# Epoch 049/60 | train_loss=0.7289 train_acc=84.00% train_bacc=82.31% train_auc=0.9777 train_f1=0.8071 | val_loss=0.8849 val_acc=76.96% val_bacc=77.04% val_auc=0.9517 val_f1=0.7060
# cnn_late_fusion train epoch 50/60:   0%|          | 0/29 [00:00<?, ?it/s]
# cnn_late_fusion val epoch 50/60:   0%|          | 0/4 [00:00<?, ?it/s]
# Epoch 050/60 | train_loss=0.7139 train_acc=84.93% train_bacc=84.42% train_auc=0.9799 train_f1=0.8253 | val_loss=0.8637 val_acc=77.39% val_bacc=76.64% val_auc=0.9539 val_f1=0.7084
# cnn_late_fusion train epoch 51/60:   0%|          | 0/29 [00:00<?, ?it/s]
# cnn_late_fusion val epoch 51/60:   0%|          | 0/4 [00:00<?, ?it/s]
# Epoch 051/60 | train_loss=0.7213 train_acc=85.15% train_bacc=82.78% train_auc=0.9775 train_f1=0.8145 | val_loss=0.8726 val_acc=76.52% val_bacc=74.60% val_auc=0.9521 val_f1=0.6933
# cnn_late_fusion train epoch 52/60:   0%|          | 0/29 [00:00<?, ?it/s]
# cnn_late_fusion val epoch 52/60:   0%|          | 0/4 [00:00<?, ?it/s]
# Epoch 052/60 | train_loss=0.7282 train_acc=84.22% train_bacc=82.05% train_auc=0.9779 train_f1=0.8056 | val_loss=0.8624 val_acc=77.83% val_bacc=76.58% val_auc=0.9535 val_f1=0.7125
# cnn_late_fusion train epoch 53/60:   0%|          | 0/29 [00:00<?, ?it/s]
# cnn_late_fusion val epoch 53/60:   0%|          | 0/4 [00:00<?, ?it/s]
# Epoch 053/60 | train_loss=0.7195 train_acc=84.98% train_bacc=83.09% train_auc=0.9792 train_f1=0.8134 | val_loss=0.8654 val_acc=76.09% val_bacc=75.08% val_auc=0.9529 val_f1=0.6924
# cnn_late_fusion train epoch 54/60:   0%|          | 0/29 [00:00<?, ?it/s]
# cnn_late_fusion val epoch 54/60:   0%|          | 0/4 [00:00<?, ?it/s]
# Epoch 054/60 | train_loss=0.7055 train_acc=86.62% train_bacc=83.78% train_auc=0.9803 train_f1=0.8265 | val_loss=0.8766 val_acc=76.52% val_bacc=76.20% val_auc=0.9519 val_f1=0.6951
# cnn_late_fusion train epoch 55/60:   0%|          | 0/29 [00:00<?, ?it/s]
# cnn_late_fusion val epoch 55/60:   0%|          | 0/4 [00:00<?, ?it/s]
# Epoch 055/60 | train_loss=0.7094 train_acc=86.72% train_bacc=85.35% train_auc=0.9809 train_f1=0.8361 | val_loss=0.8944 val_acc=77.39% val_bacc=77.15% val_auc=0.9484 val_f1=0.7111
# Early stopping at epoch 55: no validation macro-F1 improvement for 12 epochs.
# cnn_late_fusion test:   0%|          | 0/4 [00:00<?, ?it/s]
# wandb: WARNING Saving files without folders. If you want to preserve subdirectories pass base_path to wandb.save, i.e. wandb.save("/mnt/folder/file.h5", base_path="/mnt")
# wandb: WARNING Symlinked 1 file into the W&B run directory; call wandb.save again to sync new files.
# wandb: WARNING Symlinked 1 file into the W&B run directory; call wandb.save again to sync new files.
# wandb: WARNING Symlinked 1 file into the W&B run directory; call wandb.save again to sync new files.
# wandb: WARNING Symlinked 1 file into the W&B run directory; call wandb.save again to sync new files.
# wandb: WARNING Symlinked 1 file into the W&B run directory; call wandb.save again to sync new files.
# wandb: updating run metadata
# wandb:
# wandb: Run history:
# wandb:                elapsed_sec ▁▁▁▁▂▂▂▂▂▂▃▃▃▃▃▃▄▄▄▄▄▅▅▅▅▅▅▆▆▆▆▇▇▇▇▇▇███
# wandb:                      epoch ▁▁▁▂▂▂▂▂▂▂▃▃▃▃▃▄▄▄▄▄▅▅▅▅▆▆▆▆▆▆▇▇▇▇▇▇▇███
# wandb: epochs_without_improvement ▁▁▁▁▁▂▁▂▁▂▃▁▂▂▃▁▁▁▁▂▁▂▁▂▃▅▅▆▆▇▁▂▂▃▄▅▆▆▇█
# wandb:                         lr ███████████████████████████▄▄▄▄▄▄▄▄▂▂▂▂▁
# wandb:                  train_acc ▁▂▄▅▅▆▆▆▆▇▇▇▆▇▇▇▇▇▇▇▇▇▇▇▇▇▇▇████████████
# wandb:                  train_auc ▁▄▅▆▆▇▇▇▇▇▇▇▇▇▇█████████████████████████
# wandb:                 train_bacc ▁▃▄▄▄▆▅▆▆▆▆▆▇▇▇▇▇▇▇▇▇▇▇▇▇▇▇█▇▇██████████
# wandb:             train_f1_macro ▁▂▄▅▅▆▆▆▆▆▆▆▇▇▇▇▇▇▇▇▇▇▇▇▇▇█▇▇██████▇████
# wandb:                 train_loss █▇▆▅▅▃▃▃▃▃▂▂▂▂▂▂▂▂▂▂▂▂▂▂▂▂▁▁▁▁▁▁▁▁▁▁▁▁▁▁
# wandb:                    val_acc ▂▁▂▃▄▇▆▆▆▇▇▇▆▇▇▇▇▇▇▇▇█▇▇▇██▇█▇▇█▇▇▇▇█▇██
# wandb:                         +4 ...
# wandb:
# wandb: Run summary:
# wandb:                 best_epoch 43
# wandb:               best_val_acc 79.56522
# wandb:               best_val_auc 0.95123
# wandb:              best_val_bacc 78.60808
# wandb:          best_val_f1_macro 0.73188
# wandb:                elapsed_sec 244.15997
# wandb:                      epoch 55
# wandb: epochs_without_improvement 12
# wandb:                         lr 4e-05
# wandb:                   test_acc 77.82609
# wandb:                        +13 ...
# wandb:
# wandb: 🚀 View run cnn_late_fusion at: https://wandb.ai/belalofficial123-the-british-university-in-egypt/iot%20fusion/runs/b0jmmpw8
# wandb: ⭐️ View project at: https://wandb.ai/belalofficial123-the-british-university-in-egypt/iot%20fusion
# wandb: Synced 5 W&B file(s), 4 media file(s), 0 artifact file(s) and 5 other file(s)
# wandb: Find logs at: ./wandb/run-20260416_192019-b0jmmpw8/logs
# Test performance:
# test_loss=0.9137 test_acc=77.83% test_bacc=75.33% test_auc=0.9399 test_f1=0.7311
# Classification report:
#               precision    recall  f1-score     support
# ACK            0.910448  0.835616  0.871429   73.000000
# BCC            0.795181  0.776471  0.785714   85.000000
# MEL            0.666667  0.800000  0.727273    5.000000
# NEV            0.750000  0.875000  0.807692   24.000000
# SCC            0.409091  0.450000  0.428571   20.000000
# SEK            0.750000  0.782609  0.765957   23.000000
# accuracy       0.778261  0.778261  0.778261    0.778261
# macro avg      0.713564  0.753283  0.731106  230.000000
# weighted avg   0.786166  0.778261  0.780911  230.000000
# cnn_late_fusion complete: best_epoch=43, test_acc=77.83%
# {'experiment_name': 'cnn_late_fusion',
#  'model_name': 'cnn',
#  'input_mode': 'late_fusion',
#  'epochs': 60,
#  'batch_size': 64,
#  'split': '80 train / 10 validation / 10 test',
#  'augment_train': True,
#  'class_weighted_loss': True,
#  'class_weight_power': 0.5,
#  'class_balanced_sampler': False,
#  'best_epoch': 43,
#  'best_val_acc': 79.56521739130434,
#  'best_val_bacc': 78.60808127624998,
#  'best_val_auc': 0.9512322411242452,
#  'best_val_f1_macro': 0.7318775931274032,
#  'final_train_loss': 0.709390529221627,
#  'final_train_acc': 86.72470076169749,
#  'final_train_bacc': 85.34713903382392,
#  'final_train_auc': 0.9808552037155996,
#  'final_train_f1_macro': 0.836081811575886,
#  'final_val_loss': 0.8944154024124146,
#  'final_val_acc': 77.39130434782608,
#  'final_val_bacc': 77.14988384202516,
#  'final_val_auc': 0.9483678291186206,
#  'final_val_f1_macro': 0.711069697769251,
#  'test_loss': 0.9136674823968307,
#  'test_acc': 77.82608695652173,
#  'test_bacc': 75.32826203739388,
#  'test_auc': 0.9398811212759709,
#  'test_f1_macro': 0.7311061279146385,
#  'elapsed_sec': 244.15996956825256,
#  'metrics_path': '/home/zeus/content/IOT_fusion/Results_Logs/cnn_late_fusion/epoch_metrics.csv',
#  'epoch_log_path': '/home/zeus/content/IOT_fusion/Results_Logs/cnn_late_fusion/epoch_log.txt',
#  'split_summary_path': '/home/zeus/content/IOT_fusion/Results_Logs/cnn_late_fusion/split_summary.csv',
#  'checkpoint_path': '/home/zeus/content/IOT_fusion/outputs/ablations/cnn_late_fusion_best.pth',
#  'classification_report_path': '/home/zeus/content/IOT_fusion/Results_Logs/cnn_late_fusion/classification_report.csv',
#  'confusion_matrix_path': '/home/zeus/content/IOT_fusion/Results_Logs/cnn_late_fusion/confusion_matrix.csv',
#  'test_predictions_path': '/home/zeus/content/IOT_fusion/Results_Logs/cnn_late_fusion/test_predictions.csv',
#  'loss_curve_path': '/home/zeus/content/IOT_fusion/Results_Figures/cnn_late_fusion/loss_curve.png',
#  'epoch_metrics_curve_path': '/home/zeus/content/IOT_fusion/Results_Figures/cnn_late_fusion/epoch_metrics.png',
#  'confusion_matrix_plot_path': '/home/zeus/content/IOT_fusion/Results_Figures/cnn_late_fusion/confusion_matrix.png',
#  'roc_curve_path': '/home/zeus/content/IOT_fusion/Results_Figures/cnn_late_fusion/roc_curve.png',
#  'xai_paths': "{'image_saliency': '/home/zeus/content/IOT_fusion/Results_XAI/cnn_late_fusion/cnn_late_fusion_image_saliency.npy', 'metadata_importance': '/home/zeus/content/IOT_fusion/Results_XAI/cnn_late_fusion/cnn_late_fusion_metadata_xai_top20.csv'}"}

# %% [markdown]
# ## Training Outputs

# %%
from pathlib import Path
output_dir = Path('outputs/ablations')
logs_dir = Path('Results_Logs') / 'cnn_late_fusion'
figures_dir = Path('Results_Figures') / 'cnn_late_fusion'
xai_dir = Path('Results_XAI') / 'cnn_late_fusion'
print('metrics:', logs_dir / 'epoch_metrics.csv')
print('epoch log:', logs_dir / 'epoch_log.txt')
print('result:', logs_dir / 'result_summary.csv')
print('checkpoint:', output_dir / 'cnn_late_fusion_best.pth')
print('classification report:', logs_dir / 'classification_report.csv')
print('confusion matrix CSV:', logs_dir / 'confusion_matrix.csv')
print('loss curve:', figures_dir / 'loss_curve.png')
print('roc curve:', figures_dir / 'roc_curve.png')
sorted(str(p) for p in list(logs_dir.glob('*')) + list(figures_dir.glob('*')) + list(xai_dir.glob('*')))
# Out:
# metrics: Results_Logs/cnn_late_fusion/epoch_metrics.csv
# epoch log: Results_Logs/cnn_late_fusion/epoch_log.txt
# result: Results_Logs/cnn_late_fusion/result_summary.csv
# checkpoint: outputs/ablations/cnn_late_fusion_best.pth
# classification report: Results_Logs/cnn_late_fusion/classification_report.csv
# confusion matrix CSV: Results_Logs/cnn_late_fusion/confusion_matrix.csv
# loss curve: Results_Figures/cnn_late_fusion/loss_curve.png
# roc curve: Results_Figures/cnn_late_fusion/roc_curve.png
# ['Results_Figures/cnn_late_fusion/confusion_matrix.png',
#  'Results_Figures/cnn_late_fusion/epoch_metrics.png',
#  'Results_Figures/cnn_late_fusion/loss_curve.png',
#  'Results_Figures/cnn_late_fusion/roc_curve.png',
#  'Results_Logs/cnn_late_fusion/classification_report.csv',
#  'Results_Logs/cnn_late_fusion/confusion_matrix.csv',
#  'Results_Logs/cnn_late_fusion/epoch_log.txt',
#  'Results_Logs/cnn_late_fusion/epoch_metrics.csv',
#  'Results_Logs/cnn_late_fusion/result_summary.csv',
#  'Results_Logs/cnn_late_fusion/split_summary.csv',
#  'Results_Logs/cnn_late_fusion/test_predictions.csv',
#  'Results_XAI/cnn_late_fusion/cnn_late_fusion_image_saliency.npy',
#  'Results_XAI/cnn_late_fusion/cnn_late_fusion_metadata_xai_top20.csv']
