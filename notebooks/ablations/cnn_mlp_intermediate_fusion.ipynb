# %% [markdown]
# # CNN Intermediate Fusion Ablation
#
# Experiment: `cnn_inter_fusion`
#
# This notebook runs full GPU training on a stratified 80/10/10 train/validation/test split built from the extracted processed tabular data and image tensors. Image runs use tensor-safe train augmentation and class-weighted loss. CNN runs use tempered class-weighted loss, stronger paper-style augmentation, and early stopping to reduce overfitting; balanced sampling can be enabled manually, but is off by default because it over-corrected on this dataset. Fusion modes combine the tabular metadata vector with the image tensor. It prints per-epoch train/validation loss, accuracy, macro AUC, and macro F1 with tqdm progress bars. Epoch logs are written under `Results_Logs/<experiment>/`, figures under `Results_Figures/<experiment>/`, and XAI artifacts under `Results_XAI/<experiment>/`.

# %%
from pathlib import Path
import os, sys
REPO_ROOT = Path('/home/zeus/content/IOT_fusion')
os.chdir(REPO_ROOT)
sys.path.insert(0, str(REPO_ROOT / 'training'))
from ablation_utils import get_data_info, run_training

info = get_data_info()
print('classes:', info.class_to_idx)
print('metadata_dim:', info.metadata_dim)
# Out:
# classes: {'ACK': 0, 'BCC': 1, 'MEL': 2, 'NEV': 3, 'SCC': 4, 'SEK': 5}
# metadata_dim: 87

# %% [markdown]
# ## Full GPU Training
# Adjust `epochs` and `batch_size` if needed.

# %%
full_result = run_training(
    model_name='cnn',
    input_mode='intermediate_fusion',
    experiment_name='cnn_inter_fusion',
    epochs=60,
    batch_size=64,
    lr=0.0003,
    num_workers=2,
    device_name='cuda',
    wandb_enabled=True,
    xai_enabled=True,
    augment_train=True,
    class_weighted_loss=True,
    class_weight_power=0.5,
    class_balanced_sampler=False,
    early_stopping_patience=12,
    min_epochs=15,
)
full_result
# Out:
# wandb: [wandb.login()] Loaded credentials for https://api.wandb.ai from WANDB_API_KEY.
# wandb: Currently logged in as: belalofficial123 (belalofficial123-the-british-university-in-egypt) to https://api.wandb.ai. Use `wandb login --relogin` to force relogin
# wandb: Tracking run with wandb version 0.26.0
# wandb: Run data is saved locally in /home/zeus/content/IOT_fusion/wandb/run-20260416_191540-1xf2gl90
# wandb: Run `wandb offline` to turn off syncing.
# wandb: Syncing run cnn_inter_fusion
# wandb: ⭐️ View project at https://wandb.ai/belalofficial123-the-british-university-in-egypt/iot%20fusion
# wandb: 🚀 View run at https://wandb.ai/belalofficial123-the-british-university-in-egypt/iot%20fusion/runs/1xf2gl90
# Split sizes: {'train': 1838, 'val': 230, 'test': 230}
# Class mapping: {'ACK': 0, 'BCC': 1, 'MEL': 2, 'NEV': 3, 'SCC': 4, 'SEK': 5}
# cnn_inter_fusion train epoch 1/60:   0%|          | 0/29 [00:00<?, ?it/s]
# cnn_inter_fusion val epoch 1/60:   0%|          | 0/4 [00:00<?, ?it/s]
# Epoch 001/60 | train_loss=1.7068 train_acc=35.20% train_bacc=27.47% train_auc=0.6360 train_f1=0.2636 | val_loss=1.5919 val_acc=59.57% val_bacc=35.64% val_auc=0.8205 val_f1=0.3263
# cnn_inter_fusion train epoch 2/60:   0%|          | 0/29 [00:00<?, ?it/s]
# cnn_inter_fusion val epoch 2/60:   0%|          | 0/4 [00:00<?, ?it/s]
# Epoch 002/60 | train_loss=1.5409 train_acc=51.80% train_bacc=34.82% train_auc=0.7482 train_f1=0.3202 | val_loss=1.4742 val_acc=60.43% val_bacc=39.40% val_auc=0.8331 val_f1=0.3590
# cnn_inter_fusion train epoch 3/60:   0%|          | 0/29 [00:00<?, ?it/s]
# cnn_inter_fusion val epoch 3/60:   0%|          | 0/4 [00:00<?, ?it/s]
# Epoch 003/60 | train_loss=1.4048 train_acc=62.73% train_bacc=41.93% train_auc=0.8197 train_f1=0.4087 | val_loss=1.3572 val_acc=62.61% val_bacc=40.98% val_auc=0.8642 val_f1=0.3836
# cnn_inter_fusion train epoch 4/60:   0%|          | 0/29 [00:00<?, ?it/s]
# cnn_inter_fusion val epoch 4/60:   0%|          | 0/4 [00:00<?, ?it/s]
# Epoch 004/60 | train_loss=1.2909 train_acc=64.53% train_bacc=47.36% train_auc=0.8538 train_f1=0.4859 | val_loss=1.2436 val_acc=64.35% val_bacc=44.26% val_auc=0.8927 val_f1=0.4256
# cnn_inter_fusion train epoch 5/60:   0%|          | 0/29 [00:00<?, ?it/s]
# cnn_inter_fusion val epoch 5/60:   0%|          | 0/4 [00:00<?, ?it/s]
# Epoch 005/60 | train_loss=1.2271 train_acc=67.63% train_bacc=49.77% train_auc=0.8695 train_f1=0.5180 | val_loss=1.1729 val_acc=69.13% val_bacc=55.37% val_auc=0.9098 val_f1=0.5086
# cnn_inter_fusion train epoch 6/60:   0%|          | 0/29 [00:00<?, ?it/s]
# cnn_inter_fusion val epoch 6/60:   0%|          | 0/4 [00:00<?, ?it/s]
# Epoch 006/60 | train_loss=1.1474 train_acc=71.27% train_bacc=54.92% train_auc=0.8930 train_f1=0.5663 | val_loss=1.0977 val_acc=74.78% val_bacc=63.39% val_auc=0.9264 val_f1=0.6247
# cnn_inter_fusion train epoch 7/60:   0%|          | 0/29 [00:00<?, ?it/s]
# cnn_inter_fusion val epoch 7/60:   0%|          | 0/4 [00:00<?, ?it/s]
# Epoch 007/60 | train_loss=1.1011 train_acc=72.52% train_bacc=58.46% train_auc=0.9078 train_f1=0.5872 | val_loss=1.0488 val_acc=73.91% val_bacc=62.75% val_auc=0.9272 val_f1=0.5907
# cnn_inter_fusion train epoch 8/60:   0%|          | 0/29 [00:00<?, ?it/s]
# cnn_inter_fusion val epoch 8/60:   0%|          | 0/4 [00:00<?, ?it/s]
# Epoch 008/60 | train_loss=1.0665 train_acc=73.56% train_bacc=62.32% train_auc=0.9109 train_f1=0.6202 | val_loss=1.0396 val_acc=73.04% val_bacc=63.46% val_auc=0.9251 val_f1=0.5780
# cnn_inter_fusion train epoch 9/60:   0%|          | 0/29 [00:00<?, ?it/s]
# cnn_inter_fusion val epoch 9/60:   0%|          | 0/4 [00:00<?, ?it/s]
# Epoch 009/60 | train_loss=1.0298 train_acc=75.46% train_bacc=63.42% train_auc=0.9218 train_f1=0.6408 | val_loss=1.0121 val_acc=74.35% val_bacc=65.89% val_auc=0.9334 val_f1=0.6230
# cnn_inter_fusion train epoch 10/60:   0%|          | 0/29 [00:00<?, ?it/s]
# cnn_inter_fusion val epoch 10/60:   0%|          | 0/4 [00:00<?, ?it/s]
# Epoch 010/60 | train_loss=1.0065 train_acc=75.24% train_bacc=64.63% train_auc=0.9281 train_f1=0.6552 | val_loss=0.9804 val_acc=73.48% val_bacc=64.96% val_auc=0.9380 val_f1=0.6261
# cnn_inter_fusion train epoch 11/60:   0%|          | 0/29 [00:00<?, ?it/s]
# cnn_inter_fusion val epoch 11/60:   0%|          | 0/4 [00:00<?, ?it/s]
# Epoch 011/60 | train_loss=0.9976 train_acc=74.32% train_bacc=64.10% train_auc=0.9313 train_f1=0.6309 | val_loss=0.9673 val_acc=74.78% val_bacc=63.85% val_auc=0.9418 val_f1=0.6180
# cnn_inter_fusion train epoch 12/60:   0%|          | 0/29 [00:00<?, ?it/s]
# cnn_inter_fusion val epoch 12/60:   0%|          | 0/4 [00:00<?, ?it/s]
# Epoch 012/60 | train_loss=0.9769 train_acc=75.95% train_bacc=68.04% train_auc=0.9341 train_f1=0.6648 | val_loss=0.9650 val_acc=73.04% val_bacc=65.16% val_auc=0.9393 val_f1=0.6117
# cnn_inter_fusion train epoch 13/60:   0%|          | 0/29 [00:00<?, ?it/s]
# cnn_inter_fusion val epoch 13/60:   0%|          | 0/4 [00:00<?, ?it/s]
# Epoch 013/60 | train_loss=0.9480 train_acc=76.33% train_bacc=68.95% train_auc=0.9406 train_f1=0.6729 | val_loss=0.9461 val_acc=75.22% val_bacc=68.44% val_auc=0.9418 val_f1=0.6534
# cnn_inter_fusion train epoch 14/60:   0%|          | 0/29 [00:00<?, ?it/s]
# cnn_inter_fusion val epoch 14/60:   0%|          | 0/4 [00:00<?, ?it/s]
# Epoch 014/60 | train_loss=0.9504 train_acc=76.82% train_bacc=70.27% train_auc=0.9400 train_f1=0.6905 | val_loss=0.9152 val_acc=76.96% val_bacc=72.71% val_auc=0.9481 val_f1=0.6893
# cnn_inter_fusion train epoch 15/60:   0%|          | 0/29 [00:00<?, ?it/s]
# cnn_inter_fusion val epoch 15/60:   0%|          | 0/4 [00:00<?, ?it/s]
# Epoch 015/60 | train_loss=0.9402 train_acc=76.39% train_bacc=70.01% train_auc=0.9418 train_f1=0.6797 | val_loss=0.9213 val_acc=75.65% val_bacc=71.63% val_auc=0.9486 val_f1=0.6945
# cnn_inter_fusion train epoch 16/60:   0%|          | 0/29 [00:00<?, ?it/s]
# cnn_inter_fusion val epoch 16/60:   0%|          | 0/4 [00:00<?, ?it/s]
# Epoch 016/60 | train_loss=0.9204 train_acc=76.77% train_bacc=71.58% train_auc=0.9451 train_f1=0.6912 | val_loss=0.9142 val_acc=77.39% val_bacc=74.78% val_auc=0.9459 val_f1=0.6932
# cnn_inter_fusion train epoch 17/60:   0%|          | 0/29 [00:00<?, ?it/s]
# cnn_inter_fusion val epoch 17/60:   0%|          | 0/4 [00:00<?, ?it/s]
# Epoch 017/60 | train_loss=0.9150 train_acc=76.22% train_bacc=72.19% train_auc=0.9463 train_f1=0.6985 | val_loss=0.9177 val_acc=75.65% val_bacc=70.07% val_auc=0.9474 val_f1=0.6722
# cnn_inter_fusion train epoch 18/60:   0%|          | 0/29 [00:00<?, ?it/s]
# cnn_inter_fusion val epoch 18/60:   0%|          | 0/4 [00:00<?, ?it/s]
# Epoch 018/60 | train_loss=0.9144 train_acc=76.82% train_bacc=71.55% train_auc=0.9441 train_f1=0.6964 | val_loss=0.9111 val_acc=76.96% val_bacc=72.80% val_auc=0.9443 val_f1=0.6814
# cnn_inter_fusion train epoch 19/60:   0%|          | 0/29 [00:00<?, ?it/s]
# cnn_inter_fusion val epoch 19/60:   0%|          | 0/4 [00:00<?, ?it/s]
# Epoch 019/60 | train_loss=0.9163 train_acc=77.97% train_bacc=71.73% train_auc=0.9466 train_f1=0.7092 | val_loss=0.9177 val_acc=76.09% val_bacc=71.58% val_auc=0.9470 val_f1=0.6731
# cnn_inter_fusion train epoch 20/60:   0%|          | 0/29 [00:00<?, ?it/s]
# cnn_inter_fusion val epoch 20/60:   0%|          | 0/4 [00:00<?, ?it/s]
# Epoch 020/60 | train_loss=0.8955 train_acc=78.89% train_bacc=74.44% train_auc=0.9473 train_f1=0.7206 | val_loss=0.9192 val_acc=74.78% val_bacc=72.35% val_auc=0.9414 val_f1=0.6683
# cnn_inter_fusion train epoch 21/60:   0%|          | 0/29 [00:00<?, ?it/s]
# cnn_inter_fusion val epoch 21/60:   0%|          | 0/4 [00:00<?, ?it/s]
# Epoch 021/60 | train_loss=0.8974 train_acc=78.40% train_bacc=74.62% train_auc=0.9480 train_f1=0.7133 | val_loss=0.8992 val_acc=78.26% val_bacc=74.77% val_auc=0.9473 val_f1=0.7138
# cnn_inter_fusion train epoch 22/60:   0%|          | 0/29 [00:00<?, ?it/s]
# cnn_inter_fusion val epoch 22/60:   0%|          | 0/4 [00:00<?, ?it/s]
# Epoch 022/60 | train_loss=0.9064 train_acc=77.48% train_bacc=72.62% train_auc=0.9463 train_f1=0.7010 | val_loss=0.8949 val_acc=78.70% val_bacc=75.15% val_auc=0.9483 val_f1=0.7165
# cnn_inter_fusion train epoch 23/60:   0%|          | 0/29 [00:00<?, ?it/s]
# cnn_inter_fusion val epoch 23/60:   0%|          | 0/4 [00:00<?, ?it/s]
# Epoch 023/60 | train_loss=0.8853 train_acc=78.40% train_bacc=73.90% train_auc=0.9518 train_f1=0.7150 | val_loss=0.8927 val_acc=76.96% val_bacc=72.09% val_auc=0.9503 val_f1=0.6838
# cnn_inter_fusion train epoch 24/60:   0%|          | 0/29 [00:00<?, ?it/s]
# cnn_inter_fusion val epoch 24/60:   0%|          | 0/4 [00:00<?, ?it/s]
# Epoch 024/60 | train_loss=0.8759 train_acc=78.67% train_bacc=73.12% train_auc=0.9522 train_f1=0.7154 | val_loss=0.8833 val_acc=78.26% val_bacc=75.28% val_auc=0.9524 val_f1=0.7174
# cnn_inter_fusion train epoch 25/60:   0%|          | 0/29 [00:00<?, ?it/s]
# cnn_inter_fusion val epoch 25/60:   0%|          | 0/4 [00:00<?, ?it/s]
# Epoch 025/60 | train_loss=0.8732 train_acc=78.35% train_bacc=74.81% train_auc=0.9523 train_f1=0.7165 | val_loss=0.8977 val_acc=77.39% val_bacc=74.09% val_auc=0.9473 val_f1=0.6927
# cnn_inter_fusion train epoch 26/60:   0%|          | 0/29 [00:00<?, ?it/s]
# cnn_inter_fusion val epoch 26/60:   0%|          | 0/4 [00:00<?, ?it/s]
# Epoch 026/60 | train_loss=0.8575 train_acc=79.43% train_bacc=75.66% train_auc=0.9559 train_f1=0.7410 | val_loss=0.8933 val_acc=78.70% val_bacc=76.79% val_auc=0.9464 val_f1=0.7066
# cnn_inter_fusion train epoch 27/60:   0%|          | 0/29 [00:00<?, ?it/s]
# cnn_inter_fusion val epoch 27/60:   0%|          | 0/4 [00:00<?, ?it/s]
# Epoch 027/60 | train_loss=0.8600 train_acc=79.76% train_bacc=75.23% train_auc=0.9550 train_f1=0.7283 | val_loss=0.8760 val_acc=80.00% val_bacc=76.30% val_auc=0.9513 val_f1=0.7314
# cnn_inter_fusion train epoch 28/60:   0%|          | 0/29 [00:00<?, ?it/s]
# cnn_inter_fusion val epoch 28/60:   0%|          | 0/4 [00:00<?, ?it/s]
# Epoch 028/60 | train_loss=0.8527 train_acc=79.27% train_bacc=76.00% train_auc=0.9559 train_f1=0.7419 | val_loss=0.8799 val_acc=77.39% val_bacc=75.32% val_auc=0.9494 val_f1=0.7139
# cnn_inter_fusion train epoch 29/60:   0%|          | 0/29 [00:00<?, ?it/s]
# cnn_inter_fusion val epoch 29/60:   0%|          | 0/4 [00:00<?, ?it/s]
# Epoch 029/60 | train_loss=0.8490 train_acc=79.65% train_bacc=76.77% train_auc=0.9572 train_f1=0.7423 | val_loss=0.8959 val_acc=77.83% val_bacc=75.15% val_auc=0.9480 val_f1=0.7223
# cnn_inter_fusion train epoch 30/60:   0%|          | 0/29 [00:00<?, ?it/s]
# cnn_inter_fusion val epoch 30/60:   0%|          | 0/4 [00:00<?, ?it/s]
# Epoch 030/60 | train_loss=0.8693 train_acc=79.60% train_bacc=75.53% train_auc=0.9527 train_f1=0.7352 | val_loss=0.8929 val_acc=79.13% val_bacc=77.45% val_auc=0.9443 val_f1=0.7270
# cnn_inter_fusion train epoch 31/60:   0%|          | 0/29 [00:00<?, ?it/s]
# cnn_inter_fusion val epoch 31/60:   0%|          | 0/4 [00:00<?, ?it/s]
# Epoch 031/60 | train_loss=0.8377 train_acc=80.41% train_bacc=77.44% train_auc=0.9590 train_f1=0.7547 | val_loss=0.8962 val_acc=78.70% val_bacc=74.28% val_auc=0.9479 val_f1=0.7124
# cnn_inter_fusion train epoch 32/60:   0%|          | 0/29 [00:00<?, ?it/s]
# cnn_inter_fusion val epoch 32/60:   0%|          | 0/4 [00:00<?, ?it/s]
# Epoch 032/60 | train_loss=0.8410 train_acc=80.69% train_bacc=77.66% train_auc=0.9592 train_f1=0.7521 | val_loss=0.8751 val_acc=80.00% val_bacc=76.98% val_auc=0.9483 val_f1=0.7358
# cnn_inter_fusion train epoch 33/60:   0%|          | 0/29 [00:00<?, ?it/s]
# cnn_inter_fusion val epoch 33/60:   0%|          | 0/4 [00:00<?, ?it/s]
# Epoch 033/60 | train_loss=0.8386 train_acc=79.60% train_bacc=76.01% train_auc=0.9582 train_f1=0.7429 | val_loss=0.8839 val_acc=80.00% val_bacc=77.42% val_auc=0.9469 val_f1=0.7394
# cnn_inter_fusion train epoch 34/60:   0%|          | 0/29 [00:00<?, ?it/s]
# cnn_inter_fusion val epoch 34/60:   0%|          | 0/4 [00:00<?, ?it/s]
# Epoch 034/60 | train_loss=0.8141 train_acc=81.56% train_bacc=78.07% train_auc=0.9622 train_f1=0.7648 | val_loss=0.9113 val_acc=77.39% val_bacc=75.58% val_auc=0.9501 val_f1=0.7334
# cnn_inter_fusion train epoch 35/60:   0%|          | 0/29 [00:00<?, ?it/s]
# cnn_inter_fusion val epoch 35/60:   0%|          | 0/4 [00:00<?, ?it/s]
# Epoch 035/60 | train_loss=0.8226 train_acc=80.63% train_bacc=77.61% train_auc=0.9610 train_f1=0.7551 | val_loss=0.8723 val_acc=80.00% val_bacc=76.24% val_auc=0.9515 val_f1=0.7456
# cnn_inter_fusion train epoch 36/60:   0%|          | 0/29 [00:00<?, ?it/s]
# cnn_inter_fusion val epoch 36/60:   0%|          | 0/4 [00:00<?, ?it/s]
# Epoch 036/60 | train_loss=0.8138 train_acc=81.61% train_bacc=77.43% train_auc=0.9630 train_f1=0.7650 | val_loss=0.8765 val_acc=76.96% val_bacc=75.06% val_auc=0.9506 val_f1=0.7251
# cnn_inter_fusion train epoch 37/60:   0%|          | 0/29 [00:00<?, ?it/s]
# cnn_inter_fusion val epoch 37/60:   0%|          | 0/4 [00:00<?, ?it/s]
# Epoch 037/60 | train_loss=0.8210 train_acc=81.07% train_bacc=79.62% train_auc=0.9612 train_f1=0.7675 | val_loss=0.8665 val_acc=78.70% val_bacc=75.42% val_auc=0.9514 val_f1=0.7271
# cnn_inter_fusion train epoch 38/60:   0%|          | 0/29 [00:00<?, ?it/s]
# cnn_inter_fusion val epoch 38/60:   0%|          | 0/4 [00:00<?, ?it/s]
# Epoch 038/60 | train_loss=0.8024 train_acc=81.45% train_bacc=78.96% train_auc=0.9658 train_f1=0.7700 | val_loss=0.8788 val_acc=79.57% val_bacc=76.57% val_auc=0.9474 val_f1=0.7317
# cnn_inter_fusion train epoch 39/60:   0%|          | 0/29 [00:00<?, ?it/s]
# cnn_inter_fusion val epoch 39/60:   0%|          | 0/4 [00:00<?, ?it/s]
# Epoch 039/60 | train_loss=0.8160 train_acc=80.96% train_bacc=77.90% train_auc=0.9628 train_f1=0.7544 | val_loss=0.8804 val_acc=80.43% val_bacc=76.18% val_auc=0.9489 val_f1=0.7512
# cnn_inter_fusion train epoch 40/60:   0%|          | 0/29 [00:00<?, ?it/s]
# cnn_inter_fusion val epoch 40/60:   0%|          | 0/4 [00:00<?, ?it/s]
# Epoch 040/60 | train_loss=0.7974 train_acc=81.88% train_bacc=79.42% train_auc=0.9657 train_f1=0.7727 | val_loss=0.8788 val_acc=76.09% val_bacc=75.87% val_auc=0.9470 val_f1=0.7184
# cnn_inter_fusion train epoch 41/60:   0%|          | 0/29 [00:00<?, ?it/s]
# cnn_inter_fusion val epoch 41/60:   0%|          | 0/4 [00:00<?, ?it/s]
# Epoch 041/60 | train_loss=0.8077 train_acc=80.79% train_bacc=77.45% train_auc=0.9648 train_f1=0.7558 | val_loss=0.8672 val_acc=80.43% val_bacc=77.68% val_auc=0.9482 val_f1=0.7440
# cnn_inter_fusion train epoch 42/60:   0%|          | 0/29 [00:00<?, ?it/s]
# cnn_inter_fusion val epoch 42/60:   0%|          | 0/4 [00:00<?, ?it/s]
# Epoch 042/60 | train_loss=0.8024 train_acc=81.18% train_bacc=78.39% train_auc=0.9651 train_f1=0.7528 | val_loss=0.8782 val_acc=79.13% val_bacc=75.09% val_auc=0.9508 val_f1=0.7289
# cnn_inter_fusion train epoch 43/60:   0%|          | 0/29 [00:00<?, ?it/s]
# cnn_inter_fusion val epoch 43/60:   0%|          | 0/4 [00:00<?, ?it/s]
# Epoch 043/60 | train_loss=0.7949 train_acc=81.50% train_bacc=77.57% train_auc=0.9675 train_f1=0.7581 | val_loss=0.8656 val_acc=80.00% val_bacc=76.95% val_auc=0.9492 val_f1=0.7408
# cnn_inter_fusion train epoch 44/60:   0%|          | 0/29 [00:00<?, ?it/s]
# cnn_inter_fusion val epoch 44/60:   0%|          | 0/4 [00:00<?, ?it/s]
# Epoch 044/60 | train_loss=0.7834 train_acc=82.75% train_bacc=80.34% train_auc=0.9679 train_f1=0.7847 | val_loss=0.8801 val_acc=77.39% val_bacc=74.99% val_auc=0.9491 val_f1=0.7249
# cnn_inter_fusion train epoch 45/60:   0%|          | 0/29 [00:00<?, ?it/s]
# cnn_inter_fusion val epoch 45/60:   0%|          | 0/4 [00:00<?, ?it/s]
# Epoch 045/60 | train_loss=0.8013 train_acc=81.88% train_bacc=79.60% train_auc=0.9651 train_f1=0.7772 | val_loss=0.8997 val_acc=80.87% val_bacc=75.55% val_auc=0.9465 val_f1=0.7497
# cnn_inter_fusion train epoch 46/60:   0%|          | 0/29 [00:00<?, ?it/s]
# cnn_inter_fusion val epoch 46/60:   0%|          | 0/4 [00:00<?, ?it/s]
# Epoch 046/60 | train_loss=0.7886 train_acc=82.32% train_bacc=80.55% train_auc=0.9677 train_f1=0.7778 | val_loss=0.8629 val_acc=79.13% val_bacc=76.74% val_auc=0.9491 val_f1=0.7412
# cnn_inter_fusion train epoch 47/60:   0%|          | 0/29 [00:00<?, ?it/s]
# cnn_inter_fusion val epoch 47/60:   0%|          | 0/4 [00:00<?, ?it/s]
# Epoch 047/60 | train_loss=0.7720 train_acc=82.26% train_bacc=79.77% train_auc=0.9705 train_f1=0.7784 | val_loss=0.8692 val_acc=79.57% val_bacc=75.61% val_auc=0.9486 val_f1=0.7438
# cnn_inter_fusion train epoch 48/60:   0%|          | 0/29 [00:00<?, ?it/s]
# cnn_inter_fusion val epoch 48/60:   0%|          | 0/4 [00:00<?, ?it/s]
# Epoch 048/60 | train_loss=0.7757 train_acc=82.97% train_bacc=80.04% train_auc=0.9690 train_f1=0.7838 | val_loss=0.8786 val_acc=80.87% val_bacc=77.82% val_auc=0.9471 val_f1=0.7594
# cnn_inter_fusion train epoch 49/60:   0%|          | 0/29 [00:00<?, ?it/s]
# cnn_inter_fusion val epoch 49/60:   0%|          | 0/4 [00:00<?, ?it/s]
# Epoch 049/60 | train_loss=0.7525 train_acc=84.00% train_bacc=81.63% train_auc=0.9724 train_f1=0.8002 | val_loss=0.8781 val_acc=80.00% val_bacc=77.19% val_auc=0.9469 val_f1=0.7451
# cnn_inter_fusion train epoch 50/60:   0%|          | 0/29 [00:00<?, ?it/s]
# cnn_inter_fusion val epoch 50/60:   0%|          | 0/4 [00:00<?, ?it/s]
# Epoch 050/60 | train_loss=0.7611 train_acc=83.24% train_bacc=81.13% train_auc=0.9719 train_f1=0.7991 | val_loss=0.8773 val_acc=80.87% val_bacc=78.03% val_auc=0.9491 val_f1=0.7509
# cnn_inter_fusion train epoch 51/60:   0%|          | 0/29 [00:00<?, ?it/s]
# cnn_inter_fusion val epoch 51/60:   0%|          | 0/4 [00:00<?, ?it/s]
# Epoch 051/60 | train_loss=0.7543 train_acc=83.57% train_bacc=81.65% train_auc=0.9728 train_f1=0.7976 | val_loss=0.8717 val_acc=79.57% val_bacc=77.67% val_auc=0.9504 val_f1=0.7445
# cnn_inter_fusion train epoch 52/60:   0%|          | 0/29 [00:00<?, ?it/s]
# cnn_inter_fusion val epoch 52/60:   0%|          | 0/4 [00:00<?, ?it/s]
# Epoch 052/60 | train_loss=0.7486 train_acc=83.51% train_bacc=82.29% train_auc=0.9741 train_f1=0.7953 | val_loss=0.8732 val_acc=80.43% val_bacc=77.15% val_auc=0.9488 val_f1=0.7450
# cnn_inter_fusion train epoch 53/60:   0%|          | 0/29 [00:00<?, ?it/s]
# cnn_inter_fusion val epoch 53/60:   0%|          | 0/4 [00:00<?, ?it/s]
# Epoch 053/60 | train_loss=0.7547 train_acc=84.00% train_bacc=82.13% train_auc=0.9718 train_f1=0.8065 | val_loss=0.8865 val_acc=80.00% val_bacc=77.63% val_auc=0.9458 val_f1=0.7436
# cnn_inter_fusion train epoch 54/60:   0%|          | 0/29 [00:00<?, ?it/s]
# cnn_inter_fusion val epoch 54/60:   0%|          | 0/4 [00:00<?, ?it/s]
# Epoch 054/60 | train_loss=0.7633 train_acc=83.13% train_bacc=80.79% train_auc=0.9711 train_f1=0.7933 | val_loss=0.8902 val_acc=80.43% val_bacc=76.78% val_auc=0.9463 val_f1=0.7421
# cnn_inter_fusion train epoch 55/60:   0%|          | 0/29 [00:00<?, ?it/s]
# cnn_inter_fusion val epoch 55/60:   0%|          | 0/4 [00:00<?, ?it/s]
# Epoch 055/60 | train_loss=0.7362 train_acc=83.24% train_bacc=82.54% train_auc=0.9743 train_f1=0.8004 | val_loss=0.8724 val_acc=79.13% val_bacc=76.09% val_auc=0.9493 val_f1=0.7439
# cnn_inter_fusion train epoch 56/60:   0%|          | 0/29 [00:00<?, ?it/s]
# cnn_inter_fusion val epoch 56/60:   0%|          | 0/4 [00:00<?, ?it/s]
# Epoch 056/60 | train_loss=0.7463 train_acc=83.19% train_bacc=81.05% train_auc=0.9742 train_f1=0.7829 | val_loss=0.8846 val_acc=79.57% val_bacc=76.84% val_auc=0.9478 val_f1=0.7387
# cnn_inter_fusion train epoch 57/60:   0%|          | 0/29 [00:00<?, ?it/s]
# cnn_inter_fusion val epoch 57/60:   0%|          | 0/4 [00:00<?, ?it/s]
# Epoch 057/60 | train_loss=0.7427 train_acc=84.17% train_bacc=81.95% train_auc=0.9740 train_f1=0.8049 | val_loss=0.8922 val_acc=77.39% val_bacc=73.87% val_auc=0.9447 val_f1=0.7129
# cnn_inter_fusion train epoch 58/60:   0%|          | 0/29 [00:00<?, ?it/s]
# cnn_inter_fusion val epoch 58/60:   0%|          | 0/4 [00:00<?, ?it/s]
# Epoch 058/60 | train_loss=0.7333 train_acc=84.77% train_bacc=84.03% train_auc=0.9742 train_f1=0.8287 | val_loss=0.8864 val_acc=80.00% val_bacc=76.33% val_auc=0.9482 val_f1=0.7506
# cnn_inter_fusion train epoch 59/60:   0%|          | 0/29 [00:00<?, ?it/s]
# cnn_inter_fusion val epoch 59/60:   0%|          | 0/4 [00:00<?, ?it/s]
# Epoch 059/60 | train_loss=0.7347 train_acc=84.22% train_bacc=81.85% train_auc=0.9762 train_f1=0.8040 | val_loss=0.8853 val_acc=79.13% val_bacc=76.73% val_auc=0.9465 val_f1=0.7476
# cnn_inter_fusion train epoch 60/60:   0%|          | 0/29 [00:00<?, ?it/s]
# cnn_inter_fusion val epoch 60/60:   0%|          | 0/4 [00:00<?, ?it/s]
# Epoch 060/60 | train_loss=0.7378 train_acc=83.79% train_bacc=81.94% train_auc=0.9756 train_f1=0.8063 | val_loss=0.8867 val_acc=78.70% val_bacc=75.42% val_auc=0.9464 val_f1=0.7248
# Early stopping at epoch 60: no validation macro-F1 improvement for 12 epochs.
# cnn_inter_fusion test:   0%|          | 0/4 [00:00<?, ?it/s]
# wandb: WARNING Saving files without folders. If you want to preserve subdirectories pass base_path to wandb.save, i.e. wandb.save("/mnt/folder/file.h5", base_path="/mnt")
# wandb: WARNING Symlinked 1 file into the W&B run directory; call wandb.save again to sync new files.
# wandb: WARNING Symlinked 1 file into the W&B run directory; call wandb.save again to sync new files.
# wandb: WARNING Symlinked 1 file into the W&B run directory; call wandb.save again to sync new files.
# wandb: WARNING Symlinked 1 file into the W&B run directory; call wandb.save again to sync new files.
# wandb: WARNING Symlinked 1 file into the W&B run directory; call wandb.save again to sync new files.
# wandb: updating run metadata
# wandb: uploading history steps 114-123, summary, console lines 59-68
# wandb:
# wandb: Run history:
# wandb:                elapsed_sec ▁▁▁▁▂▂▂▂▂▂▃▃▃▃▄▄▄▄▅▅▅▅▅▅▅▆▆▆▆▆▆▇▇▇▇▇▇███
# wandb:                      epoch ▁▁▁▁▁▂▂▂▂▂▃▃▃▃▃▄▄▄▄▅▅▅▅▆▆▆▆▇▇▇▇▇▇▇▇█████
# wandb: epochs_without_improvement ▁▁▁▁▁▂▂▁▂▂▁▁▂▂▃▄▁▂▁▂▁▂▂▃▁▂▁▂▂▂▅▅▆▁▂▃▄▆▆█
# wandb:                         lr ███████████████████████████████▄▄▄▄▄▄▂▂▁
# wandb:                  train_acc ▁▃▅▆▆▆▇▇▇▇▇▇▇▇▇▇▇▇▇▇▇▇▇▇▇▇▇▇▇███████████
# wandb:                  train_auc ▁▃▅▅▆▇▇▇▇▇▇▇▇███████████████████████████
# wandb:                 train_bacc ▁▂▃▄▄▅▅▆▆▆▆▆▆▆▆▆▇▇▇▇▇▇▇▇▇▇▇▇▇▇██████████
# wandb:             train_f1_macro ▁▂▃▄▄▅▆▆▆▆▆▇▇▇▇▇▇▇▇▇▇▇▇▇▇▇█▇▇▇██████████
# wandb:                 train_loss █▇▆▅▅▃▃▃▃▃▂▂▂▂▂▂▂▂▂▂▂▂▂▂▂▂▁▂▁▁▁▁▁▁▁▁▁▁▁▁
# wandb:                    val_acc ▁▁▂▃▄▅▆▆▆▅▇▆▆▆▇▇█▇▇▇█▇█▇▇█▆██▇▇██████▇█▇
# wandb:                         +4 ...
# wandb:
# wandb: Run summary:
# wandb:                 best_epoch 48
# wandb:               best_val_acc 80.86957
# wandb:               best_val_auc 0.94713
# wandb:              best_val_bacc 77.81586
# wandb:          best_val_f1_macro 0.75939
# wandb:                elapsed_sec 264.6425
# wandb:                      epoch 60
# wandb: epochs_without_improvement 12
# wandb:                         lr 4e-05
# wandb:                   test_acc 80.86957
# wandb:                        +13 ...
# wandb:
# wandb: 🚀 View run cnn_inter_fusion at: https://wandb.ai/belalofficial123-the-british-university-in-egypt/iot%20fusion/runs/1xf2gl90
# wandb: ⭐️ View project at: https://wandb.ai/belalofficial123-the-british-university-in-egypt/iot%20fusion
# wandb: Synced 5 W&B file(s), 4 media file(s), 0 artifact file(s) and 5 other file(s)
# wandb: Find logs at: ./wandb/run-20260416_191540-1xf2gl90/logs
# Test performance:
# test_loss=0.8635 test_acc=80.87% test_bacc=72.65% test_auc=0.9482 test_f1=0.7361
# Classification report:
#               precision    recall  f1-score     support
# ACK            0.910448  0.835616  0.871429   73.000000
# BCC            0.789474  0.882353  0.833333   85.000000
# MEL            0.750000  0.600000  0.666667    5.000000
# NEV            0.884615  0.958333  0.920000   24.000000
# SCC            0.400000  0.300000  0.342857   20.000000
# SEK            0.782609  0.782609  0.782609   23.000000
# accuracy       0.808696  0.808696  0.808696    0.808696
# macro avg      0.752858  0.726485  0.736149  230.000000
# weighted avg   0.802386  0.808696  0.803122  230.000000
# cnn_inter_fusion complete: best_epoch=48, test_acc=80.87%
# {'experiment_name': 'cnn_inter_fusion',
#  'model_name': 'cnn',
#  'input_mode': 'intermediate_fusion',
#  'epochs': 60,
#  'batch_size': 64,
#  'split': '80 train / 10 validation / 10 test',
#  'augment_train': True,
#  'class_weighted_loss': True,
#  'class_weight_power': 0.5,
#  'class_balanced_sampler': False,
#  'best_epoch': 48,
#  'best_val_acc': 80.8695652173913,
#  'best_val_bacc': 77.81586099953078,
#  'best_val_auc': 0.9471297243857012,
#  'best_val_f1_macro': 0.7593933937899737,
#  'final_train_loss': 0.7377565577707301,
#  'final_train_acc': 83.7867247007617,
#  'final_train_bacc': 81.94353268153698,
#  'final_train_auc': 0.9755856135949664,
#  'final_train_f1_macro': 0.8063156910425989,
#  'final_val_loss': 0.886717034422833,
#  'final_val_acc': 78.69565217391305,
#  'final_val_bacc': 75.42327565489066,
#  'final_val_auc': 0.946383905564594,
#  'final_val_f1_macro': 0.7247815888987413,
#  'test_loss': 0.8634528595468273,
#  'test_acc': 80.8695652173913,
#  'test_bacc': 72.64852347530237,
#  'test_auc': 0.9482308480572944,
#  'test_f1_macro': 0.7361490683229813,
#  'elapsed_sec': 264.64250349998474,
#  'metrics_path': '/home/zeus/content/IOT_fusion/Results_Logs/cnn_inter_fusion/epoch_metrics.csv',
#  'epoch_log_path': '/home/zeus/content/IOT_fusion/Results_Logs/cnn_inter_fusion/epoch_log.txt',
#  'split_summary_path': '/home/zeus/content/IOT_fusion/Results_Logs/cnn_inter_fusion/split_summary.csv',
#  'checkpoint_path': '/home/zeus/content/IOT_fusion/outputs/ablations/cnn_inter_fusion_best.pth',
#  'classification_report_path': '/home/zeus/content/IOT_fusion/Results_Logs/cnn_inter_fusion/classification_report.csv',
#  'confusion_matrix_path': '/home/zeus/content/IOT_fusion/Results_Logs/cnn_inter_fusion/confusion_matrix.csv',
#  'test_predictions_path': '/home/zeus/content/IOT_fusion/Results_Logs/cnn_inter_fusion/test_predictions.csv',
#  'loss_curve_path': '/home/zeus/content/IOT_fusion/Results_Figures/cnn_inter_fusion/loss_curve.png',
#  'epoch_metrics_curve_path': '/home/zeus/content/IOT_fusion/Results_Figures/cnn_inter_fusion/epoch_metrics.png',
#  'confusion_matrix_plot_path': '/home/zeus/content/IOT_fusion/Results_Figures/cnn_inter_fusion/confusion_matrix.png',
#  'roc_curve_path': '/home/zeus/content/IOT_fusion/Results_Figures/cnn_inter_fusion/roc_curve.png',
#  'xai_paths': "{'image_saliency': '/home/zeus/content/IOT_fusion/Results_XAI/cnn_inter_fusion/cnn_inter_fusion_image_saliency.npy', 'metadata_importance': '/home/zeus/content/IOT_fusion/Results_XAI/cnn_inter_fusion/cnn_inter_fusion_metadata_xai_top20.csv'}"}

# %% [markdown]
# ## Training Outputs

# %%
from pathlib import Path
output_dir = Path('outputs/ablations')
logs_dir = Path('Results_Logs') / 'cnn_inter_fusion'
figures_dir = Path('Results_Figures') / 'cnn_inter_fusion'
xai_dir = Path('Results_XAI') / 'cnn_inter_fusion'
print('metrics:', logs_dir / 'epoch_metrics.csv')
print('epoch log:', logs_dir / 'epoch_log.txt')
print('result:', logs_dir / 'result_summary.csv')
print('checkpoint:', output_dir / 'cnn_inter_fusion_best.pth')
print('classification report:', logs_dir / 'classification_report.csv')
print('confusion matrix CSV:', logs_dir / 'confusion_matrix.csv')
print('loss curve:', figures_dir / 'loss_curve.png')
print('roc curve:', figures_dir / 'roc_curve.png')
sorted(str(p) for p in list(logs_dir.glob('*')) + list(figures_dir.glob('*')) + list(xai_dir.glob('*')))
# Out:
# metrics: Results_Logs/cnn_inter_fusion/epoch_metrics.csv
# epoch log: Results_Logs/cnn_inter_fusion/epoch_log.txt
# result: Results_Logs/cnn_inter_fusion/result_summary.csv
# checkpoint: outputs/ablations/cnn_inter_fusion_best.pth
# classification report: Results_Logs/cnn_inter_fusion/classification_report.csv
# confusion matrix CSV: Results_Logs/cnn_inter_fusion/confusion_matrix.csv
# loss curve: Results_Figures/cnn_inter_fusion/loss_curve.png
# roc curve: Results_Figures/cnn_inter_fusion/roc_curve.png
# ['Results_Figures/cnn_inter_fusion/confusion_matrix.png',
#  'Results_Figures/cnn_inter_fusion/epoch_metrics.png',
#  'Results_Figures/cnn_inter_fusion/loss_curve.png',
#  'Results_Figures/cnn_inter_fusion/roc_curve.png',
#  'Results_Logs/cnn_inter_fusion/classification_report.csv',
#  'Results_Logs/cnn_inter_fusion/confusion_matrix.csv',
#  'Results_Logs/cnn_inter_fusion/epoch_log.txt',
#  'Results_Logs/cnn_inter_fusion/epoch_metrics.csv',
#  'Results_Logs/cnn_inter_fusion/result_summary.csv',
#  'Results_Logs/cnn_inter_fusion/split_summary.csv',
#  'Results_Logs/cnn_inter_fusion/test_predictions.csv',
#  'Results_XAI/cnn_inter_fusion/cnn_inter_fusion_image_saliency.npy',
#  'Results_XAI/cnn_inter_fusion/cnn_inter_fusion_metadata_xai_top20.csv']
