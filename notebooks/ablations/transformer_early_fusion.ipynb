# %% [markdown]
# # TRANSFORMER Early Fusion Ablation
#
# Experiment: `transformer_early_fusion`
#
# This notebook runs full GPU training on a stratified 80/10/10 train/validation/test split built from the extracted processed tabular data and image tensors. Image runs use tensor-safe train augmentation and class-weighted loss. CNN runs use tempered class-weighted loss, stronger paper-style augmentation, and early stopping to reduce overfitting; balanced sampling can be enabled manually, but is off by default because it over-corrected on this dataset. Fusion modes combine the tabular metadata vector with the image tensor. It prints per-epoch train/validation loss, accuracy, macro AUC, and macro F1 with tqdm progress bars. Epoch logs are written under `Results_Logs/<experiment>/`, figures under `Results_Figures/<experiment>/`, and XAI artifacts under `Results_XAI/<experiment>/`.

# %%
from pathlib import Path
import os, sys
REPO_ROOT = Path('/home/zeus/content/IOT_fusion')
os.chdir(REPO_ROOT)
sys.path.insert(0, str(REPO_ROOT / 'training'))
from ablation_utils import get_data_info, run_training

info = get_data_info()
print('classes:', info.class_to_idx)
print('metadata_dim:', info.metadata_dim)
# Out:
# classes: {'ACK': 0, 'BCC': 1, 'MEL': 2, 'NEV': 3, 'SCC': 4, 'SEK': 5}
# metadata_dim: 87

# %% [markdown]
# ## Full GPU Training
# Adjust `epochs` and `batch_size` if needed.

# %%
full_result = run_training(
    model_name='transformer',
    input_mode='early_fusion',
    experiment_name='transformer_early_fusion',
    epochs=25,
    batch_size=256,
    lr=0.0005,
    num_workers=2,
    device_name='cuda',
    wandb_enabled=True,
    xai_enabled=True,
    augment_train=True,
    class_weighted_loss=True,
    class_weight_power=0.5,
    class_balanced_sampler=False,
    early_stopping_patience=12,
    min_epochs=15,
)
full_result
# Out:
# wandb: [wandb.login()] Loaded credentials for https://api.wandb.ai from WANDB_API_KEY.
# wandb: Currently logged in as: belalofficial123 (belalofficial123-the-british-university-in-egypt) to https://api.wandb.ai. Use `wandb login --relogin` to force relogin
# wandb: Tracking run with wandb version 0.26.0
# wandb: Run data is saved locally in /home/zeus/content/IOT_fusion/wandb/run-20260416_192734-54w6qgdk
# wandb: Run `wandb offline` to turn off syncing.
# wandb: Syncing run transformer_early_fusion
# wandb: ⭐️ View project at https://wandb.ai/belalofficial123-the-british-university-in-egypt/iot%20fusion
# wandb: 🚀 View run at https://wandb.ai/belalofficial123-the-british-university-in-egypt/iot%20fusion/runs/54w6qgdk
# Split sizes: {'train': 1838, 'val': 230, 'test': 230}
# Class mapping: {'ACK': 0, 'BCC': 1, 'MEL': 2, 'NEV': 3, 'SCC': 4, 'SEK': 5}
# /home/zeus/miniconda3/envs/cloudspace/lib/python3.12/site-packages/torch/nn/modules/transformer.py:392: UserWarning: enable_nested_tensor is True, but self.use_nested_tensor is False because encoder_layer.norm_first was True
#   warnings.warn(
# transformer_early_fusion train epoch 1/25:   0%|          | 0/8 [00:00<?, ?it/s]
# transformer_early_fusion val epoch 1/25:   0%|          | 0/1 [00:00<?, ?it/s]
# Epoch 001/25 | train_loss=2.9960 train_acc=27.58% train_bacc=19.40% train_auc=0.5232 train_f1=0.1860 | val_loss=2.0481 val_acc=10.43% val_bacc=12.71% val_auc=0.5562 val_f1=0.0782
# transformer_early_fusion train epoch 2/25:   0%|          | 0/8 [00:00<?, ?it/s]
# transformer_early_fusion val epoch 2/25:   0%|          | 0/1 [00:00<?, ?it/s]
# Epoch 002/25 | train_loss=1.8742 train_acc=27.04% train_bacc=19.54% train_auc=0.5462 train_f1=0.1630 | val_loss=1.7292 val_acc=32.17% val_bacc=22.80% val_auc=0.6435 val_f1=0.1838
# transformer_early_fusion train epoch 3/25:   0%|          | 0/8 [00:00<?, ?it/s]
# transformer_early_fusion val epoch 3/25:   0%|          | 0/1 [00:00<?, ?it/s]
# Epoch 003/25 | train_loss=1.7676 train_acc=35.09% train_bacc=23.78% train_auc=0.5728 train_f1=0.2399 | val_loss=1.8667 val_acc=33.04% val_bacc=21.80% val_auc=0.5878 val_f1=0.1520
# transformer_early_fusion train epoch 4/25:   0%|          | 0/8 [00:00<?, ?it/s]
# transformer_early_fusion val epoch 4/25:   0%|          | 0/1 [00:00<?, ?it/s]
# Epoch 004/25 | train_loss=1.7764 train_acc=30.69% train_bacc=21.35% train_auc=0.5726 train_f1=0.1971 | val_loss=1.7084 val_acc=38.70% val_bacc=19.30% val_auc=0.6968 val_f1=0.1497
# transformer_early_fusion train epoch 5/25:   0%|          | 0/8 [00:00<?, ?it/s]
# transformer_early_fusion val epoch 5/25:   0%|          | 0/1 [00:00<?, ?it/s]
# Epoch 005/25 | train_loss=1.7383 train_acc=38.57% train_bacc=21.25% train_auc=0.6029 train_f1=0.2033 | val_loss=1.7053 val_acc=32.17% val_bacc=22.83% val_auc=0.6914 val_f1=0.1776
# transformer_early_fusion train epoch 6/25:   0%|          | 0/8 [00:00<?, ?it/s]
# transformer_early_fusion val epoch 6/25:   0%|          | 0/1 [00:00<?, ?it/s]
# Epoch 006/25 | train_loss=1.7209 train_acc=35.85% train_bacc=23.74% train_auc=0.6200 train_f1=0.2318 | val_loss=1.6876 val_acc=42.17% val_bacc=27.33% val_auc=0.6605 val_f1=0.2644
# transformer_early_fusion train epoch 7/25:   0%|          | 0/8 [00:00<?, ?it/s]
# transformer_early_fusion val epoch 7/25:   0%|          | 0/1 [00:00<?, ?it/s]
# Epoch 007/25 | train_loss=1.7023 train_acc=37.92% train_bacc=24.82% train_auc=0.6299 train_f1=0.2439 | val_loss=1.6617 val_acc=43.48% val_bacc=26.51% val_auc=0.7157 val_f1=0.2440
# transformer_early_fusion train epoch 8/25:   0%|          | 0/8 [00:00<?, ?it/s]
# transformer_early_fusion val epoch 8/25:   0%|          | 0/1 [00:00<?, ?it/s]
# Epoch 008/25 | train_loss=1.6958 train_acc=39.34% train_bacc=27.41% train_auc=0.6319 train_f1=0.2527 | val_loss=1.6705 val_acc=44.78% val_bacc=24.96% val_auc=0.7011 val_f1=0.2328
# transformer_early_fusion train epoch 9/25:   0%|          | 0/8 [00:00<?, ?it/s]
# transformer_early_fusion val epoch 9/25:   0%|          | 0/1 [00:00<?, ?it/s]
# Epoch 009/25 | train_loss=1.6775 train_acc=41.19% train_bacc=26.90% train_auc=0.6520 train_f1=0.2757 | val_loss=1.6761 val_acc=42.17% val_bacc=32.85% val_auc=0.7188 val_f1=0.2567
# transformer_early_fusion train epoch 10/25:   0%|          | 0/8 [00:00<?, ?it/s]
# transformer_early_fusion val epoch 10/25:   0%|          | 0/1 [00:00<?, ?it/s]
# Epoch 010/25 | train_loss=1.7020 train_acc=39.88% train_bacc=25.21% train_auc=0.6481 train_f1=0.2359 | val_loss=1.6180 val_acc=47.39% val_bacc=33.96% val_auc=0.7437 val_f1=0.3301
# transformer_early_fusion train epoch 11/25:   0%|          | 0/8 [00:00<?, ?it/s]
# transformer_early_fusion val epoch 11/25:   0%|          | 0/1 [00:00<?, ?it/s]
# Epoch 011/25 | train_loss=1.6514 train_acc=41.68% train_bacc=29.10% train_auc=0.6794 train_f1=0.2824 | val_loss=1.6029 val_acc=48.26% val_bacc=28.69% val_auc=0.7332 val_f1=0.2656
# transformer_early_fusion train epoch 12/25:   0%|          | 0/8 [00:00<?, ?it/s]
# transformer_early_fusion val epoch 12/25:   0%|          | 0/1 [00:00<?, ?it/s]
# Epoch 012/25 | train_loss=1.6082 train_acc=45.76% train_bacc=31.49% train_auc=0.7132 train_f1=0.3018 | val_loss=1.5871 val_acc=49.13% val_bacc=36.18% val_auc=0.7626 val_f1=0.2923
# transformer_early_fusion train epoch 13/25:   0%|          | 0/8 [00:00<?, ?it/s]
# transformer_early_fusion val epoch 13/25:   0%|          | 0/1 [00:00<?, ?it/s]
# Epoch 013/25 | train_loss=1.5874 train_acc=44.50% train_bacc=30.00% train_auc=0.7255 train_f1=0.2734 | val_loss=1.6890 val_acc=46.09% val_bacc=28.85% val_auc=0.7471 val_f1=0.2267
# transformer_early_fusion train epoch 14/25:   0%|          | 0/8 [00:00<?, ?it/s]
# transformer_early_fusion val epoch 14/25:   0%|          | 0/1 [00:00<?, ?it/s]
# Epoch 014/25 | train_loss=1.5335 train_acc=47.61% train_bacc=36.25% train_auc=0.7488 train_f1=0.3503 | val_loss=1.6550 val_acc=46.52% val_bacc=34.78% val_auc=0.7606 val_f1=0.2832
# transformer_early_fusion train epoch 15/25:   0%|          | 0/8 [00:00<?, ?it/s]
# transformer_early_fusion val epoch 15/25:   0%|          | 0/1 [00:00<?, ?it/s]
# Epoch 015/25 | train_loss=1.4764 train_acc=50.87% train_bacc=37.62% train_auc=0.7766 train_f1=0.3493 | val_loss=1.6720 val_acc=48.26% val_bacc=32.66% val_auc=0.7541 val_f1=0.2855
# transformer_early_fusion train epoch 16/25:   0%|          | 0/8 [00:00<?, ?it/s]
# transformer_early_fusion val epoch 16/25:   0%|          | 0/1 [00:00<?, ?it/s]
# Epoch 016/25 | train_loss=1.4555 train_acc=54.52% train_bacc=36.39% train_auc=0.7856 train_f1=0.3607 | val_loss=1.6870 val_acc=45.22% val_bacc=33.10% val_auc=0.7510 val_f1=0.2464
# transformer_early_fusion train epoch 17/25:   0%|          | 0/8 [00:00<?, ?it/s]
# transformer_early_fusion val epoch 17/25:   0%|          | 0/1 [00:00<?, ?it/s]
# Epoch 017/25 | train_loss=1.4249 train_acc=52.29% train_bacc=38.91% train_auc=0.8050 train_f1=0.3776 | val_loss=1.7652 val_acc=41.30% val_bacc=28.67% val_auc=0.7501 val_f1=0.1822
# transformer_early_fusion train epoch 18/25:   0%|          | 0/8 [00:00<?, ?it/s]
# transformer_early_fusion val epoch 18/25:   0%|          | 0/1 [00:00<?, ?it/s]
# Epoch 018/25 | train_loss=1.4121 train_acc=56.20% train_bacc=37.47% train_auc=0.8058 train_f1=0.3659 | val_loss=1.6050 val_acc=44.78% val_bacc=33.87% val_auc=0.7540 val_f1=0.2564
# transformer_early_fusion train epoch 19/25:   0%|          | 0/8 [00:00<?, ?it/s]
# transformer_early_fusion val epoch 19/25:   0%|          | 0/1 [00:00<?, ?it/s]
# Epoch 019/25 | train_loss=1.4080 train_acc=53.05% train_bacc=38.46% train_auc=0.8035 train_f1=0.3674 | val_loss=1.7061 val_acc=46.52% val_bacc=34.01% val_auc=0.7550 val_f1=0.2645
# transformer_early_fusion train epoch 20/25:   0%|          | 0/8 [00:00<?, ?it/s]
# transformer_early_fusion val epoch 20/25:   0%|          | 0/1 [00:00<?, ?it/s]
# Epoch 020/25 | train_loss=1.3818 train_acc=58.11% train_bacc=37.94% train_auc=0.8155 train_f1=0.3759 | val_loss=1.6290 val_acc=46.52% val_bacc=34.57% val_auc=0.7699 val_f1=0.2615
# transformer_early_fusion train epoch 21/25:   0%|          | 0/8 [00:00<?, ?it/s]
# transformer_early_fusion val epoch 21/25:   0%|          | 0/1 [00:00<?, ?it/s]
# Epoch 021/25 | train_loss=1.3625 train_acc=57.45% train_bacc=41.54% train_auc=0.8229 train_f1=0.3930 | val_loss=1.6731 val_acc=44.78% val_bacc=33.63% val_auc=0.7800 val_f1=0.2556
# transformer_early_fusion train epoch 22/25:   0%|          | 0/8 [00:00<?, ?it/s]
# transformer_early_fusion val epoch 22/25:   0%|          | 0/1 [00:00<?, ?it/s]
# Epoch 022/25 | train_loss=1.3594 train_acc=55.11% train_bacc=42.68% train_auc=0.8289 train_f1=0.3961 | val_loss=1.6146 val_acc=46.96% val_bacc=37.87% val_auc=0.7824 val_f1=0.2803
# Early stopping at epoch 22: no validation macro-F1 improvement for 12 epochs.
# transformer_early_fusion test:   0%|          | 0/1 [00:00<?, ?it/s]
# wandb: WARNING Saving files without folders. If you want to preserve subdirectories pass base_path to wandb.save, i.e. wandb.save("/mnt/folder/file.h5", base_path="/mnt")
# wandb: WARNING Symlinked 1 file into the W&B run directory; call wandb.save again to sync new files.
# wandb: WARNING Symlinked 1 file into the W&B run directory; call wandb.save again to sync new files.
# wandb: WARNING Symlinked 1 file into the W&B run directory; call wandb.save again to sync new files.
# wandb: WARNING Symlinked 1 file into the W&B run directory; call wandb.save again to sync new files.
# wandb: WARNING Symlinked 1 file into the W&B run directory; call wandb.save again to sync new files.
# wandb: updating run metadata
# wandb:
# wandb: Run history:
# wandb:                elapsed_sec ▁▁▂▂▂▃▃▃▄▄▄▅▅▅▆▆▆▇▇▇██
# wandb:                      epoch ▁▁▁▁▂▂▂▂▂▂▃▃▃▃▃▄▄▄▄▄▅▅▅▅▅▅▆▆▆▆▆▇▇▇▇▇▇███
# wandb: epochs_without_improvement ▁▁▂▂▃▁▂▂▃▁▂▂▃▃▄▅▅▆▆▇▇█
# wandb:                         lr ███████████████▃▃▃▃▃▃▁
# wandb:                  train_acc ▁▁▃▂▄▃▃▄▄▄▄▅▅▆▆▇▇█▇██▇
# wandb:                  train_auc ▁▂▂▂▃▃▃▃▄▄▅▅▆▆▇▇▇▇▇███
# wandb:                 train_bacc ▁▁▂▂▂▂▃▃▃▃▄▅▄▆▆▆▇▆▇▇██
# wandb:             train_f1_macro ▂▁▃▂▂▃▃▄▄▃▅▅▄▇▇▇▇▇▇▇██
# wandb:                 train_loss █▃▃▃▃▃▂▂▂▂▂▂▂▂▂▁▁▁▁▁▁▁
# wandb:                    val_acc ▁▅▅▆▅▇▇▇▇███▇██▇▇▇██▇█
# wandb:                         +4 ...
# wandb:
# wandb: Run summary:
# wandb:                 best_epoch 10
# wandb:               best_val_acc 47.3913
# wandb:               best_val_auc 0.74365
# wandb:              best_val_bacc 33.96145
# wandb:          best_val_f1_macro 0.33014
# wandb:                elapsed_sec 134.59529
# wandb:                      epoch 22
# wandb: epochs_without_improvement 12
# wandb:                         lr 0.00013
# wandb:                   test_acc 40.86957
# wandb:                        +13 ...
# wandb:
# wandb: 🚀 View run transformer_early_fusion at: https://wandb.ai/belalofficial123-the-british-university-in-egypt/iot%20fusion/runs/54w6qgdk
# wandb: ⭐️ View project at: https://wandb.ai/belalofficial123-the-british-university-in-egypt/iot%20fusion
# wandb: Synced 5 W&B file(s), 4 media file(s), 0 artifact file(s) and 5 other file(s)
# wandb: Find logs at: ./wandb/run-20260416_192734-54w6qgdk/logs
# Test performance:
# test_loss=1.6895 test_acc=40.87% test_bacc=29.34% test_auc=0.6842 test_f1=0.2821
# Classification report:
#               precision    recall  f1-score     support
# ACK            0.444444  0.438356  0.441379   73.000000
# BCC            0.558442  0.505882  0.530864   85.000000
# MEL            0.000000  0.000000  0.000000    5.000000
# NEV            0.391304  0.375000  0.382979   24.000000
# SCC            0.076923  0.050000  0.060606   20.000000
# SEK            0.214286  0.391304  0.276923   23.000000
# accuracy       0.408696  0.408696  0.408696    0.408696
# macro avg      0.280900  0.293424  0.282125  230.000000
# weighted avg   0.416393  0.408696  0.409204  230.000000
# transformer_early_fusion complete: best_epoch=10, test_acc=40.87%
# {'experiment_name': 'transformer_early_fusion',
#  'model_name': 'transformer',
#  'input_mode': 'early_fusion',
#  'epochs': 25,
#  'batch_size': 256,
#  'split': '80 train / 10 validation / 10 test',
#  'augment_train': True,
#  'class_weighted_loss': True,
#  'class_weight_power': 0.5,
#  'class_balanced_sampler': False,
#  'best_epoch': 10,
#  'best_val_acc': 47.391304347826086,
#  'best_val_bacc': 33.961450429727286,
#  'best_val_auc': 0.7436517511865356,
#  'best_val_f1_macro': 0.3301430001161722,
#  'final_train_loss': 1.3594160576769525,
#  'final_train_acc': 55.11425462459195,
#  'final_train_bacc': 42.68049411045101,
#  'final_train_auc': 0.828888125283702,
#  'final_train_f1_macro': 0.3960665352416379,
#  'final_val_loss': 1.614560604095459,
#  'final_val_acc': 46.95652173913044,
#  'final_val_bacc': 37.87176560121765,
#  'final_val_auc': 0.7823624581769416,
#  'final_val_f1_macro': 0.28028358629186256,
#  'test_loss': 1.6894912719726562,
#  'test_acc': 40.869565217391305,
#  'test_bacc': 29.342381085847087,
#  'test_auc': 0.6841556065133565,
#  'test_f1_macro': 0.2821252281348474,
#  'elapsed_sec': 134.59529304504395,
#  'metrics_path': '/home/zeus/content/IOT_fusion/Results_Logs/transformer_early_fusion/epoch_metrics.csv',
#  'epoch_log_path': '/home/zeus/content/IOT_fusion/Results_Logs/transformer_early_fusion/epoch_log.txt',
#  'split_summary_path': '/home/zeus/content/IOT_fusion/Results_Logs/transformer_early_fusion/split_summary.csv',
#  'checkpoint_path': '/home/zeus/content/IOT_fusion/outputs/ablations/transformer_early_fusion_best.pth',
#  'classification_report_path': '/home/zeus/content/IOT_fusion/Results_Logs/transformer_early_fusion/classification_report.csv',
#  'confusion_matrix_path': '/home/zeus/content/IOT_fusion/Results_Logs/transformer_early_fusion/confusion_matrix.csv',
#  'test_predictions_path': '/home/zeus/content/IOT_fusion/Results_Logs/transformer_early_fusion/test_predictions.csv',
#  'loss_curve_path': '/home/zeus/content/IOT_fusion/Results_Figures/transformer_early_fusion/loss_curve.png',
#  'epoch_metrics_curve_path': '/home/zeus/content/IOT_fusion/Results_Figures/transformer_early_fusion/epoch_metrics.png',
#  'confusion_matrix_plot_path': '/home/zeus/content/IOT_fusion/Results_Figures/transformer_early_fusion/confusion_matrix.png',
#  'roc_curve_path': '/home/zeus/content/IOT_fusion/Results_Figures/transformer_early_fusion/roc_curve.png',
#  'xai_paths': "{'image_saliency': '/home/zeus/content/IOT_fusion/Results_XAI/transformer_early_fusion/transformer_early_fusion_image_saliency.npy', 'metadata_importance': '/home/zeus/content/IOT_fusion/Results_XAI/transformer_early_fusion/transformer_early_fusion_metadata_xai_top20.csv'}"}

# %% [markdown]
# ## Training Outputs

# %%
from pathlib import Path
output_dir = Path('outputs/ablations')
logs_dir = Path('Results_Logs') / 'transformer_early_fusion'
figures_dir = Path('Results_Figures') / 'transformer_early_fusion'
xai_dir = Path('Results_XAI') / 'transformer_early_fusion'
print('metrics:', logs_dir / 'epoch_metrics.csv')
print('epoch log:', logs_dir / 'epoch_log.txt')
print('result:', logs_dir / 'result_summary.csv')
print('checkpoint:', output_dir / 'transformer_early_fusion_best.pth')
print('classification report:', logs_dir / 'classification_report.csv')
print('confusion matrix CSV:', logs_dir / 'confusion_matrix.csv')
print('loss curve:', figures_dir / 'loss_curve.png')
print('roc curve:', figures_dir / 'roc_curve.png')
sorted(str(p) for p in list(logs_dir.glob('*')) + list(figures_dir.glob('*')) + list(xai_dir.glob('*')))
# Out:
# metrics: Results_Logs/transformer_early_fusion/epoch_metrics.csv
# epoch log: Results_Logs/transformer_early_fusion/epoch_log.txt
# result: Results_Logs/transformer_early_fusion/result_summary.csv
# checkpoint: outputs/ablations/transformer_early_fusion_best.pth
# classification report: Results_Logs/transformer_early_fusion/classification_report.csv
# confusion matrix CSV: Results_Logs/transformer_early_fusion/confusion_matrix.csv
# loss curve: Results_Figures/transformer_early_fusion/loss_curve.png
# roc curve: Results_Figures/transformer_early_fusion/roc_curve.png
# ['Results_Figures/transformer_early_fusion/confusion_matrix.png',
#  'Results_Figures/transformer_early_fusion/epoch_metrics.png',
#  'Results_Figures/transformer_early_fusion/loss_curve.png',
#  'Results_Figures/transformer_early_fusion/roc_curve.png',
#  'Results_Logs/transformer_early_fusion/classification_report.csv',
#  'Results_Logs/transformer_early_fusion/confusion_matrix.csv',
#  'Results_Logs/transformer_early_fusion/epoch_log.txt',
#  'Results_Logs/transformer_early_fusion/epoch_metrics.csv',
#  'Results_Logs/transformer_early_fusion/result_summary.csv',
#  'Results_Logs/transformer_early_fusion/split_summary.csv',
#  'Results_Logs/transformer_early_fusion/test_predictions.csv',
#  'Results_XAI/transformer_early_fusion/transformer_early_fusion_image_saliency.npy',
#  'Results_XAI/transformer_early_fusion/transformer_early_fusion_metadata_xai_top20.csv']
